# %% [markdown]
# ---
#
# # 230920
# ## 목표
# 1. 230912_MILP_WTA의 데이터 받아서 실행하기
#     - 데이터 전처리
#     - 제한 함수 삭제
#     - 목적함수 수정

# %%
import numpy as np
import time

path = "/ssd2/kawon/230727_WTA/data/wta_100x200x1.txt"

weight=[]



# reading data from text file
f = open(path, "r")
lines = f.readlines()
f.close()



# reading first line
W, T, FN_T = [int(v) for v in lines[0].split()]
# asssuming all weapons have the same availability:
FN_T = [FN_T] * W

M = sum(FN_T)


# 0과 99 사이의 실수로 PK_wt 배열 초기화
PK_wt = np.random.uniform(0, 99, (W, T))


# reading target weights
for line in lines[1:T + 1]:
    weight.append(int(line))



# reading probabilities
for line in lines[T + 1:]:
    splitted = line.split()
    w, t, p = int(splitted[0]), int(splitted[1]), float(splitted[2])
    PK_wt[w][t] = p

# %%
# 발사대 만큼의 빈 리스트로 구성
tau = [[] for _ in range(W)]

# M을 W로 나누어 리스트에 적절히 분배
quotient, remainder = divmod(M, W)
m_w = [quotient] * W

# 나머지 값을 리스트의 앞부분에 추가
for i in range(remainder):
    m_w[i] += 1

# %%
import copy
# Initialize a 3D binary matrix of zeros
theta_wt = np.zeros((W, T, M), dtype=int)

# 미사일이 소모되는 리스트 left_FN_T으로 복사
# left_FN_T = copy.copy(FN_T)

# 발사대에 적재된 유도탄 수량 리스트 left_m_w로 복사
left_m_w = copy.copy(m_w)

# 행렬의 원소들을 1차원 배열로 변환
flattened = PK_wt.flatten()

# 원소들을 내림차순으로 정렬
sorted_indices = np.argsort(flattened)[::-1]

# %%
i = 0
m = 0
indices_list = []

while True :
    if i == T * W :
        break
    # i번째 요격확률의 인덱스 v
    v = sorted_indices[i]
    
    row = v // T # Weapon
    col = v % T # Target
    print(f"Value: {flattened[v]}, Index: (Weapon : {row}, Target : {col})")
    
    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있다면,
    # 해당 Weapon의 적재된 유도탄이 남아 있다면,
    # if left_FN_T[col] > 0 and left_m_w[row] > 0:
    if left_m_w[row] > 0:
            
        
            
        # 할당할 유도탄 개수 감소
        # left_FN_T[col] -= 1
        left_m_w[row] -= 1
        # 해당 W T M에 1 부여
        theta_wt[row][col][m] = 1
        # 무기가 할당된 indices_list에 추가
        indices_list.append(v)

        # 다음 미사일 인덱스로 이동
        m += 1

    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있지 않다면,
    elif left_FN_T[col] > 0:
        pass
        # print(f"not enough Missile on Weapon {row}")
    
    else :
        pass
        # print(f"not enough Missile for Target {col}")
    
    # 할당할 수 있는 유도탄의 개수를 모두 소모했다면 종료.
    if sum(left_FN_T) == 0:
        break
    

    # 다음으로 요격확률이 높은 인덱스로 이동
    i += 1
# Out:
# Value: 0.999976253973, Index: (Weapon : 32, Target : 138)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /ssd2/kawon/230727_WTA/230920_algorithm.ipynb 셀 5 line <cell line: 6>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>     pass
#      <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a>     # print(f"not enough Missile for Target {col}")
#      <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> # 할당할 수 있는 유도탄의 개수를 모두 소모했다면 종료.
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> if sum(left_FN_T) == 0:
#      <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a>     break
#      <a href='vscode-notebook-cell://ssh-remote%2Bserver10/ssd2/kawon/230727_WTA/230920_algorithm.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> # 다음으로 요격확률이 높은 인덱스로 이동
#
# NameError: name 'left_FN_T' is not defined

# %%
"""
목표함수 (1)
해당 목적함수는 결정변수 theta_wt와 요격확률의 곱의 합을 최대화함으로써 요격확률이 높을 때 표적-발사대 쌍의 발사 시점에 무기할당을 하는 의미로 해석할 수 있다.
"""
def objective_fun_1(theta_wt,weight):
    res = 0
    for t in range(T):
        
        a = 1
        for w in range(W):
            for m in range(M):
                p = 1 - PK_wt[w,t] * theta_wt[w,t,m]
                a *= p
        
        a *= weight[t]

        print(f"타깃 {t}에 대한 성공 값 : {a}")
        res += a


    return res

# %%
objective_fun_1(theta_wt,weight)
# Out:
# 타깃 0에 대한 성공 값 : 54.0
# 타깃 1에 대한 성공 값 : 49.0
# 타깃 2에 대한 성공 값 : 66.0
# 타깃 3에 대한 성공 값 : 61.0
# 타깃 4에 대한 성공 값 : 94.0
# 타깃 5에 대한 성공 값 : 29.0
# 타깃 6에 대한 성공 값 : 51.0
# 타깃 7에 대한 성공 값 : 65.0
# 타깃 8에 대한 성공 값 : 5.0
# 타깃 9에 대한 성공 값 : 21.0
# 타깃 10에 대한 성공 값 : 51.0
# 타깃 11에 대한 성공 값 : 63.0
# 타깃 12에 대한 성공 값 : 50.0
# 타깃 13에 대한 성공 값 : 42.0
# 타깃 14에 대한 성공 값 : 66.0
# 타깃 15에 대한 성공 값 : 22.0
# 타깃 16에 대한 성공 값 : 59.0
# 타깃 17에 대한 성공 값 : 30.0
# 타깃 18에 대한 성공 값 : 17.0
# 타깃 19에 대한 성공 값 : 13.0
# 타깃 20에 대한 성공 값 : 55.0
# 타깃 21에 대한 성공 값 : 19.0
# 타깃 22에 대한 성공 값 : 95.0
# 타깃 23에 대한 성공 값 : 17.0
# 타깃 24에 대한 성공 값 : 89.0
# 타깃 25에 대한 성공 값 : 25.0
# 타깃 26에 대한 성공 값 : 15.0
# 타깃 27에 대한 성공 값 : 33.0
# 타깃 28에 대한 성공 값 : 54.0
# 타깃 29에 대한 성공 값 : 42.0
# 타깃 30에 대한 성공 값 : 91.0
# 타깃 31에 대한 성공 값 : 87.0
# 타깃 32에 대한 성공 값 : 30.0
# 타깃 33에 대한 성공 값 : 34.0
# 타깃 34에 대한 성공 값 : 30.0
# 타깃 35에 대한 성공 값 : 34.0
# 타깃 36에 대한 성공 값 : 56.0
# 타깃 37에 대한 성공 값 : 95.0
# 타깃 38에 대한 성공 값 : 78.0
# 타깃 39에 대한 성공 값 : 58.0
# 타깃 40에 대한 성공 값 : 38.0
# 타깃 41에 대한 성공 값 : 100.0
# 타깃 42에 대한 성공 값 : 95.0
# 타깃 43에 대한 성공 값 : 34.0
# 타깃 44에 대한 성공 값 : 84.0
# 타깃 45에 대한 성공 값 : 40.0
# 타깃 46에 대한 성공 값 : 50.0
# 타깃 47에 대한 성공 값 : 52.0
# 타깃 48에 대한 성공 값 : 63.0
# 타깃 49에 대한 성공 값 : 58.0
# 타깃 50에 대한 성공 값 : 98.0
# 타깃 51에 대한 성공 값 : 70.0
# 타깃 52에 대한 성공 값 : 12.0
# 타깃 53에 대한 성공 값 : 46.0
# 타깃 54에 대한 성공 값 : 65.0
# 타깃 55에 대한 성공 값 : 38.0
# 타깃 56에 대한 성공 값 : 40.0
# 타깃 57에 대한 성공 값 : 22.0
# 타깃 58에 대한 성공 값 : 37.0
# 타깃 59에 대한 성공 값 : 70.0
# 타깃 60에 대한 성공 값 : 26.0
# 타깃 61에 대한 성공 값 : 74.0
# 타깃 62에 대한 성공 값 : 20.0
# 타깃 63에 대한 성공 값 : 87.0
# 타깃 64에 대한 성공 값 : 46.0
# 타깃 65에 대한 성공 값 : 17.0
# 타깃 66에 대한 성공 값 : 91.0
# 타깃 67에 대한 성공 값 : 12.0
# 타깃 68에 대한 성공 값 : 48.0
# 타깃 69에 대한 성공 값 : 63.0
# 타깃 70에 대한 성공 값 : 20.0
# 타깃 71에 대한 성공 값 : 89.0
# 타깃 72에 대한 성공 값 : 84.0
# 타깃 73에 대한 성공 값 : 7.0
# 타깃 74에 대한 성공 값 : 44.0
# 타깃 75에 대한 성공 값 : 11.0
# 타깃 76에 대한 성공 값 : 89.0
# 타깃 77에 대한 성공 값 : 12.0
# 타깃 78에 대한 성공 값 : 38.0
# 타깃 79에 대한 성공 값 : 66.0
# 타깃 80에 대한 성공 값 : 4.0
# 타깃 81에 대한 성공 값 : 55.0
# 타깃 82에 대한 성공 값 : 49.0
# 타깃 83에 대한 성공 값 : 26.0
# 타깃 84에 대한 성공 값 : 47.0
# 타깃 85에 대한 성공 값 : 79.0
# 타깃 86에 대한 성공 값 : 92.0
# 타깃 87에 대한 성공 값 : 93.0
# 타깃 88에 대한 성공 값 : 18.0
# 타깃 89에 대한 성공 값 : 95.0
# 타깃 90에 대한 성공 값 : 17.0
# 타깃 91에 대한 성공 값 : 88.0
# 타깃 92에 대한 성공 값 : 84.0
# 타깃 93에 대한 성공 값 : 45.0
# 타깃 94에 대한 성공 값 : 60.0
# 타깃 95에 대한 성공 값 : 67.0
# 타깃 96에 대한 성공 값 : 87.0
# 타깃 97에 대한 성공 값 : 98.0
# 타깃 98에 대한 성공 값 : 39.0
# 타깃 99에 대한 성공 값 : 27.0
# 타깃 100에 대한 성공 값 : 99.0
# 타깃 101에 대한 성공 값 : 59.0
# 타깃 102에 대한 성공 값 : 41.0
# 타깃 103에 대한 성공 값 : 1.0
# 타깃 104에 대한 성공 값 : 52.0
# 타깃 105에 대한 성공 값 : 6.0
# 타깃 106에 대한 성공 값 : 75.0
# 타깃 107에 대한 성공 값 : 100.0
# 타깃 108에 대한 성공 값 : 50.0
# 타깃 109에 대한 성공 값 : 37.0
# 타깃 110에 대한 성공 값 : 64.0
# 타깃 111에 대한 성공 값 : 53.0
# 타깃 112에 대한 성공 값 : 52.0
# 타깃 113에 대한 성공 값 : 78.0
# 타깃 114에 대한 성공 값 : 23.0
# 타깃 115에 대한 성공 값 : 46.0
# 타깃 116에 대한 성공 값 : 58.0
# 타깃 117에 대한 성공 값 : 87.0
# 타깃 118에 대한 성공 값 : 94.0
# 타깃 119에 대한 성공 값 : 27.0
# 타깃 120에 대한 성공 값 : 19.0
# 타깃 121에 대한 성공 값 : 96.0
# 타깃 122에 대한 성공 값 : 32.0
# 타깃 123에 대한 성공 값 : 27.0
# 타깃 124에 대한 성공 값 : 65.0
# 타깃 125에 대한 성공 값 : 26.0
# 타깃 126에 대한 성공 값 : 81.0
# 타깃 127에 대한 성공 값 : 37.0
# 타깃 128에 대한 성공 값 : 11.0
# 타깃 129에 대한 성공 값 : 8.0
# 타깃 130에 대한 성공 값 : 46.0
# 타깃 131에 대한 성공 값 : 30.0
# 타깃 132에 대한 성공 값 : 28.0
# 타깃 133에 대한 성공 값 : 84.0
# 타깃 134에 대한 성공 값 : 61.0
# 타깃 135에 대한 성공 값 : 55.0
# 타깃 136에 대한 성공 값 : 43.0
# 타깃 137에 대한 성공 값 : 26.0
# 타깃 138에 대한 성공 값 : 0.00023746026999948988
# 타깃 139에 대한 성공 값 : 76.0
# 타깃 140에 대한 성공 값 : 14.0
# 타깃 141에 대한 성공 값 : 32.0
# 타깃 142에 대한 성공 값 : 29.0
# 타깃 143에 대한 성공 값 : 46.0
# 타깃 144에 대한 성공 값 : 65.0
# 타깃 145에 대한 성공 값 : 64.0
# 타깃 146에 대한 성공 값 : 24.0
# 타깃 147에 대한 성공 값 : 65.0
# 타깃 148에 대한 성공 값 : 44.0
# 타깃 149에 대한 성공 값 : 2.0
# 타깃 150에 대한 성공 값 : 15.0
# 타깃 151에 대한 성공 값 : 1.0
# 타깃 152에 대한 성공 값 : 40.0
# 타깃 153에 대한 성공 값 : 49.0
# 타깃 154에 대한 성공 값 : 37.0
# 타깃 155에 대한 성공 값 : 31.0
# 타깃 156에 대한 성공 값 : 23.0
# 타깃 157에 대한 성공 값 : 47.0
# 타깃 158에 대한 성공 값 : 2.0
# 타깃 159에 대한 성공 값 : 33.0
# 타깃 160에 대한 성공 값 : 36.0
# 타깃 161에 대한 성공 값 : 63.0
# 타깃 162에 대한 성공 값 : 70.0
# 타깃 163에 대한 성공 값 : 92.0
# 타깃 164에 대한 성공 값 : 98.0
# 타깃 165에 대한 성공 값 : 32.0
# 타깃 166에 대한 성공 값 : 45.0
# 타깃 167에 대한 성공 값 : 86.0
# 타깃 168에 대한 성공 값 : 86.0
# 타깃 169에 대한 성공 값 : 35.0
# 타깃 170에 대한 성공 값 : 60.0
# 타깃 171에 대한 성공 값 : 61.0
# 타깃 172에 대한 성공 값 : 87.0
# 타깃 173에 대한 성공 값 : 62.0
# 타깃 174에 대한 성공 값 : 68.0
# 타깃 175에 대한 성공 값 : 17.0
# 타깃 176에 대한 성공 값 : 51.0
# 타깃 177에 대한 성공 값 : 94.0
# 타깃 178에 대한 성공 값 : 8.0
# 타깃 179에 대한 성공 값 : 74.0
# 타깃 180에 대한 성공 값 : 53.0
# 타깃 181에 대한 성공 값 : 80.0
# 타깃 182에 대한 성공 값 : 75.0
# 타깃 183에 대한 성공 값 : 97.0
# 타깃 184에 대한 성공 값 : 75.0
# 타깃 185에 대한 성공 값 : 46.0
# 타깃 186에 대한 성공 값 : 69.0
# 타깃 187에 대한 성공 값 : 22.0
# 타깃 188에 대한 성공 값 : 40.0
# 타깃 189에 대한 성공 값 : 65.0
# 타깃 190에 대한 성공 값 : 95.0
# 타깃 191에 대한 성공 값 : 25.0
# 타깃 192에 대한 성공 값 : 79.0
# 타깃 193에 대한 성공 값 : 4.0
# 타깃 194에 대한 성공 값 : 23.0
# 타깃 195에 대한 성공 값 : 56.0
# 타깃 196에 대한 성공 값 : 24.0
# 타깃 197에 대한 성공 값 : 83.0
# 타깃 198에 대한 성공 값 : 74.0
# 타깃 199에 대한 성공 값 : 3.0
# 10100.00023746027

# %%
# 0이 아닌 원소의 인덱스 찾기
non_zero_indices = np.argwhere(theta_wt != 0)

# 인덱스 출력
for index in non_zero_indices:
    temp_w, temp_t, temp_m = tuple(index)
    print(f"x({temp_w},{temp_t})={theta_wt[temp_w][temp_t][temp_m]}")
# Out:
# x(0,37)=1
# x(1,95)=1
# x(2,19)=1
# x(3,87)=1
# x(4,43)=1
# x(5,55)=1
# x(6,71)=1
# x(7,58)=1
# x(8,92)=1
# x(9,66)=1
# x(10,47)=1
# x(11,99)=1
# x(12,27)=1
# x(13,62)=1
# x(14,79)=1
# x(15,4)=1
# x(16,78)=1
# x(17,96)=1
# x(18,0)=1
# x(19,73)=1
# x(20,49)=1
# x(21,63)=1
# x(22,17)=1
# x(23,69)=1
# x(24,51)=1
# x(25,91)=1
# x(26,1)=1
# x(27,48)=1
# x(28,23)=1
# x(29,38)=1
# x(30,42)=1
# x(31,20)=1
# x(32,21)=1
# x(33,10)=1
# x(34,9)=1
# x(35,54)=1
# x(36,46)=1
# x(37,72)=1
# x(38,50)=1
# x(39,98)=1
# x(40,29)=1
# x(41,3)=1
# x(42,84)=1
# x(43,35)=1
# x(44,56)=1
# x(45,26)=1
# x(46,60)=1
# x(47,70)=1
# x(48,65)=1
# x(49,81)=1

# %% [markdown]
# # for runtime

# %%
import numpy as np
import time

start_time = time.time()

path = "/ssd2/kawon/230727_WTA/data/wta_50x100x1.txt"

weight=[]



# reading data from text file
f = open(path, "r")
lines = f.readlines()
f.close()



# reading first line
W, T, x = [int(v) for v in lines[0].split()]
# asssuming all weapons have the same availability:
m_w = [x] * W

M = sum(m_w)

FN_T = [x] * T

# 0과 99 사이의 실수로 PK_wt 배열 초기화
PK_wt = np.zeros((W, T))


# reading target weights
for line in lines[1:T + 1]:
    weight.append(int(line))



# reading probabilities
for line in lines[T + 1:]:
    splitted = line.split()
    w, t, p = int(splitted[0]), int(splitted[1]), float(splitted[2])
    PK_wt[w][t] = p


# M을 W로 나누어 리스트에 적절히 분배
quotient, remainder = divmod(M, W)
m_w = [quotient] * W

# 나머지 값을 리스트의 앞부분에 추가
for i in range(remainder):
    m_w[i] += 1

import copy
# Initialize a 3D binary matrix of zeros
theta_wt = np.zeros((W, T, M), dtype=int)


# 발사대에 적재된 유도탄 수량 리스트 left_m_w로 복사
left_m_w = copy.copy(m_w)

left_FN_T = copy.copy(FN_T)

# 행렬의 원소들을 1차원 배열로 변환
flattened = PK_wt.flatten()

# 원소들을 내림차순으로 정렬
sorted_indices = np.argsort(flattened)[::-1]

i = 0
m = 0
indices_list = []

while True :
    if i == T * W :
        break
    # i번째 요격확률의 인덱스 v
    v = sorted_indices[i]
    
    row = v // T # Weapon
    col = v % T # Target
    print(f"Value: {flattened[v]}, Index: (Weapon : {row}, Target : {col})")
    
    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있다면,
    # 해당 Weapon의 적재된 유도탄이 남아 있다면,
    # if left_m_w[row] > 0:
    if left_FN_T[col] > 0 and left_m_w[row] > 0:
            
        
            
        # 할당할 유도탄 개수 감소
        left_FN_T[col] -= 1
        left_m_w[row] -= 1
        # 해당 W T M에 1 부여
        theta_wt[row][col][m] = 1
        # 무기가 할당된 indices_list에 추가
        indices_list.append(v)

        # 다음 미사일 인덱스로 이동
        m += 1

    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있지 않다면,
    elif left_FN_T[col] > 0:
        pass
        print(f"not enough Missile on Weapon {row}")
    
    else :
        pass
        # print(f"not enough Missile for Target {col}")
    
    # 할당할 수 있는 유도탄의 개수를 모두 소모했다면 종료.
    if sum(left_m_w) == 0:
        break
    

    # 다음으로 요격확률이 높은 인덱스로 이동
    i += 1

end_time = time.time()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Value: 0.999908333929, Index: (Weapon : 14, Target : 79)
# Value: 0.999768899001, Index: (Weapon : 9, Target : 66)
# Value: 0.999752754517, Index: (Weapon : 19, Target : 73)
# Value: 0.999703408776, Index: (Weapon : 10, Target : 47)
# Value: 0.999495375774, Index: (Weapon : 13, Target : 62)
# Value: 0.999113550816, Index: (Weapon : 43, Target : 66)
# Value: 0.999048291878, Index: (Weapon : 27, Target : 48)
# Value: 0.998907563007, Index: (Weapon : 19, Target : 14)
# not enough Missile on Weapon 19
# Value: 0.998892149437, Index: (Weapon : 12, Target : 27)
# Value: 0.998769585667, Index: (Weapon : 26, Target : 1)
# Value: 0.998462391648, Index: (Weapon : 25, Target : 91)
# Value: 0.998405988793, Index: (Weapon : 37, Target : 72)
# Value: 0.998320847532, Index: (Weapon : 32, Target : 48)
# Value: 0.998061066825, Index: (Weapon : 35, Target : 1)
# Value: 0.997906576074, Index: (Weapon : 26, Target : 63)
# not enough Missile on Weapon 26
# Value: 0.997067189233, Index: (Weapon : 9, Target : 33)
# not enough Missile on Weapon 9
# Value: 0.996459518707, Index: (Weapon : 17, Target : 96)
# Value: 0.9963816315, Index: (Weapon : 13, Target : 13)
# not enough Missile on Weapon 13
# Value: 0.996367981384, Index: (Weapon : 23, Target : 69)
# Value: 0.996278908191, Index: (Weapon : 39, Target : 98)
# Value: 0.995878636004, Index: (Weapon : 7, Target : 58)
# Value: 0.99560680254, Index: (Weapon : 12, Target : 5)
# not enough Missile on Weapon 12
# Value: 0.995563654195, Index: (Weapon : 25, Target : 74)
# not enough Missile on Weapon 25
# Value: 0.995052436015, Index: (Weapon : 1, Target : 95)
# Value: 0.994967095598, Index: (Weapon : 30, Target : 42)
# Value: 0.994608970803, Index: (Weapon : 34, Target : 9)
# Value: 0.994522042427, Index: (Weapon : 4, Target : 43)
# Value: 0.99404099033, Index: (Weapon : 1, Target : 1)
# Value: 0.99384135947, Index: (Weapon : 11, Target : 99)
# Value: 0.99364199311, Index: (Weapon : 10, Target : 54)
# not enough Missile on Weapon 10
# Value: 0.993554434953, Index: (Weapon : 31, Target : 20)
# Value: 0.993471523576, Index: (Weapon : 25, Target : 88)
# not enough Missile on Weapon 25
# Value: 0.993394005642, Index: (Weapon : 29, Target : 38)
# Value: 0.993234993858, Index: (Weapon : 41, Target : 3)
# Value: 0.992940377898, Index: (Weapon : 3, Target : 43)
# Value: 0.992359661891, Index: (Weapon : 44, Target : 56)
# Value: 0.991411417702, Index: (Weapon : 40, Target : 29)
# Value: 0.991391145833, Index: (Weapon : 0, Target : 37)
# Value: 0.991357032002, Index: (Weapon : 15, Target : 4)
# Value: 0.990640880887, Index: (Weapon : 43, Target : 35)
# Value: 0.990319924334, Index: (Weapon : 18, Target : 0)
# Value: 0.99031347734, Index: (Weapon : 43, Target : 26)
# not enough Missile on Weapon 43
# Value: 0.989874323583, Index: (Weapon : 4, Target : 86)
# not enough Missile on Weapon 4
# Value: 0.989768183467, Index: (Weapon : 17, Target : 86)
# not enough Missile on Weapon 17
# Value: 0.989612229873, Index: (Weapon : 24, Target : 51)
# Value: 0.989589193803, Index: (Weapon : 18, Target : 36)
# not enough Missile on Weapon 18
# Value: 0.989262382194, Index: (Weapon : 39, Target : 24)
# not enough Missile on Weapon 39
# Value: 0.989004777945, Index: (Weapon : 37, Target : 30)
# not enough Missile on Weapon 37
# Value: 0.988716771313, Index: (Weapon : 47, Target : 70)
# Value: 0.988644392048, Index: (Weapon : 37, Target : 7)
# not enough Missile on Weapon 37
# Value: 0.988528199615, Index: (Weapon : 38, Target : 62)
# Value: 0.988448148711, Index: (Weapon : 29, Target : 20)
# Value: 0.988299100413, Index: (Weapon : 19, Target : 29)
# Value: 0.98825578885, Index: (Weapon : 44, Target : 6)
# not enough Missile on Weapon 44
# Value: 0.987805614293, Index: (Weapon : 3, Target : 87)
# Value: 0.987725355585, Index: (Weapon : 27, Target : 49)
# not enough Missile on Weapon 27
# Value: 0.987367855763, Index: (Weapon : 18, Target : 53)
# not enough Missile on Weapon 18
# Value: 0.986795692682, Index: (Weapon : 48, Target : 51)
# Value: 0.986721476564, Index: (Weapon : 20, Target : 49)
# Value: 0.986371964079, Index: (Weapon : 17, Target : 34)
# not enough Missile on Weapon 17
# Value: 0.986245940886, Index: (Weapon : 39, Target : 89)
# not enough Missile on Weapon 39
# Value: 0.986076270945, Index: (Weapon : 34, Target : 38)
# Value: 0.986046438508, Index: (Weapon : 13, Target : 12)
# not enough Missile on Weapon 13
# Value: 0.986030705828, Index: (Weapon : 45, Target : 26)
# Value: 0.985891952677, Index: (Weapon : 39, Target : 76)
# not enough Missile on Weapon 39
# Value: 0.985853798338, Index: (Weapon : 42, Target : 58)
# Value: 0.985774536641, Index: (Weapon : 15, Target : 46)
# not enough Missile on Weapon 15
# Value: 0.985633352964, Index: (Weapon : 6, Target : 1)
# Value: 0.985537367932, Index: (Weapon : 15, Target : 20)
# Value: 0.985451124436, Index: (Weapon : 21, Target : 63)
# Value: 0.985279910825, Index: (Weapon : 29, Target : 72)
# Value: 0.985276934267, Index: (Weapon : 40, Target : 5)
# not enough Missile on Weapon 40
# Value: 0.985261857981, Index: (Weapon : 30, Target : 20)
# Value: 0.98501139153, Index: (Weapon : 33, Target : 3)
# Value: 0.984892023428, Index: (Weapon : 20, Target : 40)
# not enough Missile on Weapon 20
# Value: 0.98482342521, Index: (Weapon : 27, Target : 39)
# not enough Missile on Weapon 27
# Value: 0.984807104075, Index: (Weapon : 42, Target : 84)
# Value: 0.98450336463, Index: (Weapon : 35, Target : 63)
# Value: 0.984243229401, Index: (Weapon : 42, Target : 70)
# Value: 0.983788465476, Index: (Weapon : 12, Target : 68)
# not enough Missile on Weapon 12
# Value: 0.98371948975, Index: (Weapon : 42, Target : 75)
# not enough Missile on Weapon 42
# Value: 0.983481454517, Index: (Weapon : 24, Target : 71)
# not enough Missile on Weapon 24
# Value: 0.983395750291, Index: (Weapon : 21, Target : 91)
# Value: 0.983271561627, Index: (Weapon : 37, Target : 73)
# Value: 0.982989257322, Index: (Weapon : 40, Target : 14)
# not enough Missile on Weapon 40
# Value: 0.981906036277, Index: (Weapon : 9, Target : 9)
# Value: 0.981831606221, Index: (Weapon : 2, Target : 19)
# Value: 0.98170584597, Index: (Weapon : 0, Target : 29)
# Value: 0.981371020179, Index: (Weapon : 21, Target : 14)
# not enough Missile on Weapon 21
# Value: 0.981204641644, Index: (Weapon : 25, Target : 93)
# not enough Missile on Weapon 25
# Value: 0.980866016832, Index: (Weapon : 38, Target : 56)
# Value: 0.980636944283, Index: (Weapon : 40, Target : 98)
# Value: 0.980269472609, Index: (Weapon : 12, Target : 65)
# not enough Missile on Weapon 12
# Value: 0.980121003334, Index: (Weapon : 20, Target : 47)
# Value: 0.98003358687, Index: (Weapon : 12, Target : 71)
# not enough Missile on Weapon 12
# Value: 0.979827136615, Index: (Weapon : 48, Target : 19)
# Value: 0.979650482127, Index: (Weapon : 17, Target : 27)
# Value: 0.97917734586, Index: (Weapon : 26, Target : 64)
# not enough Missile on Weapon 26
# Value: 0.979060734559, Index: (Weapon : 14, Target : 85)
# not enough Missile on Weapon 14
# Value: 0.978659497451, Index: (Weapon : 40, Target : 73)
# Value: 0.978462928159, Index: (Weapon : 6, Target : 96)
# Value: 0.978349882456, Index: (Weapon : 11, Target : 46)
# not enough Missile on Weapon 11
# Value: 0.978015850343, Index: (Weapon : 5, Target : 38)
# Value: 0.977998019002, Index: (Weapon : 26, Target : 58)
# Value: 0.977667986861, Index: (Weapon : 1, Target : 37)
# Value: 0.977127469564, Index: (Weapon : 13, Target : 45)
# not enough Missile on Weapon 13
# Value: 0.977017459465, Index: (Weapon : 7, Target : 29)
# Value: 0.976873013334, Index: (Weapon : 13, Target : 98)
# Value: 0.976811925426, Index: (Weapon : 7, Target : 95)
# Value: 0.976519633965, Index: (Weapon : 30, Target : 21)
# not enough Missile on Weapon 30
# Value: 0.976258117671, Index: (Weapon : 9, Target : 51)
# Value: 0.97624779483, Index: (Weapon : 8, Target : 92)
# Value: 0.976113466546, Index: (Weapon : 28, Target : 23)
# Value: 0.976113108781, Index: (Weapon : 35, Target : 54)
# Value: 0.975882398731, Index: (Weapon : 47, Target : 95)
# Value: 0.975710106713, Index: (Weapon : 24, Target : 80)
# not enough Missile on Weapon 24
# Value: 0.975684330199, Index: (Weapon : 4, Target : 19)
# Value: 0.975277075544, Index: (Weapon : 45, Target : 60)
# not enough Missile on Weapon 45
# Value: 0.975110512218, Index: (Weapon : 33, Target : 87)
# Value: 0.974954305991, Index: (Weapon : 45, Target : 13)
# not enough Missile on Weapon 45
# Value: 0.974504481901, Index: (Weapon : 0, Target : 31)
# not enough Missile on Weapon 0
# Value: 0.974460820814, Index: (Weapon : 35, Target : 50)
# not enough Missile on Weapon 35
# Value: 0.97420381711, Index: (Weapon : 19, Target : 40)
# not enough Missile on Weapon 19
# Value: 0.973509127639, Index: (Weapon : 18, Target : 57)
# not enough Missile on Weapon 18
# Value: 0.97330124839, Index: (Weapon : 22, Target : 17)
# Value: 0.972998858277, Index: (Weapon : 32, Target : 51)
# Value: 0.972873105528, Index: (Weapon : 31, Target : 9)
# Value: 0.972854662083, Index: (Weapon : 17, Target : 68)
# not enough Missile on Weapon 17
# Value: 0.972736481159, Index: (Weapon : 16, Target : 78)
# Value: 0.971508884077, Index: (Weapon : 38, Target : 50)
# Value: 0.971492369464, Index: (Weapon : 44, Target : 28)
# not enough Missile on Weapon 44
# Value: 0.971379420398, Index: (Weapon : 12, Target : 33)
# not enough Missile on Weapon 12
# Value: 0.971121756033, Index: (Weapon : 5, Target : 17)
# Value: 0.971073327503, Index: (Weapon : 6, Target : 72)
# Value: 0.970968610548, Index: (Weapon : 31, Target : 28)
# not enough Missile on Weapon 31
# Value: 0.970569733759, Index: (Weapon : 25, Target : 27)
# Value: 0.970462051466, Index: (Weapon : 47, Target : 48)
# Value: 0.970261349054, Index: (Weapon : 15, Target : 86)
# not enough Missile on Weapon 15
# Value: 0.970173505734, Index: (Weapon : 6, Target : 71)
# Value: 0.969952344198, Index: (Weapon : 47, Target : 21)
# not enough Missile on Weapon 47
# Value: 0.969531340613, Index: (Weapon : 45, Target : 6)
# not enough Missile on Weapon 45
# Value: 0.969315515876, Index: (Weapon : 20, Target : 89)
# not enough Missile on Weapon 20
# Value: 0.969230222401, Index: (Weapon : 11, Target : 48)
# Value: 0.969228398744, Index: (Weapon : 8, Target : 29)
# Value: 0.96911882986, Index: (Weapon : 40, Target : 53)
# not enough Missile on Weapon 40
# Value: 0.969077569773, Index: (Weapon : 15, Target : 37)
# Value: 0.968858989133, Index: (Weapon : 2, Target : 65)
# not enough Missile on Weapon 2
# Value: 0.96862902621, Index: (Weapon : 44, Target : 2)
# not enough Missile on Weapon 44
# Value: 0.968561329076, Index: (Weapon : 46, Target : 60)
# Value: 0.968408667357, Index: (Weapon : 23, Target : 53)
# not enough Missile on Weapon 23
# Value: 0.968070164704, Index: (Weapon : 17, Target : 37)
# Value: 0.967286892092, Index: (Weapon : 23, Target : 52)
# not enough Missile on Weapon 23
# Value: 0.967042094765, Index: (Weapon : 7, Target : 7)
# not enough Missile on Weapon 7
# Value: 0.967019535791, Index: (Weapon : 5, Target : 55)
# Value: 0.966806389861, Index: (Weapon : 32, Target : 21)
# Value: 0.966717881611, Index: (Weapon : 8, Target : 35)
# Value: 0.966625849126, Index: (Weapon : 33, Target : 10)
# Value: 0.966196896548, Index: (Weapon : 4, Target : 10)
# Value: 0.966155842227, Index: (Weapon : 8, Target : 14)
# not enough Missile on Weapon 8
# Value: 0.965868850875, Index: (Weapon : 43, Target : 48)
# Value: 0.965793184634, Index: (Weapon : 49, Target : 81)
# Value: 0.965756406003, Index: (Weapon : 13, Target : 47)
# Value: 0.96556559424, Index: (Weapon : 21, Target : 10)
# Value: 0.965515341791, Index: (Weapon : 46, Target : 56)
# Value: 0.965388758861, Index: (Weapon : 15, Target : 18)
# not enough Missile on Weapon 15
# Value: 0.965207310077, Index: (Weapon : 42, Target : 13)
# not enough Missile on Weapon 42
# Value: 0.964913572022, Index: (Weapon : 44, Target : 14)
# not enough Missile on Weapon 44
# Value: 0.964912405344, Index: (Weapon : 36, Target : 46)
# Value: 0.964728500026, Index: (Weapon : 28, Target : 99)
# Value: 0.964727069826, Index: (Weapon : 27, Target : 32)
# not enough Missile on Weapon 27
# Value: 0.96467133061, Index: (Weapon : 21, Target : 4)
# Value: 0.963323985719, Index: (Weapon : 24, Target : 91)
# Value: 0.963183966252, Index: (Weapon : 2, Target : 41)
# not enough Missile on Weapon 2
# Value: 0.963018128871, Index: (Weapon : 15, Target : 33)
# not enough Missile on Weapon 15
# Value: 0.962988911296, Index: (Weapon : 33, Target : 9)
# Value: 0.962953777668, Index: (Weapon : 4, Target : 68)
# not enough Missile on Weapon 4
# Value: 0.962352064973, Index: (Weapon : 11, Target : 5)
# not enough Missile on Weapon 11
# Value: 0.962125860647, Index: (Weapon : 49, Target : 80)
# not enough Missile on Weapon 49
# Value: 0.961999035988, Index: (Weapon : 19, Target : 0)
# Value: 0.961943235882, Index: (Weapon : 40, Target : 2)
# not enough Missile on Weapon 40
# Value: 0.961847200773, Index: (Weapon : 21, Target : 67)
# not enough Missile on Weapon 21
# Value: 0.961820488462, Index: (Weapon : 45, Target : 19)
# Value: 0.961736809418, Index: (Weapon : 34, Target : 46)
# Value: 0.961673320314, Index: (Weapon : 19, Target : 83)
# not enough Missile on Weapon 19
# Value: 0.961192006307, Index: (Weapon : 16, Target : 63)
# Value: 0.960769712779, Index: (Weapon : 43, Target : 74)
# not enough Missile on Weapon 43
# Value: 0.96068239984, Index: (Weapon : 27, Target : 15)
# not enough Missile on Weapon 27
# Value: 0.960626285567, Index: (Weapon : 3, Target : 80)
# not enough Missile on Weapon 3
# Value: 0.959988507408, Index: (Weapon : 28, Target : 85)
# not enough Missile on Weapon 28
# Value: 0.959909910909, Index: (Weapon : 21, Target : 33)
# not enough Missile on Weapon 21
# Value: 0.959641398786, Index: (Weapon : 25, Target : 56)
# Value: 0.959632174609, Index: (Weapon : 41, Target : 53)
# not enough Missile on Weapon 41
# Value: 0.959415010144, Index: (Weapon : 0, Target : 74)
# not enough Missile on Weapon 0
# Value: 0.95933117407, Index: (Weapon : 22, Target : 76)
# not enough Missile on Weapon 22
# Value: 0.959310571404, Index: (Weapon : 3, Target : 1)
# Value: 0.958240061462, Index: (Weapon : 24, Target : 61)
# not enough Missile on Weapon 24
# Value: 0.958013039083, Index: (Weapon : 36, Target : 44)
# not enough Missile on Weapon 36
# Value: 0.95743374533, Index: (Weapon : 8, Target : 65)
# not enough Missile on Weapon 8
# Value: 0.957033688507, Index: (Weapon : 0, Target : 92)
# Value: 0.956819975225, Index: (Weapon : 22, Target : 57)
# not enough Missile on Weapon 22
# Value: 0.956265628122, Index: (Weapon : 1, Target : 12)
# not enough Missile on Weapon 1
# Value: 0.956151529036, Index: (Weapon : 0, Target : 9)
# Value: 0.956089421296, Index: (Weapon : 17, Target : 0)
# Value: 0.956041577111, Index: (Weapon : 46, Target : 8)
# not enough Missile on Weapon 46
# Value: 0.95603674542, Index: (Weapon : 13, Target : 42)
# Value: 0.955914783468, Index: (Weapon : 41, Target : 9)
# Value: 0.955846978195, Index: (Weapon : 7, Target : 65)
# not enough Missile on Weapon 7
# Value: 0.955365535162, Index: (Weapon : 1, Target : 5)
# not enough Missile on Weapon 1
# Value: 0.955194640656, Index: (Weapon : 8, Target : 90)
# not enough Missile on Weapon 8
# Value: 0.954873465041, Index: (Weapon : 26, Target : 35)
# Value: 0.954369777309, Index: (Weapon : 33, Target : 58)
# Value: 0.954051123094, Index: (Weapon : 25, Target : 76)
# not enough Missile on Weapon 25
# Value: 0.953788137045, Index: (Weapon : 18, Target : 18)
# not enough Missile on Weapon 18
# Value: 0.953635263815, Index: (Weapon : 14, Target : 56)
# Value: 0.953517513194, Index: (Weapon : 25, Target : 78)
# Value: 0.953493320134, Index: (Weapon : 38, Target : 8)
# not enough Missile on Weapon 38
# Value: 0.953263325363, Index: (Weapon : 3, Target : 71)
# Value: 0.953139535646, Index: (Weapon : 23, Target : 28)
# not enough Missile on Weapon 23
# Value: 0.953078955674, Index: (Weapon : 47, Target : 8)
# not enough Missile on Weapon 47
# Value: 0.952819005165, Index: (Weapon : 4, Target : 81)
# Value: 0.952582753901, Index: (Weapon : 12, Target : 88)
# not enough Missile on Weapon 12
# Value: 0.952456481258, Index: (Weapon : 2, Target : 14)
# not enough Missile on Weapon 2
# Value: 0.952270158042, Index: (Weapon : 4, Target : 64)
# not enough Missile on Weapon 4
# Value: 0.952006599195, Index: (Weapon : 12, Target : 25)
# not enough Missile on Weapon 12
# Value: 0.951902710884, Index: (Weapon : 39, Target : 2)
# not enough Missile on Weapon 39
# Value: 0.951803386518, Index: (Weapon : 39, Target : 41)
# not enough Missile on Weapon 39
# Value: 0.951270237537, Index: (Weapon : 38, Target : 65)
# not enough Missile on Weapon 38
# Value: 0.951205523493, Index: (Weapon : 17, Target : 22)
# not enough Missile on Weapon 17
# Value: 0.95112794379, Index: (Weapon : 22, Target : 52)
# not enough Missile on Weapon 22
# Value: 0.951106494961, Index: (Weapon : 7, Target : 64)
# not enough Missile on Weapon 7
# Value: 0.950997441314, Index: (Weapon : 12, Target : 20)
# Value: 0.950773860416, Index: (Weapon : 42, Target : 56)
# Value: 0.950646233065, Index: (Weapon : 28, Target : 38)
# Value: 0.950411562661, Index: (Weapon : 22, Target : 82)
# not enough Missile on Weapon 22
# Value: 0.950036973264, Index: (Weapon : 33, Target : 88)
# not enough Missile on Weapon 33
# Value: 0.949771143469, Index: (Weapon : 22, Target : 85)
# not enough Missile on Weapon 22
# Value: 0.949664879744, Index: (Weapon : 13, Target : 74)
# not enough Missile on Weapon 13
# Value: 0.94963147058, Index: (Weapon : 18, Target : 4)
# Value: 0.94919420553, Index: (Weapon : 20, Target : 1)
# Value: 0.94910421003, Index: (Weapon : 45, Target : 38)
# Value: 0.948634296472, Index: (Weapon : 10, Target : 63)
# Value: 0.947760658664, Index: (Weapon : 49, Target : 43)
# Value: 0.947646233824, Index: (Weapon : 37, Target : 25)
# not enough Missile on Weapon 37
# Value: 0.947505584422, Index: (Weapon : 37, Target : 82)
# not enough Missile on Weapon 37
# Value: 0.947450940704, Index: (Weapon : 18, Target : 86)
# not enough Missile on Weapon 18
# Value: 0.947413899389, Index: (Weapon : 17, Target : 77)
# not enough Missile on Weapon 17
# Value: 0.947351779283, Index: (Weapon : 32, Target : 37)
# Value: 0.947298372434, Index: (Weapon : 1, Target : 29)
# Value: 0.947227620763, Index: (Weapon : 11, Target : 14)
# not enough Missile on Weapon 11
# Value: 0.947131968346, Index: (Weapon : 27, Target : 83)
# not enough Missile on Weapon 27
# Value: 0.946916566174, Index: (Weapon : 22, Target : 94)
# not enough Missile on Weapon 22
# Value: 0.946652254586, Index: (Weapon : 2, Target : 74)
# not enough Missile on Weapon 2
# Value: 0.946516894804, Index: (Weapon : 47, Target : 85)
# not enough Missile on Weapon 47
# Value: 0.946039875402, Index: (Weapon : 19, Target : 27)
# Value: 0.946003365949, Index: (Weapon : 20, Target : 20)
# Value: 0.945940971832, Index: (Weapon : 1, Target : 36)
# not enough Missile on Weapon 1
# Value: 0.94589272612, Index: (Weapon : 3, Target : 39)
# not enough Missile on Weapon 3
# Value: 0.945777023799, Index: (Weapon : 2, Target : 50)
# Value: 0.945584052516, Index: (Weapon : 42, Target : 8)
# not enough Missile on Weapon 42
# Value: 0.94551669543, Index: (Weapon : 35, Target : 78)
# Value: 0.945469332024, Index: (Weapon : 17, Target : 75)
# not enough Missile on Weapon 17
# Value: 0.945079389203, Index: (Weapon : 40, Target : 49)
# Value: 0.9448035397, Index: (Weapon : 11, Target : 87)
# Value: 0.944704083925, Index: (Weapon : 29, Target : 74)
# not enough Missile on Weapon 29
# Value: 0.944560777214, Index: (Weapon : 36, Target : 49)
# Value: 0.944559064316, Index: (Weapon : 13, Target : 37)
# Value: 0.944535645278, Index: (Weapon : 19, Target : 3)
# Value: 0.94449868678, Index: (Weapon : 22, Target : 8)
# not enough Missile on Weapon 22
# Value: 0.9439488693, Index: (Weapon : 34, Target : 62)
# Value: 0.943708579031, Index: (Weapon : 20, Target : 82)
# not enough Missile on Weapon 20
# Value: 0.943396764555, Index: (Weapon : 27, Target : 81)
# Value: 0.943161578477, Index: (Weapon : 23, Target : 38)
# Value: 0.942859895098, Index: (Weapon : 34, Target : 94)
# not enough Missile on Weapon 34
# Value: 0.942114208629, Index: (Weapon : 41, Target : 26)
# Value: 0.941955671064, Index: (Weapon : 30, Target : 51)
# Value: 0.941448649507, Index: (Weapon : 33, Target : 34)
# not enough Missile on Weapon 33
# Value: 0.94102937612, Index: (Weapon : 48, Target : 65)
# Elapsed time: 0.04971456527709961 seconds

# %%
objective_fun_1(theta_wt,weight)
# Out:
# 타깃 0에 대한 성공 값 : 0.12584098365800056
# 타깃 1에 대한 성공 값 : 0.07382485997999844
# 타깃 2에 대한 성공 값 : 71.0
# 타깃 3에 대한 성공 값 : 0.6291455712060038
# 타깃 4에 대한 성공 값 : 0.1555734239640003
# 타깃 5에 대한 성공 값 : 46.0
# 타깃 6에 대한 성공 값 : 82.0
# 타깃 7에 대한 성공 값 : 82.0
# 타깃 8에 대한 성공 값 : 43.0
# 타깃 9에 대한 성공 값 : 0.010782058393999927
# 타깃 10에 대한 성공 값 : 2.6365579190459982
# 타깃 11에 대한 성공 값 : 60.0
# 타깃 12에 대한 성공 값 : 19.0
# 타깃 13에 대한 성공 값 : 91.0
# 타깃 14에 대한 성공 값 : 66.0
# 타깃 15에 대한 성공 값 : 23.0
# 타깃 16에 대한 성공 값 : 95.0
# 타깃 17에 대한 성공 값 : 2.029105122360001
# 타깃 18에 대한 성공 값 : 56.0
# 타깃 19에 대한 성공 값 : 1.017430051624002
# 타깃 20에 대한 성공 값 : 0.31583268730300007
# 타깃 21에 대한 성공 값 : 3.1201993530660017
# 타깃 22에 대한 성공 값 : 28.0
# 타깃 23에 대한 성공 값 : 2.2692206781300044
# 타깃 24에 대한 성공 값 : 64.0
# 타깃 25에 대한 성공 값 : 91.0
# 타깃 26에 대한 성공 값 : 0.4889252960199997
# 타깃 27에 대한 성공 값 : 0.06536318321700008
# 타깃 28에 대한 성공 값 : 61.0
# 타깃 29에 대한 성공 값 : 0.42942911489999847
# 타깃 30에 대한 성공 값 : 42.0
# 타깃 31에 대한 성공 값 : 30.0
# 타깃 32에 대한 성공 값 : 60.0
# 타깃 33에 대한 성공 값 : 96.0
# 타깃 34에 대한 성공 값 : 85.0
# 타깃 35에 대한 성공 값 : 0.8329616010570022
# 타깃 36에 대한 성공 값 : 33.0
# 타깃 37에 대한 성공 값 : 0.7747968750299972
# 타깃 38에 대한 성공 값 : 0.11230190408600038
# 타깃 39에 대한 성공 값 : 10.0
# 타깃 40에 대한 성공 값 : 44.0
# 타깃 41에 대한 성공 값 : 95.0
# 타깃 42에 대한 성공 값 : 0.4831588225919994
# 타깃 43에 대한 성공 값 : 0.1972064726279985
# 타깃 44에 대한 성공 값 : 92.0
# 타깃 45에 대한 성공 값 : 46.0
# 타깃 46에 대한 성공 값 : 2.1052556793599986
# 타깃 47에 대한 성공 값 : 0.01631251732000294
# 타깃 48에 대한 성공 값 : 0.0761366497599969
# 타깃 49에 대한 성공 값 : 0.411634226516
# 타깃 50에 대한 성공 값 : 1.1681357528430008
# 타깃 51에 대한 성공 값 : 0.44667411546099933
# 타깃 52에 대한 성공 값 : 58.0
# 타깃 53에 대한 성공 값 : 91.0
# 타깃 54에 대한 성공 값 : 2.1020464272720005
# 타깃 55에 대한 성공 값 : 1.4511404251960012
# 타깃 56에 대한 성공 값 : 0.106964733526
# 타깃 57에 대한 성공 값 : 93.0
# 타깃 58에 대한 성공 값 : 0.09479137190800113
# 타깃 59에 대한 성공 값 : 57.0
# 타깃 60에 대한 성공 값 : 1.5404948752759995
# 타깃 61에 대한 성공 값 : 69.0
# 타깃 62에 대한 성공 값 : 0.020689593265997952
# 타깃 63에 대한 성공 값 : 0.21823313345999962
# 타깃 64에 대한 성공 값 : 84.0
# 타깃 65에 대한 성공 값 : 0.9435299820799994
# 타깃 66에 대한 성공 값 : 0.003697615984000535
# 타깃 67에 대한 성공 값 : 69.0
# 타깃 68에 대한 성공 값 : 49.0
# 타깃 69에 대한 성공 값 : 0.3159856195920038
# 타깃 70에 대한 성공 값 : 0.6769937212200028
# 타깃 71에 대한 성공 값 : 0.6860093681180008
# 타깃 72에 대한 성공 값 : 0.1291149077669983
# 타깃 73에 대한 성공 값 : 0.015576465429002262
# 타깃 74에 대한 성공 값 : 28.0
# 타깃 75에 대한 성공 값 : 79.0
# 타깃 76에 대한 성공 값 : 73.0
# 타깃 77에 대한 성공 값 : 30.0
# 타깃 78에 대한 성공 값 : 0.5452703768199996
# 타깃 79에 대한 성공 값 : 0.006324958898998201
# 타깃 80에 대한 성공 값 : 57.0
# 타깃 81에 대한 성공 값 : 2.0524089219600006
# 타깃 82에 대한 성공 값 : 1.0
# 타깃 83에 대한 성공 값 : 21.0
# 타깃 84에 대한 성공 값 : 0.6229087329249979
# 타깃 85에 대한 성공 값 : 98.0
# 타깃 86에 대한 성공 값 : 77.0
# 타깃 87에 대한 성공 값 : 0.8536069994900031
# 타깃 88에 대한 성공 값 : 54.0
# 타깃 89에 대한 성공 값 : 19.0
# 타깃 90에 대한 성공 값 : 46.0
# 타깃 91에 대한 성공 값 : 0.03382738374400018
# 타깃 92에 대한 성공 값 : 0.9975926171399994
# 타깃 93에 대한 성공 값 : 58.0
# 타깃 94에 대한 성공 값 : 35.0
# 타깃 95에 대한 성공 값 : 0.4898088345149959
# 타깃 96에 대한 성공 값 : 0.23013128404499983
# 타깃 97에 대한 성공 값 : 26.0
# 타깃 98에 대한 성공 값 : 0.3200138955740037
# 타깃 99에 대한 성공 값 : 0.166283294310001
# 2917.6152504590364

# %% [markdown]
# Target : 0, res: 0.00
#
# Elapsed time: 0.0113525390625 seconds
#
# Target : 100, res: 94.64
#
# Elapsed time: 6.394922733306885 seconds
#
# Target : 200, res: 193.84
#
# Elapsed time: 23.664151906967163 seconds
#
# Target : 300, res: 292.16
#
# Elapsed time: 52.60361385345459 seconds
#
# Target : 400, res: 390.56
#
# Elapsed time: 93.8756833076477 seconds
#
# Target : 500, res: 489.18
#
# Elapsed time: 147.16718006134033 seconds
#
# Target : 600, res: 588.93
#
# Elapsed time: 210.77380347251892 seconds
#
# Target : 700, res: 688.24
#
# Elapsed time: 286.8595986366272 seconds
#
# Target : 800, res: 786.17
#
# Elapsed time: 374.906601190567 seconds
#
# Target : 900, res: 884.81
#
# Elapsed time: 475.8631122112274 seconds
#
# Target : 1000, res: 984.37
#
# Elapsed time: 587.348771572113 seconds
#
# Target : 1100, res: 1084.19
#
# Elapsed time: 737.4572696685791 seconds
#
# Target : 1200, res: 1182.09
#
# Elapsed time: 843.8965196609497 seconds
#
# Target : 1300, res: 1280.86
#
# Elapsed time: 994.9845380783081 seconds
#
# Target : 1400, res: 1379.28
#
# Elapsed time: 1156.028076171875 seconds
#
# Target : 1500, res: 1478.83
#
# Elapsed time: 1324.567284822464 seconds
#
# **WEAPON 1000, TARGET (0:1600:100) 결과 (SEED(1))**

# %%
import numpy as np

# reading first line
W, T, mu = [int(v) for v in lines[0].split()]
# asssuming all weapons have the same availability:
FN_T = [mu] * T

w = []

M = mu * T

PK_wt = np.zeros((W, T), dtype=float)

# reading target weights
for line in lines[1:T + 1]:
    w.append(int(line))



# reading probabilities
for line in (lines[T + 1:]):
    splitted = line.split()
    i, j, p = int(splitted[0]), int(splitted[1]), float(splitted[2])
    PK_wt[i][j] = p

# %%
# M을 W로 나누어 리스트에 적절히 분배
quotient, remainder = divmod(M, W)
m_w = [quotient] * W

# 나머지 값을 리스트의 앞부분에 추가
for i in range(remainder):
    m_w[i] += 1

import copy
# Initialize a 3D binary matrix of zeros
theta_wt = np.zeros((W, T, M), dtype=int)

# 미사일이 소모되는 리스트 left_FN_T으로 복사
left_FN_T = copy.copy(FN_T)

# 발사대에 적재된 유도탄 수량 리스트 left_m_w로 복사
left_m_w = copy.copy(m_w)

# 행렬의 원소들을 1차원 배열로 변환
flattened = PK_wt.flatten()

# 원소들을 내림차순으로 정렬
sorted_indices = np.argsort(flattened)[::-1]


i = 0
m = 0
indices_list = []
while True :
    if i == T * W :
        break
    # i번째 요격확률의 인덱스 v
    v = sorted_indices[i]
    
    row = v // T # Weapon
    col = v % T # Target
    print(f"Value: {flattened[v]}, Index: (Weapon : {row}, Target : {col})")
    
    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있다면,
    # 해당 Weapon의 적재된 유도탄이 남아 있다면,
    if left_FN_T[col] > 0 and left_m_w[row] > 0:
        
        

            
        
             
        # 할당할 유도탄 개수 감소
        left_FN_T[col] -= 1
        left_m_w[row] -= 1
        # 해당 W T M에 1 부여
        theta_wt[row][col][m] = 1
        # 무기가 할당된 indices_list에 추가
        indices_list.append(v)

        # 다음 미사일 인덱스로 이동
        m += 1

    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있지 않다면,
    elif left_FN_T[col] > 0:
        print(f"not enough Missile on Weapon {row}")
    
    else :
        print(f"not enough Missile for Target {col}")
    
    # 할당할 수 있는 유도탄의 개수를 모두 소모했다면 종료.
    if sum(left_FN_T) == 0:
        break
    

    # 다음으로 요격확률이 높은 인덱스로 이동
    i += 1
# Out:
# Value: 0.999908333929, Index: (Weapon : 14, Target : 79)
# Value: 0.999768899001, Index: (Weapon : 9, Target : 66)
# Value: 0.999752754517, Index: (Weapon : 19, Target : 73)
# Value: 0.999703408776, Index: (Weapon : 10, Target : 47)
# Value: 0.999495375774, Index: (Weapon : 13, Target : 62)
# Value: 0.999113550816, Index: (Weapon : 43, Target : 66)
# not enough Missile for Target 66
# Value: 0.999048291878, Index: (Weapon : 27, Target : 48)
# Value: 0.998907563007, Index: (Weapon : 19, Target : 14)
# Value: 0.998892149437, Index: (Weapon : 12, Target : 27)
# Value: 0.998769585667, Index: (Weapon : 26, Target : 1)
# Value: 0.998462391648, Index: (Weapon : 25, Target : 91)
# Value: 0.998405988793, Index: (Weapon : 37, Target : 72)
# Value: 0.998320847532, Index: (Weapon : 32, Target : 48)
# not enough Missile for Target 48
# Value: 0.998061066825, Index: (Weapon : 35, Target : 1)
# not enough Missile for Target 1
# Value: 0.997906576074, Index: (Weapon : 26, Target : 63)
# Value: 0.997067189233, Index: (Weapon : 9, Target : 33)
# Value: 0.996459518707, Index: (Weapon : 17, Target : 96)
# Value: 0.9963816315, Index: (Weapon : 13, Target : 13)
# Value: 0.996367981384, Index: (Weapon : 23, Target : 69)
# Value: 0.996278908191, Index: (Weapon : 39, Target : 98)
# Value: 0.995878636004, Index: (Weapon : 7, Target : 58)
# Value: 0.99560680254, Index: (Weapon : 12, Target : 5)
# Value: 0.995563654195, Index: (Weapon : 25, Target : 74)
# Value: 0.995052436015, Index: (Weapon : 1, Target : 95)
# Value: 0.994967095598, Index: (Weapon : 30, Target : 42)
# Value: 0.994608970803, Index: (Weapon : 34, Target : 9)
# Value: 0.994522042427, Index: (Weapon : 4, Target : 43)
# Value: 0.99404099033, Index: (Weapon : 1, Target : 1)
# not enough Missile for Target 1
# Value: 0.99384135947, Index: (Weapon : 11, Target : 99)
# Value: 0.99364199311, Index: (Weapon : 10, Target : 54)
# Value: 0.993554434953, Index: (Weapon : 31, Target : 20)
# Value: 0.993471523576, Index: (Weapon : 25, Target : 88)
# not enough Missile on Weapon 25
# Value: 0.993394005642, Index: (Weapon : 29, Target : 38)
# Value: 0.993234993858, Index: (Weapon : 41, Target : 3)
# Value: 0.992940377898, Index: (Weapon : 3, Target : 43)
# not enough Missile for Target 43
# Value: 0.992359661891, Index: (Weapon : 44, Target : 56)
# Value: 0.991411417702, Index: (Weapon : 40, Target : 29)
# Value: 0.991391145833, Index: (Weapon : 0, Target : 37)
# Value: 0.991357032002, Index: (Weapon : 15, Target : 4)
# Value: 0.990640880887, Index: (Weapon : 43, Target : 35)
# Value: 0.990319924334, Index: (Weapon : 18, Target : 0)
# Value: 0.99031347734, Index: (Weapon : 43, Target : 26)
# Value: 0.989874323583, Index: (Weapon : 4, Target : 86)
# Value: 0.989768183467, Index: (Weapon : 17, Target : 86)
# not enough Missile for Target 86
# Value: 0.989612229873, Index: (Weapon : 24, Target : 51)
# Value: 0.989589193803, Index: (Weapon : 18, Target : 36)
# Value: 0.989262382194, Index: (Weapon : 39, Target : 24)
# Value: 0.989004777945, Index: (Weapon : 37, Target : 30)
# Value: 0.988716771313, Index: (Weapon : 47, Target : 70)
# Value: 0.988644392048, Index: (Weapon : 37, Target : 7)
# not enough Missile on Weapon 37
# Value: 0.988528199615, Index: (Weapon : 38, Target : 62)
# not enough Missile for Target 62
# Value: 0.988448148711, Index: (Weapon : 29, Target : 20)
# not enough Missile for Target 20
# Value: 0.988299100413, Index: (Weapon : 19, Target : 29)
# not enough Missile for Target 29
# Value: 0.98825578885, Index: (Weapon : 44, Target : 6)
# Value: 0.987805614293, Index: (Weapon : 3, Target : 87)
# Value: 0.987725355585, Index: (Weapon : 27, Target : 49)
# Value: 0.987367855763, Index: (Weapon : 18, Target : 53)
# not enough Missile on Weapon 18
# Value: 0.986795692682, Index: (Weapon : 48, Target : 51)
# not enough Missile for Target 51
# Value: 0.986721476564, Index: (Weapon : 20, Target : 49)
# not enough Missile for Target 49
# Value: 0.986371964079, Index: (Weapon : 17, Target : 34)
# Value: 0.986245940886, Index: (Weapon : 39, Target : 89)
# not enough Missile on Weapon 39
# Value: 0.986076270945, Index: (Weapon : 34, Target : 38)
# not enough Missile for Target 38
# Value: 0.986046438508, Index: (Weapon : 13, Target : 12)
# not enough Missile on Weapon 13
# Value: 0.986030705828, Index: (Weapon : 45, Target : 26)
# not enough Missile for Target 26
# Value: 0.985891952677, Index: (Weapon : 39, Target : 76)
# not enough Missile on Weapon 39
# Value: 0.985853798338, Index: (Weapon : 42, Target : 58)
# not enough Missile for Target 58
# Value: 0.985774536641, Index: (Weapon : 15, Target : 46)
# Value: 0.985633352964, Index: (Weapon : 6, Target : 1)
# not enough Missile for Target 1
# Value: 0.985537367932, Index: (Weapon : 15, Target : 20)
# not enough Missile for Target 20
# Value: 0.985451124436, Index: (Weapon : 21, Target : 63)
# not enough Missile for Target 63
# Value: 0.985279910825, Index: (Weapon : 29, Target : 72)
# not enough Missile for Target 72
# Value: 0.985276934267, Index: (Weapon : 40, Target : 5)
# not enough Missile for Target 5
# Value: 0.985261857981, Index: (Weapon : 30, Target : 20)
# not enough Missile for Target 20
# Value: 0.98501139153, Index: (Weapon : 33, Target : 3)
# not enough Missile for Target 3
# Value: 0.984892023428, Index: (Weapon : 20, Target : 40)
# Value: 0.98482342521, Index: (Weapon : 27, Target : 39)
# not enough Missile on Weapon 27
# Value: 0.984807104075, Index: (Weapon : 42, Target : 84)
# Value: 0.98450336463, Index: (Weapon : 35, Target : 63)
# not enough Missile for Target 63
# Value: 0.984243229401, Index: (Weapon : 42, Target : 70)
# not enough Missile for Target 70
# Value: 0.983788465476, Index: (Weapon : 12, Target : 68)
# not enough Missile on Weapon 12
# Value: 0.98371948975, Index: (Weapon : 42, Target : 75)
# Value: 0.983481454517, Index: (Weapon : 24, Target : 71)
# Value: 0.983395750291, Index: (Weapon : 21, Target : 91)
# not enough Missile for Target 91
# Value: 0.983271561627, Index: (Weapon : 37, Target : 73)
# not enough Missile for Target 73
# Value: 0.982989257322, Index: (Weapon : 40, Target : 14)
# not enough Missile for Target 14
# Value: 0.981906036277, Index: (Weapon : 9, Target : 9)
# not enough Missile for Target 9
# Value: 0.981831606221, Index: (Weapon : 2, Target : 19)
# Value: 0.98170584597, Index: (Weapon : 0, Target : 29)
# not enough Missile for Target 29
# Value: 0.981371020179, Index: (Weapon : 21, Target : 14)
# not enough Missile for Target 14
# Value: 0.981204641644, Index: (Weapon : 25, Target : 93)
# not enough Missile on Weapon 25
# Value: 0.980866016832, Index: (Weapon : 38, Target : 56)
# not enough Missile for Target 56
# Value: 0.980636944283, Index: (Weapon : 40, Target : 98)
# not enough Missile for Target 98
# Value: 0.980269472609, Index: (Weapon : 12, Target : 65)
# not enough Missile on Weapon 12
# Value: 0.980121003334, Index: (Weapon : 20, Target : 47)
# not enough Missile for Target 47
# Value: 0.98003358687, Index: (Weapon : 12, Target : 71)
# not enough Missile for Target 71
# Value: 0.979827136615, Index: (Weapon : 48, Target : 19)
# not enough Missile for Target 19
# Value: 0.979650482127, Index: (Weapon : 17, Target : 27)
# not enough Missile for Target 27
# Value: 0.97917734586, Index: (Weapon : 26, Target : 64)
# not enough Missile on Weapon 26
# Value: 0.979060734559, Index: (Weapon : 14, Target : 85)
# Value: 0.978659497451, Index: (Weapon : 40, Target : 73)
# not enough Missile for Target 73
# Value: 0.978462928159, Index: (Weapon : 6, Target : 96)
# not enough Missile for Target 96
# Value: 0.978349882456, Index: (Weapon : 11, Target : 46)
# not enough Missile for Target 46
# Value: 0.978015850343, Index: (Weapon : 5, Target : 38)
# not enough Missile for Target 38
# Value: 0.977998019002, Index: (Weapon : 26, Target : 58)
# not enough Missile for Target 58
# Value: 0.977667986861, Index: (Weapon : 1, Target : 37)
# not enough Missile for Target 37
# Value: 0.977127469564, Index: (Weapon : 13, Target : 45)
# not enough Missile on Weapon 13
# Value: 0.977017459465, Index: (Weapon : 7, Target : 29)
# not enough Missile for Target 29
# Value: 0.976873013334, Index: (Weapon : 13, Target : 98)
# not enough Missile for Target 98
# Value: 0.976811925426, Index: (Weapon : 7, Target : 95)
# not enough Missile for Target 95
# Value: 0.976519633965, Index: (Weapon : 30, Target : 21)
# Value: 0.976258117671, Index: (Weapon : 9, Target : 51)
# not enough Missile for Target 51
# Value: 0.97624779483, Index: (Weapon : 8, Target : 92)
# Value: 0.976113466546, Index: (Weapon : 28, Target : 23)
# Value: 0.976113108781, Index: (Weapon : 35, Target : 54)
# not enough Missile for Target 54
# Value: 0.975882398731, Index: (Weapon : 47, Target : 95)
# not enough Missile for Target 95
# Value: 0.975710106713, Index: (Weapon : 24, Target : 80)
# not enough Missile on Weapon 24
# Value: 0.975684330199, Index: (Weapon : 4, Target : 19)
# not enough Missile for Target 19
# Value: 0.975277075544, Index: (Weapon : 45, Target : 60)
# Value: 0.975110512218, Index: (Weapon : 33, Target : 87)
# not enough Missile for Target 87
# Value: 0.974954305991, Index: (Weapon : 45, Target : 13)
# not enough Missile for Target 13
# Value: 0.974504481901, Index: (Weapon : 0, Target : 31)
# Value: 0.974460820814, Index: (Weapon : 35, Target : 50)
# Value: 0.97420381711, Index: (Weapon : 19, Target : 40)
# not enough Missile for Target 40
# Value: 0.973509127639, Index: (Weapon : 18, Target : 57)
# not enough Missile on Weapon 18
# Value: 0.97330124839, Index: (Weapon : 22, Target : 17)
# Value: 0.972998858277, Index: (Weapon : 32, Target : 51)
# not enough Missile for Target 51
# Value: 0.972873105528, Index: (Weapon : 31, Target : 9)
# not enough Missile for Target 9
# Value: 0.972854662083, Index: (Weapon : 17, Target : 68)
# not enough Missile on Weapon 17
# Value: 0.972736481159, Index: (Weapon : 16, Target : 78)
# Value: 0.971508884077, Index: (Weapon : 38, Target : 50)
# not enough Missile for Target 50
# Value: 0.971492369464, Index: (Weapon : 44, Target : 28)
# not enough Missile on Weapon 44
# Value: 0.971379420398, Index: (Weapon : 12, Target : 33)
# not enough Missile for Target 33
# Value: 0.971121756033, Index: (Weapon : 5, Target : 17)
# not enough Missile for Target 17
# Value: 0.971073327503, Index: (Weapon : 6, Target : 72)
# not enough Missile for Target 72
# Value: 0.970968610548, Index: (Weapon : 31, Target : 28)
# Value: 0.970569733759, Index: (Weapon : 25, Target : 27)
# not enough Missile for Target 27
# Value: 0.970462051466, Index: (Weapon : 47, Target : 48)
# not enough Missile for Target 48
# Value: 0.970261349054, Index: (Weapon : 15, Target : 86)
# not enough Missile for Target 86
# Value: 0.970173505734, Index: (Weapon : 6, Target : 71)
# not enough Missile for Target 71
# Value: 0.969952344198, Index: (Weapon : 47, Target : 21)
# not enough Missile for Target 21
# Value: 0.969531340613, Index: (Weapon : 45, Target : 6)
# not enough Missile for Target 6
# Value: 0.969315515876, Index: (Weapon : 20, Target : 89)
# Value: 0.969230222401, Index: (Weapon : 11, Target : 48)
# not enough Missile for Target 48
# Value: 0.969228398744, Index: (Weapon : 8, Target : 29)
# not enough Missile for Target 29
# Value: 0.96911882986, Index: (Weapon : 40, Target : 53)
# Value: 0.969077569773, Index: (Weapon : 15, Target : 37)
# not enough Missile for Target 37
# Value: 0.968858989133, Index: (Weapon : 2, Target : 65)
# Value: 0.96862902621, Index: (Weapon : 44, Target : 2)
# not enough Missile on Weapon 44
# Value: 0.968561329076, Index: (Weapon : 46, Target : 60)
# not enough Missile for Target 60
# Value: 0.968408667357, Index: (Weapon : 23, Target : 53)
# not enough Missile for Target 53
# Value: 0.968070164704, Index: (Weapon : 17, Target : 37)
# not enough Missile for Target 37
# Value: 0.967286892092, Index: (Weapon : 23, Target : 52)
# Value: 0.967042094765, Index: (Weapon : 7, Target : 7)
# Value: 0.967019535791, Index: (Weapon : 5, Target : 55)
# Value: 0.966806389861, Index: (Weapon : 32, Target : 21)
# not enough Missile for Target 21
# Value: 0.966717881611, Index: (Weapon : 8, Target : 35)
# not enough Missile for Target 35
# Value: 0.966625849126, Index: (Weapon : 33, Target : 10)
# Value: 0.966196896548, Index: (Weapon : 4, Target : 10)
# not enough Missile for Target 10
# Value: 0.966155842227, Index: (Weapon : 8, Target : 14)
# not enough Missile for Target 14
# Value: 0.965868850875, Index: (Weapon : 43, Target : 48)
# not enough Missile for Target 48
# Value: 0.965793184634, Index: (Weapon : 49, Target : 81)
# Value: 0.965756406003, Index: (Weapon : 13, Target : 47)
# not enough Missile for Target 47
# Value: 0.96556559424, Index: (Weapon : 21, Target : 10)
# not enough Missile for Target 10
# Value: 0.965515341791, Index: (Weapon : 46, Target : 56)
# not enough Missile for Target 56
# Value: 0.965388758861, Index: (Weapon : 15, Target : 18)
# not enough Missile on Weapon 15
# Value: 0.965207310077, Index: (Weapon : 42, Target : 13)
# not enough Missile for Target 13
# Value: 0.964913572022, Index: (Weapon : 44, Target : 14)
# not enough Missile for Target 14
# Value: 0.964912405344, Index: (Weapon : 36, Target : 46)
# not enough Missile for Target 46
# Value: 0.964728500026, Index: (Weapon : 28, Target : 99)
# not enough Missile for Target 99
# Value: 0.964727069826, Index: (Weapon : 27, Target : 32)
# not enough Missile on Weapon 27
# Value: 0.96467133061, Index: (Weapon : 21, Target : 4)
# not enough Missile for Target 4
# Value: 0.963323985719, Index: (Weapon : 24, Target : 91)
# not enough Missile for Target 91
# Value: 0.963183966252, Index: (Weapon : 2, Target : 41)
# not enough Missile on Weapon 2
# Value: 0.963018128871, Index: (Weapon : 15, Target : 33)
# not enough Missile for Target 33
# Value: 0.962988911296, Index: (Weapon : 33, Target : 9)
# not enough Missile for Target 9
# Value: 0.962953777668, Index: (Weapon : 4, Target : 68)
# not enough Missile on Weapon 4
# Value: 0.962352064973, Index: (Weapon : 11, Target : 5)
# not enough Missile for Target 5
# Value: 0.962125860647, Index: (Weapon : 49, Target : 80)
# Value: 0.961999035988, Index: (Weapon : 19, Target : 0)
# not enough Missile for Target 0
# Value: 0.961943235882, Index: (Weapon : 40, Target : 2)
# not enough Missile on Weapon 40
# Value: 0.961847200773, Index: (Weapon : 21, Target : 67)
# Value: 0.961820488462, Index: (Weapon : 45, Target : 19)
# not enough Missile for Target 19
# Value: 0.961736809418, Index: (Weapon : 34, Target : 46)
# not enough Missile for Target 46
# Value: 0.961673320314, Index: (Weapon : 19, Target : 83)
# not enough Missile on Weapon 19
# Value: 0.961192006307, Index: (Weapon : 16, Target : 63)
# not enough Missile for Target 63
# Value: 0.960769712779, Index: (Weapon : 43, Target : 74)
# not enough Missile for Target 74
# Value: 0.96068239984, Index: (Weapon : 27, Target : 15)
# not enough Missile on Weapon 27
# Value: 0.960626285567, Index: (Weapon : 3, Target : 80)
# not enough Missile for Target 80
# Value: 0.959988507408, Index: (Weapon : 28, Target : 85)
# not enough Missile for Target 85
# Value: 0.959909910909, Index: (Weapon : 21, Target : 33)
# not enough Missile for Target 33
# Value: 0.959641398786, Index: (Weapon : 25, Target : 56)
# not enough Missile for Target 56
# Value: 0.959632174609, Index: (Weapon : 41, Target : 53)
# not enough Missile for Target 53
# Value: 0.959415010144, Index: (Weapon : 0, Target : 74)
# not enough Missile for Target 74
# Value: 0.95933117407, Index: (Weapon : 22, Target : 76)
# Value: 0.959310571404, Index: (Weapon : 3, Target : 1)
# not enough Missile for Target 1
# Value: 0.958240061462, Index: (Weapon : 24, Target : 61)
# not enough Missile on Weapon 24
# Value: 0.958013039083, Index: (Weapon : 36, Target : 44)
# Value: 0.95743374533, Index: (Weapon : 8, Target : 65)
# not enough Missile for Target 65
# Value: 0.957033688507, Index: (Weapon : 0, Target : 92)
# not enough Missile for Target 92
# Value: 0.956819975225, Index: (Weapon : 22, Target : 57)
# not enough Missile on Weapon 22
# Value: 0.956265628122, Index: (Weapon : 1, Target : 12)
# Value: 0.956151529036, Index: (Weapon : 0, Target : 9)
# not enough Missile for Target 9
# Value: 0.956089421296, Index: (Weapon : 17, Target : 0)
# not enough Missile for Target 0
# Value: 0.956041577111, Index: (Weapon : 46, Target : 8)
# Value: 0.95603674542, Index: (Weapon : 13, Target : 42)
# not enough Missile for Target 42
# Value: 0.955914783468, Index: (Weapon : 41, Target : 9)
# not enough Missile for Target 9
# Value: 0.955846978195, Index: (Weapon : 7, Target : 65)
# not enough Missile for Target 65
# Value: 0.955365535162, Index: (Weapon : 1, Target : 5)
# not enough Missile for Target 5
# Value: 0.955194640656, Index: (Weapon : 8, Target : 90)
# Value: 0.954873465041, Index: (Weapon : 26, Target : 35)
# not enough Missile for Target 35
# Value: 0.954369777309, Index: (Weapon : 33, Target : 58)
# not enough Missile for Target 58
# Value: 0.954051123094, Index: (Weapon : 25, Target : 76)
# not enough Missile for Target 76
# Value: 0.953788137045, Index: (Weapon : 18, Target : 18)
# not enough Missile on Weapon 18
# Value: 0.953635263815, Index: (Weapon : 14, Target : 56)
# not enough Missile for Target 56
# Value: 0.953517513194, Index: (Weapon : 25, Target : 78)
# not enough Missile for Target 78
# Value: 0.953493320134, Index: (Weapon : 38, Target : 8)
# not enough Missile for Target 8
# Value: 0.953263325363, Index: (Weapon : 3, Target : 71)
# not enough Missile for Target 71
# Value: 0.953139535646, Index: (Weapon : 23, Target : 28)
# not enough Missile for Target 28
# Value: 0.953078955674, Index: (Weapon : 47, Target : 8)
# not enough Missile for Target 8
# Value: 0.952819005165, Index: (Weapon : 4, Target : 81)
# not enough Missile for Target 81
# Value: 0.952582753901, Index: (Weapon : 12, Target : 88)
# not enough Missile on Weapon 12
# Value: 0.952456481258, Index: (Weapon : 2, Target : 14)
# not enough Missile for Target 14
# Value: 0.952270158042, Index: (Weapon : 4, Target : 64)
# not enough Missile on Weapon 4
# Value: 0.952006599195, Index: (Weapon : 12, Target : 25)
# not enough Missile on Weapon 12
# Value: 0.951902710884, Index: (Weapon : 39, Target : 2)
# not enough Missile on Weapon 39
# Value: 0.951803386518, Index: (Weapon : 39, Target : 41)
# not enough Missile on Weapon 39
# Value: 0.951270237537, Index: (Weapon : 38, Target : 65)
# not enough Missile for Target 65
# Value: 0.951205523493, Index: (Weapon : 17, Target : 22)
# not enough Missile on Weapon 17
# Value: 0.95112794379, Index: (Weapon : 22, Target : 52)
# not enough Missile for Target 52
# Value: 0.951106494961, Index: (Weapon : 7, Target : 64)
# not enough Missile on Weapon 7
# Value: 0.950997441314, Index: (Weapon : 12, Target : 20)
# not enough Missile for Target 20
# Value: 0.950773860416, Index: (Weapon : 42, Target : 56)
# not enough Missile for Target 56
# Value: 0.950646233065, Index: (Weapon : 28, Target : 38)
# not enough Missile for Target 38
# Value: 0.950411562661, Index: (Weapon : 22, Target : 82)
# not enough Missile on Weapon 22
# Value: 0.950036973264, Index: (Weapon : 33, Target : 88)
# Value: 0.949771143469, Index: (Weapon : 22, Target : 85)
# not enough Missile for Target 85
# Value: 0.949664879744, Index: (Weapon : 13, Target : 74)
# not enough Missile for Target 74
# Value: 0.94963147058, Index: (Weapon : 18, Target : 4)
# not enough Missile for Target 4
# Value: 0.94919420553, Index: (Weapon : 20, Target : 1)
# not enough Missile for Target 1
# Value: 0.94910421003, Index: (Weapon : 45, Target : 38)
# not enough Missile for Target 38
# Value: 0.948634296472, Index: (Weapon : 10, Target : 63)
# not enough Missile for Target 63
# Value: 0.947760658664, Index: (Weapon : 49, Target : 43)
# not enough Missile for Target 43
# Value: 0.947646233824, Index: (Weapon : 37, Target : 25)
# not enough Missile on Weapon 37
# Value: 0.947505584422, Index: (Weapon : 37, Target : 82)
# not enough Missile on Weapon 37
# Value: 0.947450940704, Index: (Weapon : 18, Target : 86)
# not enough Missile for Target 86
# Value: 0.947413899389, Index: (Weapon : 17, Target : 77)
# not enough Missile on Weapon 17
# Value: 0.947351779283, Index: (Weapon : 32, Target : 37)
# not enough Missile for Target 37
# Value: 0.947298372434, Index: (Weapon : 1, Target : 29)
# not enough Missile for Target 29
# Value: 0.947227620763, Index: (Weapon : 11, Target : 14)
# not enough Missile for Target 14
# Value: 0.947131968346, Index: (Weapon : 27, Target : 83)
# not enough Missile on Weapon 27
# Value: 0.946916566174, Index: (Weapon : 22, Target : 94)
# not enough Missile on Weapon 22
# Value: 0.946652254586, Index: (Weapon : 2, Target : 74)
# not enough Missile for Target 74
# Value: 0.946516894804, Index: (Weapon : 47, Target : 85)
# not enough Missile for Target 85
# Value: 0.946039875402, Index: (Weapon : 19, Target : 27)
# not enough Missile for Target 27
# Value: 0.946003365949, Index: (Weapon : 20, Target : 20)
# not enough Missile for Target 20
# Value: 0.945940971832, Index: (Weapon : 1, Target : 36)
# not enough Missile for Target 36
# Value: 0.94589272612, Index: (Weapon : 3, Target : 39)
# Value: 0.945777023799, Index: (Weapon : 2, Target : 50)
# not enough Missile for Target 50
# Value: 0.945584052516, Index: (Weapon : 42, Target : 8)
# not enough Missile for Target 8
# Value: 0.94551669543, Index: (Weapon : 35, Target : 78)
# not enough Missile for Target 78
# Value: 0.945469332024, Index: (Weapon : 17, Target : 75)
# not enough Missile for Target 75
# Value: 0.945079389203, Index: (Weapon : 40, Target : 49)
# not enough Missile for Target 49
# Value: 0.9448035397, Index: (Weapon : 11, Target : 87)
# not enough Missile for Target 87
# Value: 0.944704083925, Index: (Weapon : 29, Target : 74)
# not enough Missile for Target 74
# Value: 0.944560777214, Index: (Weapon : 36, Target : 49)
# not enough Missile for Target 49
# Value: 0.944559064316, Index: (Weapon : 13, Target : 37)
# not enough Missile for Target 37
# Value: 0.944535645278, Index: (Weapon : 19, Target : 3)
# not enough Missile for Target 3
# Value: 0.94449868678, Index: (Weapon : 22, Target : 8)
# not enough Missile for Target 8
# Value: 0.9439488693, Index: (Weapon : 34, Target : 62)
# not enough Missile for Target 62
# Value: 0.943708579031, Index: (Weapon : 20, Target : 82)
# not enough Missile on Weapon 20
# Value: 0.943396764555, Index: (Weapon : 27, Target : 81)
# not enough Missile for Target 81
# Value: 0.943161578477, Index: (Weapon : 23, Target : 38)
# not enough Missile for Target 38
# Value: 0.942859895098, Index: (Weapon : 34, Target : 94)
# Value: 0.942114208629, Index: (Weapon : 41, Target : 26)
# not enough Missile for Target 26
# Value: 0.941955671064, Index: (Weapon : 30, Target : 51)
# not enough Missile for Target 51
# Value: 0.941448649507, Index: (Weapon : 33, Target : 34)
# not enough Missile for Target 34
# Value: 0.94102937612, Index: (Weapon : 48, Target : 65)
# not enough Missile for Target 65
# Value: 0.940840359088, Index: (Weapon : 11, Target : 51)
# not enough Missile for Target 51
# Value: 0.940719515129, Index: (Weapon : 12, Target : 3)
# not enough Missile for Target 3
# Value: 0.940577012472, Index: (Weapon : 32, Target : 34)
# not enough Missile for Target 34
# Value: 0.940214117977, Index: (Weapon : 38, Target : 55)
# not enough Missile for Target 55
# Value: 0.939687637035, Index: (Weapon : 14, Target : 97)
# not enough Missile on Weapon 14
# Value: 0.939681941302, Index: (Weapon : 12, Target : 54)
# not enough Missile for Target 54
# Value: 0.939361849711, Index: (Weapon : 44, Target : 57)
# not enough Missile on Weapon 44
# Value: 0.939314873192, Index: (Weapon : 45, Target : 15)
# Value: 0.938909444596, Index: (Weapon : 40, Target : 30)
# not enough Missile for Target 30
# Value: 0.938736479524, Index: (Weapon : 41, Target : 4)
# not enough Missile for Target 4
# Value: 0.937844908485, Index: (Weapon : 34, Target : 10)
# not enough Missile for Target 10
# Value: 0.937590304946, Index: (Weapon : 1, Target : 87)
# not enough Missile for Target 87
# Value: 0.937402270573, Index: (Weapon : 16, Target : 95)
# not enough Missile for Target 95
# Value: 0.93712183213, Index: (Weapon : 31, Target : 22)
# not enough Missile on Weapon 31
# Value: 0.937028578836, Index: (Weapon : 27, Target : 90)
# not enough Missile for Target 90
# Value: 0.9369705912, Index: (Weapon : 24, Target : 54)
# not enough Missile for Target 54
# Value: 0.936933071892, Index: (Weapon : 1, Target : 17)
# not enough Missile for Target 17
# Value: 0.936891180643, Index: (Weapon : 31, Target : 5)
# not enough Missile for Target 5
# Value: 0.936641352039, Index: (Weapon : 42, Target : 97)
# not enough Missile on Weapon 42
# Value: 0.93648675538, Index: (Weapon : 42, Target : 26)
# not enough Missile for Target 26
# Value: 0.936480082277, Index: (Weapon : 7, Target : 78)
# not enough Missile for Target 78
# Value: 0.936040264339, Index: (Weapon : 4, Target : 51)
# not enough Missile for Target 51
# Value: 0.935875014606, Index: (Weapon : 5, Target : 4)
# not enough Missile for Target 4
# Value: 0.935402264792, Index: (Weapon : 19, Target : 7)
# not enough Missile for Target 7
# Value: 0.935389545608, Index: (Weapon : 26, Target : 43)
# not enough Missile for Target 43
# Value: 0.935211927991, Index: (Weapon : 47, Target : 28)
# not enough Missile for Target 28
# Value: 0.934890338925, Index: (Weapon : 30, Target : 43)
# not enough Missile for Target 43
# Value: 0.934715677137, Index: (Weapon : 7, Target : 39)
# not enough Missile for Target 39
# Value: 0.934423617994, Index: (Weapon : 21, Target : 84)
# not enough Missile for Target 84
# Value: 0.934341814694, Index: (Weapon : 26, Target : 56)
# not enough Missile for Target 56
# Value: 0.93422190383, Index: (Weapon : 19, Target : 55)
# not enough Missile for Target 55
# Value: 0.933885710049, Index: (Weapon : 32, Target : 17)
# not enough Missile for Target 17
# Value: 0.933802301335, Index: (Weapon : 2, Target : 99)
# not enough Missile for Target 99
# Value: 0.933502051633, Index: (Weapon : 18, Target : 95)
# not enough Missile for Target 95
# Value: 0.933406225715, Index: (Weapon : 42, Target : 99)
# not enough Missile for Target 99
# Value: 0.932331985286, Index: (Weapon : 3, Target : 65)
# not enough Missile for Target 65
# Value: 0.932183142097, Index: (Weapon : 39, Target : 90)
# not enough Missile for Target 90
# Value: 0.932030654495, Index: (Weapon : 42, Target : 23)
# not enough Missile for Target 23
# Value: 0.931936577764, Index: (Weapon : 35, Target : 57)
# Value: 0.931847650196, Index: (Weapon : 10, Target : 46)
# not enough Missile for Target 46
# Value: 0.931838041016, Index: (Weapon : 44, Target : 77)
# not enough Missile on Weapon 44
# Value: 0.931692608329, Index: (Weapon : 36, Target : 69)
# not enough Missile for Target 69
# Value: 0.931378317998, Index: (Weapon : 11, Target : 34)
# not enough Missile for Target 34
# Value: 0.930686049541, Index: (Weapon : 38, Target : 19)
# not enough Missile for Target 19
# Value: 0.930557616473, Index: (Weapon : 46, Target : 57)
# not enough Missile for Target 57
# Value: 0.93031332878, Index: (Weapon : 45, Target : 24)
# not enough Missile for Target 24
# Value: 0.929955483058, Index: (Weapon : 4, Target : 0)
# not enough Missile for Target 0
# Value: 0.929938880205, Index: (Weapon : 49, Target : 83)
# not enough Missile on Weapon 49
# Value: 0.929661922794, Index: (Weapon : 47, Target : 30)
# not enough Missile for Target 30
# Value: 0.929656491636, Index: (Weapon : 6, Target : 84)
# not enough Missile for Target 84
# Value: 0.929486768736, Index: (Weapon : 0, Target : 60)
# not enough Missile for Target 60
# Value: 0.92920469951, Index: (Weapon : 48, Target : 0)
# not enough Missile for Target 0
# Value: 0.928985252419, Index: (Weapon : 44, Target : 71)
# not enough Missile for Target 71
# Value: 0.928232019827, Index: (Weapon : 43, Target : 89)
# not enough Missile for Target 89
# Value: 0.927948426576, Index: (Weapon : 36, Target : 85)
# not enough Missile for Target 85
# Value: 0.927583644227, Index: (Weapon : 33, Target : 82)
# not enough Missile on Weapon 33
# Value: 0.9274568742, Index: (Weapon : 19, Target : 22)
# not enough Missile on Weapon 19
# Value: 0.927349792685, Index: (Weapon : 33, Target : 6)
# not enough Missile for Target 6
# Value: 0.927226686958, Index: (Weapon : 43, Target : 6)
# not enough Missile for Target 6
# Value: 0.927070771912, Index: (Weapon : 19, Target : 54)
# not enough Missile for Target 54
# Value: 0.927025959626, Index: (Weapon : 1, Target : 69)
# not enough Missile for Target 69
# Value: 0.926912936757, Index: (Weapon : 11, Target : 90)
# not enough Missile for Target 90
# Value: 0.926878070659, Index: (Weapon : 6, Target : 60)
# not enough Missile for Target 60
# Value: 0.926807872067, Index: (Weapon : 41, Target : 25)
# Value: 0.92641539022, Index: (Weapon : 44, Target : 64)
# not enough Missile on Weapon 44
# Value: 0.926402656972, Index: (Weapon : 38, Target : 54)
# not enough Missile for Target 54
# Value: 0.926364260261, Index: (Weapon : 45, Target : 30)
# not enough Missile for Target 30
# Value: 0.926082392613, Index: (Weapon : 45, Target : 14)
# not enough Missile for Target 14
# Value: 0.92598160741, Index: (Weapon : 35, Target : 92)
# not enough Missile for Target 92
# Value: 0.925250076021, Index: (Weapon : 44, Target : 92)
# not enough Missile for Target 92
# Value: 0.924958246489, Index: (Weapon : 6, Target : 45)
# Value: 0.92490317948, Index: (Weapon : 39, Target : 22)
# not enough Missile on Weapon 39
# Value: 0.924737292224, Index: (Weapon : 38, Target : 68)
# Value: 0.924367133948, Index: (Weapon : 39, Target : 66)
# not enough Missile for Target 66
# Value: 0.923951145219, Index: (Weapon : 43, Target : 81)
# not enough Missile for Target 81
# Value: 0.923548463183, Index: (Weapon : 29, Target : 96)
# not enough Missile for Target 96
# Value: 0.923340503238, Index: (Weapon : 14, Target : 88)
# not enough Missile for Target 88
# Value: 0.923276334057, Index: (Weapon : 11, Target : 32)
# Value: 0.923107477439, Index: (Weapon : 36, Target : 4)
# not enough Missile for Target 4
# Value: 0.922975701625, Index: (Weapon : 15, Target : 0)
# not enough Missile for Target 0
# Value: 0.922865236844, Index: (Weapon : 26, Target : 4)
# not enough Missile for Target 4
# Value: 0.922502576181, Index: (Weapon : 25, Target : 86)
# not enough Missile for Target 86
# Value: 0.922482508027, Index: (Weapon : 21, Target : 87)
# not enough Missile for Target 87
# Value: 0.922475807792, Index: (Weapon : 18, Target : 33)
# not enough Missile for Target 33
# Value: 0.9222059261, Index: (Weapon : 32, Target : 79)
# not enough Missile for Target 79
# Value: 0.922153655101, Index: (Weapon : 25, Target : 59)
# not enough Missile on Weapon 25
# Value: 0.921530379231, Index: (Weapon : 5, Target : 6)
# not enough Missile for Target 6
# Value: 0.921206012101, Index: (Weapon : 8, Target : 85)
# not enough Missile for Target 85
# Value: 0.921116456278, Index: (Weapon : 44, Target : 44)
# not enough Missile for Target 44
# Value: 0.921071765257, Index: (Weapon : 38, Target : 1)
# not enough Missile for Target 1
# Value: 0.92075279277, Index: (Weapon : 8, Target : 31)
# not enough Missile for Target 31
# Value: 0.920700403281, Index: (Weapon : 27, Target : 0)
# not enough Missile for Target 0
# Value: 0.920643903364, Index: (Weapon : 32, Target : 66)
# not enough Missile for Target 66
# Value: 0.920575155156, Index: (Weapon : 21, Target : 34)
# not enough Missile for Target 34
# Value: 0.919796845663, Index: (Weapon : 38, Target : 95)
# not enough Missile for Target 95
# Value: 0.919447057471, Index: (Weapon : 47, Target : 38)
# not enough Missile for Target 38
# Value: 0.919431219105, Index: (Weapon : 26, Target : 85)
# not enough Missile for Target 85
# Value: 0.91931029999, Index: (Weapon : 46, Target : 99)
# not enough Missile for Target 99
# Value: 0.919242769502, Index: (Weapon : 41, Target : 54)
# not enough Missile for Target 54
# Value: 0.919219680802, Index: (Weapon : 48, Target : 3)
# not enough Missile for Target 3
# Value: 0.919185415653, Index: (Weapon : 36, Target : 96)
# not enough Missile for Target 96
# Value: 0.918762344672, Index: (Weapon : 28, Target : 96)
# not enough Missile for Target 96
# Value: 0.918682694205, Index: (Weapon : 14, Target : 46)
# not enough Missile for Target 46
# Value: 0.918607333201, Index: (Weapon : 14, Target : 6)
# not enough Missile for Target 6
# Value: 0.91828696534, Index: (Weapon : 22, Target : 40)
# not enough Missile for Target 40
# Value: 0.91825265774, Index: (Weapon : 12, Target : 74)
# not enough Missile for Target 74
# Value: 0.918008944987, Index: (Weapon : 48, Target : 90)
# not enough Missile for Target 90
# Value: 0.917841490273, Index: (Weapon : 10, Target : 55)
# not enough Missile for Target 55
# Value: 0.917444169825, Index: (Weapon : 36, Target : 27)
# not enough Missile for Target 27
# Value: 0.917362170834, Index: (Weapon : 1, Target : 54)
# not enough Missile for Target 54
# Value: 0.9173164089, Index: (Weapon : 18, Target : 60)
# not enough Missile for Target 60
# Value: 0.917181875812, Index: (Weapon : 44, Target : 63)
# not enough Missile for Target 63
# Value: 0.9169972826, Index: (Weapon : 16, Target : 17)
# not enough Missile for Target 17
# Value: 0.916541160696, Index: (Weapon : 41, Target : 36)
# not enough Missile for Target 36
# Value: 0.916474205148, Index: (Weapon : 13, Target : 29)
# not enough Missile for Target 29
# Value: 0.916317861893, Index: (Weapon : 46, Target : 7)
# not enough Missile for Target 7
# Value: 0.91600277142, Index: (Weapon : 29, Target : 98)
# not enough Missile for Target 98
# Value: 0.915790361561, Index: (Weapon : 11, Target : 25)
# not enough Missile for Target 25
# Value: 0.915447942911, Index: (Weapon : 16, Target : 58)
# not enough Missile for Target 58
# Value: 0.915044917529, Index: (Weapon : 23, Target : 7)
# not enough Missile for Target 7
# Value: 0.914891129947, Index: (Weapon : 45, Target : 77)
# not enough Missile on Weapon 45
# Value: 0.914509630734, Index: (Weapon : 45, Target : 29)
# not enough Missile for Target 29
# Value: 0.914394097632, Index: (Weapon : 23, Target : 32)
# not enough Missile for Target 32
# Value: 0.914378298854, Index: (Weapon : 48, Target : 35)
# not enough Missile for Target 35
# Value: 0.914252579183, Index: (Weapon : 14, Target : 49)
# not enough Missile for Target 49
# Value: 0.91413069591, Index: (Weapon : 20, Target : 29)
# not enough Missile for Target 29
# Value: 0.914129361531, Index: (Weapon : 6, Target : 40)
# not enough Missile for Target 40
# Value: 0.913647813974, Index: (Weapon : 6, Target : 10)
# not enough Missile for Target 10
# Value: 0.91355635139, Index: (Weapon : 8, Target : 53)
# not enough Missile for Target 53
# Value: 0.912740604624, Index: (Weapon : 10, Target : 43)
# not enough Missile for Target 43
# Value: 0.912547600061, Index: (Weapon : 10, Target : 81)
# not enough Missile for Target 81
# Value: 0.912515187019, Index: (Weapon : 38, Target : 0)
# not enough Missile for Target 0
# Value: 0.912177016658, Index: (Weapon : 42, Target : 16)
# not enough Missile on Weapon 42
# Value: 0.912143541176, Index: (Weapon : 35, Target : 15)
# not enough Missile for Target 15
# Value: 0.912035579105, Index: (Weapon : 6, Target : 52)
# not enough Missile for Target 52
# Value: 0.911735384047, Index: (Weapon : 33, Target : 66)
# not enough Missile for Target 66
# Value: 0.911716426437, Index: (Weapon : 26, Target : 51)
# not enough Missile for Target 51
# Value: 0.91153600697, Index: (Weapon : 15, Target : 22)
# not enough Missile on Weapon 15
# Value: 0.911131836661, Index: (Weapon : 30, Target : 91)
# not enough Missile for Target 91
# Value: 0.911086116528, Index: (Weapon : 49, Target : 89)
# not enough Missile for Target 89
# Value: 0.911022476859, Index: (Weapon : 15, Target : 92)
# not enough Missile for Target 92
# Value: 0.910762816488, Index: (Weapon : 3, Target : 54)
# not enough Missile for Target 54
# Value: 0.910691925567, Index: (Weapon : 10, Target : 41)
# not enough Missile on Weapon 10
# Value: 0.910372610359, Index: (Weapon : 21, Target : 66)
# not enough Missile for Target 66
# Value: 0.909995723291, Index: (Weapon : 4, Target : 91)
# not enough Missile for Target 91
# Value: 0.9098892687, Index: (Weapon : 21, Target : 71)
# not enough Missile for Target 71
# Value: 0.909270128104, Index: (Weapon : 19, Target : 9)
# not enough Missile for Target 9
# Value: 0.909221129826, Index: (Weapon : 39, Target : 46)
# not enough Missile for Target 46
# Value: 0.909077930059, Index: (Weapon : 21, Target : 95)
# not enough Missile for Target 95
# Value: 0.908883147446, Index: (Weapon : 32, Target : 84)
# not enough Missile for Target 84
# Value: 0.908831871567, Index: (Weapon : 16, Target : 93)
# Value: 0.908629935324, Index: (Weapon : 20, Target : 83)
# not enough Missile on Weapon 20
# Value: 0.908551632898, Index: (Weapon : 8, Target : 64)
# not enough Missile on Weapon 8
# Value: 0.908296711859, Index: (Weapon : 33, Target : 46)
# not enough Missile for Target 46
# Value: 0.908081906706, Index: (Weapon : 0, Target : 40)
# not enough Missile for Target 40
# Value: 0.908046981696, Index: (Weapon : 16, Target : 52)
# not enough Missile for Target 52
# Value: 0.907180413291, Index: (Weapon : 17, Target : 40)
# not enough Missile for Target 40
# Value: 0.907133267067, Index: (Weapon : 28, Target : 3)
# not enough Missile for Target 3
# Value: 0.907038533491, Index: (Weapon : 37, Target : 23)
# not enough Missile for Target 23
# Value: 0.906817133928, Index: (Weapon : 45, Target : 5)
# not enough Missile for Target 5
# Value: 0.906525695868, Index: (Weapon : 41, Target : 76)
# not enough Missile for Target 76
# Value: 0.90625204965, Index: (Weapon : 49, Target : 52)
# not enough Missile for Target 52
# Value: 0.905800777253, Index: (Weapon : 34, Target : 57)
# not enough Missile for Target 57
# Value: 0.90520154985, Index: (Weapon : 7, Target : 51)
# not enough Missile for Target 51
# Value: 0.905186344653, Index: (Weapon : 0, Target : 44)
# not enough Missile for Target 44
# Value: 0.905035647654, Index: (Weapon : 4, Target : 67)
# not enough Missile for Target 67
# Value: 0.904678339569, Index: (Weapon : 18, Target : 96)
# not enough Missile for Target 96
# Value: 0.904569181063, Index: (Weapon : 18, Target : 89)
# not enough Missile for Target 89
# Value: 0.90438723903, Index: (Weapon : 5, Target : 10)
# not enough Missile for Target 10
# Value: 0.904230953343, Index: (Weapon : 21, Target : 49)
# not enough Missile for Target 49
# Value: 0.904138859007, Index: (Weapon : 48, Target : 30)
# not enough Missile for Target 30
# Value: 0.903983890609, Index: (Weapon : 31, Target : 79)
# not enough Missile for Target 79
# Value: 0.903733271867, Index: (Weapon : 7, Target : 73)
# not enough Missile for Target 73
# Value: 0.903728456123, Index: (Weapon : 28, Target : 39)
# not enough Missile for Target 39
# Value: 0.903264038427, Index: (Weapon : 34, Target : 1)
# not enough Missile for Target 1
# Value: 0.903208934373, Index: (Weapon : 20, Target : 31)
# not enough Missile for Target 31
# Value: 0.903206767948, Index: (Weapon : 24, Target : 53)
# not enough Missile for Target 53
# Value: 0.9032058427, Index: (Weapon : 0, Target : 46)
# not enough Missile for Target 46
# Value: 0.902807823389, Index: (Weapon : 30, Target : 81)
# not enough Missile for Target 81
# Value: 0.90223739785, Index: (Weapon : 24, Target : 3)
# not enough Missile for Target 3
# Value: 0.90214186371, Index: (Weapon : 33, Target : 37)
# not enough Missile for Target 37
# Value: 0.901964878924, Index: (Weapon : 32, Target : 60)
# not enough Missile for Target 60
# Value: 0.901937163978, Index: (Weapon : 13, Target : 18)
# not enough Missile on Weapon 13
# Value: 0.901705903228, Index: (Weapon : 47, Target : 10)
# not enough Missile for Target 10
# Value: 0.901672584895, Index: (Weapon : 39, Target : 15)
# not enough Missile for Target 15
# Value: 0.901468103004, Index: (Weapon : 21, Target : 82)
# Value: 0.901392074423, Index: (Weapon : 16, Target : 31)
# not enough Missile for Target 31
# Value: 0.901277452753, Index: (Weapon : 21, Target : 54)
# not enough Missile for Target 54
# Value: 0.901248533047, Index: (Weapon : 44, Target : 25)
# not enough Missile for Target 25
# Value: 0.901113815062, Index: (Weapon : 19, Target : 56)
# not enough Missile for Target 56
# Value: 0.900721546044, Index: (Weapon : 41, Target : 24)
# not enough Missile for Target 24
# Value: 0.900675929377, Index: (Weapon : 23, Target : 35)
# not enough Missile for Target 35
# Value: 0.900592170533, Index: (Weapon : 5, Target : 42)
# not enough Missile for Target 42
# Value: 0.900577475864, Index: (Weapon : 39, Target : 62)
# not enough Missile for Target 62
# Value: 0.900394510526, Index: (Weapon : 35, Target : 8)
# not enough Missile for Target 8
# Value: 0.900350237517, Index: (Weapon : 24, Target : 38)
# not enough Missile for Target 38
# Value: 0.90034633409, Index: (Weapon : 17, Target : 23)
# not enough Missile for Target 23
# Value: 0.900191829452, Index: (Weapon : 10, Target : 42)
# not enough Missile for Target 42
# Value: 0.899997267335, Index: (Weapon : 29, Target : 48)
# not enough Missile for Target 48
# Value: 0.899890551889, Index: (Weapon : 46, Target : 39)
# not enough Missile for Target 39
# Value: 0.899875259866, Index: (Weapon : 49, Target : 30)
# not enough Missile for Target 30
# Value: 0.899283747715, Index: (Weapon : 38, Target : 85)
# not enough Missile for Target 85
# Value: 0.899025542021, Index: (Weapon : 43, Target : 19)
# not enough Missile for Target 19
# Value: 0.89896150595, Index: (Weapon : 47, Target : 77)
# Value: 0.898913056153, Index: (Weapon : 10, Target : 75)
# not enough Missile for Target 75
# Value: 0.89889699181, Index: (Weapon : 4, Target : 52)
# not enough Missile for Target 52
# Value: 0.89885837584, Index: (Weapon : 43, Target : 86)
# not enough Missile for Target 86
# Value: 0.898781668197, Index: (Weapon : 21, Target : 90)
# not enough Missile for Target 90
# Value: 0.898780052, Index: (Weapon : 1, Target : 35)
# not enough Missile for Target 35
# Value: 0.898645857649, Index: (Weapon : 2, Target : 3)
# not enough Missile for Target 3
# Value: 0.898613052005, Index: (Weapon : 5, Target : 47)
# not enough Missile for Target 47
# Value: 0.898576932057, Index: (Weapon : 14, Target : 58)
# not enough Missile for Target 58
# Value: 0.898298877894, Index: (Weapon : 26, Target : 27)
# not enough Missile for Target 27
# Value: 0.897989392369, Index: (Weapon : 17, Target : 52)
# not enough Missile for Target 52
# Value: 0.897776287126, Index: (Weapon : 18, Target : 56)
# not enough Missile for Target 56
# Value: 0.897652859233, Index: (Weapon : 27, Target : 69)
# not enough Missile for Target 69
# Value: 0.896916462387, Index: (Weapon : 17, Target : 9)
# not enough Missile for Target 9
# Value: 0.896867592528, Index: (Weapon : 20, Target : 16)
# not enough Missile on Weapon 20
# Value: 0.896739718262, Index: (Weapon : 15, Target : 59)
# not enough Missile on Weapon 15
# Value: 0.896443623296, Index: (Weapon : 7, Target : 62)
# not enough Missile for Target 62
# Value: 0.89592873789, Index: (Weapon : 25, Target : 68)
# not enough Missile for Target 68
# Value: 0.895847340281, Index: (Weapon : 45, Target : 89)
# not enough Missile for Target 89
# Value: 0.89581905985, Index: (Weapon : 0, Target : 59)
# not enough Missile on Weapon 0
# Value: 0.895596512513, Index: (Weapon : 14, Target : 91)
# not enough Missile for Target 91
# Value: 0.89437762791, Index: (Weapon : 27, Target : 24)
# not enough Missile for Target 24
# Value: 0.894182578093, Index: (Weapon : 18, Target : 78)
# not enough Missile for Target 78
# Value: 0.893778709421, Index: (Weapon : 7, Target : 50)
# not enough Missile for Target 50
# Value: 0.893454923177, Index: (Weapon : 34, Target : 58)
# not enough Missile for Target 58
# Value: 0.893331726401, Index: (Weapon : 33, Target : 59)
# not enough Missile on Weapon 33
# Value: 0.893319622732, Index: (Weapon : 12, Target : 77)
# not enough Missile for Target 77
# Value: 0.893249083577, Index: (Weapon : 13, Target : 30)
# not enough Missile for Target 30
# Value: 0.892194185271, Index: (Weapon : 31, Target : 19)
# not enough Missile for Target 19
# Value: 0.891944868594, Index: (Weapon : 17, Target : 5)
# not enough Missile for Target 5
# Value: 0.891910646626, Index: (Weapon : 5, Target : 45)
# not enough Missile for Target 45
# Value: 0.89179261266, Index: (Weapon : 1, Target : 19)
# not enough Missile for Target 19
# Value: 0.891681243437, Index: (Weapon : 35, Target : 43)
# not enough Missile for Target 43
# Value: 0.891390420764, Index: (Weapon : 23, Target : 9)
# not enough Missile for Target 9
# Value: 0.891162404424, Index: (Weapon : 24, Target : 37)
# not enough Missile for Target 37
# Value: 0.890808033708, Index: (Weapon : 2, Target : 78)
# not enough Missile for Target 78
# Value: 0.890498853294, Index: (Weapon : 30, Target : 92)
# not enough Missile for Target 92
# Value: 0.889834057236, Index: (Weapon : 45, Target : 2)
# not enough Missile on Weapon 45
# Value: 0.889612835262, Index: (Weapon : 35, Target : 55)
# not enough Missile for Target 55
# Value: 0.88959726835, Index: (Weapon : 15, Target : 72)
# not enough Missile for Target 72
# Value: 0.889478600835, Index: (Weapon : 39, Target : 55)
# not enough Missile for Target 55
# Value: 0.889248884019, Index: (Weapon : 16, Target : 99)
# not enough Missile for Target 99
# Value: 0.888909015239, Index: (Weapon : 26, Target : 36)
# not enough Missile for Target 36
# Value: 0.888816872516, Index: (Weapon : 5, Target : 19)
# not enough Missile for Target 19
# Value: 0.888667241125, Index: (Weapon : 43, Target : 64)
# not enough Missile on Weapon 43
# Value: 0.888555265174, Index: (Weapon : 40, Target : 11)
# not enough Missile on Weapon 40
# Value: 0.888027838607, Index: (Weapon : 28, Target : 48)
# not enough Missile for Target 48
# Value: 0.888026728613, Index: (Weapon : 24, Target : 68)
# not enough Missile for Target 68
# Value: 0.887842368443, Index: (Weapon : 28, Target : 82)
# not enough Missile for Target 82
# Value: 0.887739716691, Index: (Weapon : 20, Target : 36)
# not enough Missile for Target 36
# Value: 0.887732908575, Index: (Weapon : 42, Target : 98)
# not enough Missile for Target 98
# Value: 0.887724898331, Index: (Weapon : 27, Target : 65)
# not enough Missile for Target 65
# Value: 0.887703524125, Index: (Weapon : 49, Target : 94)
# not enough Missile for Target 94
# Value: 0.88762790408, Index: (Weapon : 22, Target : 91)
# not enough Missile for Target 91
# Value: 0.887391405389, Index: (Weapon : 28, Target : 31)
# not enough Missile for Target 31
# Value: 0.887306683201, Index: (Weapon : 48, Target : 43)
# not enough Missile for Target 43
# Value: 0.886978407887, Index: (Weapon : 28, Target : 98)
# not enough Missile for Target 98
# Value: 0.88629517834, Index: (Weapon : 47, Target : 3)
# not enough Missile for Target 3
# Value: 0.886286498747, Index: (Weapon : 21, Target : 60)
# not enough Missile for Target 60
# Value: 0.886080578137, Index: (Weapon : 15, Target : 69)
# not enough Missile for Target 69
# Value: 0.886057349196, Index: (Weapon : 39, Target : 80)
# not enough Missile for Target 80
# Value: 0.885952458447, Index: (Weapon : 30, Target : 82)
# not enough Missile for Target 82
# Value: 0.885811026001, Index: (Weapon : 28, Target : 78)
# not enough Missile for Target 78
# Value: 0.885759765738, Index: (Weapon : 34, Target : 68)
# not enough Missile for Target 68
# Value: 0.885657976764, Index: (Weapon : 23, Target : 8)
# not enough Missile for Target 8
# Value: 0.885544942, Index: (Weapon : 3, Target : 79)
# not enough Missile for Target 79
# Value: 0.885393319166, Index: (Weapon : 46, Target : 34)
# not enough Missile for Target 34
# Value: 0.885271948517, Index: (Weapon : 40, Target : 25)
# not enough Missile for Target 25
# Value: 0.885216857698, Index: (Weapon : 40, Target : 6)
# not enough Missile for Target 6
# Value: 0.885210949909, Index: (Weapon : 0, Target : 36)
# not enough Missile for Target 36
# Value: 0.884996512799, Index: (Weapon : 13, Target : 84)
# not enough Missile for Target 84
# Value: 0.884952087683, Index: (Weapon : 4, Target : 97)
# not enough Missile on Weapon 4
# Value: 0.884618154418, Index: (Weapon : 43, Target : 47)
# not enough Missile for Target 47
# Value: 0.884201879312, Index: (Weapon : 12, Target : 97)
# not enough Missile on Weapon 12
# Value: 0.88399650521, Index: (Weapon : 17, Target : 46)
# not enough Missile for Target 46
# Value: 0.883995830336, Index: (Weapon : 25, Target : 77)
# not enough Missile for Target 77
# Value: 0.883828903944, Index: (Weapon : 46, Target : 82)
# not enough Missile for Target 82
# Value: 0.883810491607, Index: (Weapon : 20, Target : 21)
# not enough Missile for Target 21
# Value: 0.883662363331, Index: (Weapon : 26, Target : 71)
# not enough Missile for Target 71
# Value: 0.883583611985, Index: (Weapon : 1, Target : 21)
# not enough Missile for Target 21
# Value: 0.883410600976, Index: (Weapon : 13, Target : 17)
# not enough Missile for Target 17
# Value: 0.8833370344, Index: (Weapon : 47, Target : 64)
# not enough Missile on Weapon 47
# Value: 0.883228337251, Index: (Weapon : 19, Target : 62)
# not enough Missile for Target 62
# Value: 0.882561222359, Index: (Weapon : 30, Target : 69)
# not enough Missile for Target 69
# Value: 0.882400216003, Index: (Weapon : 0, Target : 61)
# not enough Missile on Weapon 0
# Value: 0.882335824115, Index: (Weapon : 38, Target : 97)
# Value: 0.882331114238, Index: (Weapon : 41, Target : 65)
# not enough Missile for Target 65
# Value: 0.882282163577, Index: (Weapon : 21, Target : 27)
# not enough Missile for Target 27
# Value: 0.8822685389, Index: (Weapon : 30, Target : 78)
# not enough Missile for Target 78
# Value: 0.882237009516, Index: (Weapon : 44, Target : 31)
# not enough Missile for Target 31
# Value: 0.881832297958, Index: (Weapon : 21, Target : 31)
# ...
# Value: 0.0470692155926, Index: (Weapon : 31, Target : 32)
# not enough Missile for Target 32
# Value: 0.0469523475793, Index: (Weapon : 42, Target : 27)
# not enough Missile for Target 27
# Value: 0.0469238024661, Index: (Weapon : 31, Target : 83)
# not enough Missile for Target 83
# Value: 0.0465185275374, Index: (Weapon : 18, Target : 63)
# not enough Missile for Target 63
# Value: 0.0463777849185, Index: (Weapon : 3, Target : 57)
# not enough Missile for Target 57
# Value: 0.0462825973038, Index: (Weapon : 11, Target : 22)
# not enough Missile for Target 22
# Value: 0.0461584053015, Index: (Weapon : 24, Target : 82)
# not enough Missile for Target 82
# Value: 0.046157408853, Index: (Weapon : 2, Target : 82)
# not enough Missile for Target 82
# Value: 0.0460433666364, Index: (Weapon : 3, Target : 16)
# not enough Missile for Target 16
# Value: 0.0457689547797, Index: (Weapon : 28, Target : 9)
# not enough Missile for Target 9
# Value: 0.0454479088274, Index: (Weapon : 42, Target : 2)
# not enough Missile for Target 2
# Value: 0.0454381088434, Index: (Weapon : 9, Target : 45)
# not enough Missile for Target 45
# Value: 0.0452061742653, Index: (Weapon : 39, Target : 64)
# not enough Missile for Target 64
# Value: 0.0450957245958, Index: (Weapon : 11, Target : 44)
# not enough Missile for Target 44
# Value: 0.0448169940745, Index: (Weapon : 21, Target : 43)
# not enough Missile for Target 43
# Value: 0.0444581946832, Index: (Weapon : 3, Target : 94)
# not enough Missile for Target 94
# Value: 0.0444425829277, Index: (Weapon : 25, Target : 50)
# not enough Missile for Target 50
# Value: 0.0444052601938, Index: (Weapon : 10, Target : 85)
# not enough Missile for Target 85
# Value: 0.0440788961103, Index: (Weapon : 1, Target : 74)
# not enough Missile for Target 74
# Value: 0.0439867834542, Index: (Weapon : 14, Target : 12)
# not enough Missile for Target 12
# Value: 0.0439594751105, Index: (Weapon : 10, Target : 9)
# not enough Missile for Target 9
# Value: 0.043746358193, Index: (Weapon : 1, Target : 38)
# not enough Missile for Target 38
# Value: 0.0435794978199, Index: (Weapon : 44, Target : 5)
# not enough Missile for Target 5
# Value: 0.0433914111267, Index: (Weapon : 40, Target : 38)
# not enough Missile for Target 38
# Value: 0.0431370848767, Index: (Weapon : 22, Target : 62)
# not enough Missile for Target 62
# Value: 0.043091007723, Index: (Weapon : 47, Target : 96)
# not enough Missile for Target 96
# Value: 0.0430171417668, Index: (Weapon : 21, Target : 22)
# not enough Missile for Target 22
# Value: 0.0429798181972, Index: (Weapon : 12, Target : 59)
# not enough Missile for Target 59
# Value: 0.0429688126555, Index: (Weapon : 47, Target : 46)
# not enough Missile for Target 46
# Value: 0.0427664233813, Index: (Weapon : 22, Target : 9)
# not enough Missile for Target 9
# Value: 0.0426805449353, Index: (Weapon : 30, Target : 79)
# not enough Missile for Target 79
# Value: 0.0424567251347, Index: (Weapon : 14, Target : 15)
# not enough Missile for Target 15
# Value: 0.042213232808, Index: (Weapon : 28, Target : 80)
# not enough Missile for Target 80
# Value: 0.0420873000978, Index: (Weapon : 2, Target : 32)
# not enough Missile for Target 32
# Value: 0.0415253285753, Index: (Weapon : 10, Target : 35)
# not enough Missile for Target 35
# Value: 0.0415231069516, Index: (Weapon : 2, Target : 30)
# not enough Missile for Target 30
# Value: 0.0412312363352, Index: (Weapon : 29, Target : 4)
# not enough Missile for Target 4
# Value: 0.0405959718183, Index: (Weapon : 28, Target : 68)
# not enough Missile for Target 68
# Value: 0.0405198675014, Index: (Weapon : 8, Target : 46)
# not enough Missile for Target 46
# Value: 0.0398705386321, Index: (Weapon : 13, Target : 83)
# not enough Missile for Target 83
# Value: 0.0397693875043, Index: (Weapon : 32, Target : 89)
# not enough Missile for Target 89
# Value: 0.0397244032181, Index: (Weapon : 4, Target : 83)
# not enough Missile for Target 83
# Value: 0.0396604777395, Index: (Weapon : 29, Target : 58)
# not enough Missile for Target 58
# Value: 0.0392349156174, Index: (Weapon : 36, Target : 37)
# not enough Missile for Target 37
# Value: 0.0390370335593, Index: (Weapon : 46, Target : 40)
# not enough Missile for Target 40
# Value: 0.0389728195427, Index: (Weapon : 2, Target : 10)
# not enough Missile for Target 10
# Value: 0.0389603890753, Index: (Weapon : 20, Target : 59)
# not enough Missile for Target 59
# Value: 0.0386094225308, Index: (Weapon : 47, Target : 14)
# not enough Missile for Target 14
# Value: 0.0385547471067, Index: (Weapon : 13, Target : 14)
# not enough Missile for Target 14
# Value: 0.0380798226072, Index: (Weapon : 19, Target : 84)
# not enough Missile for Target 84
# Value: 0.0379475716826, Index: (Weapon : 30, Target : 59)
# not enough Missile for Target 59
# Value: 0.0377246931875, Index: (Weapon : 28, Target : 49)
# not enough Missile for Target 49
# Value: 0.0376651305928, Index: (Weapon : 11, Target : 29)
# not enough Missile for Target 29
# Value: 0.0376391037776, Index: (Weapon : 0, Target : 5)
# not enough Missile for Target 5
# Value: 0.0376039891871, Index: (Weapon : 30, Target : 71)
# not enough Missile for Target 71
# Value: 0.0374780938244, Index: (Weapon : 3, Target : 26)
# not enough Missile for Target 26
# Value: 0.0372795738345, Index: (Weapon : 36, Target : 61)
# not enough Missile for Target 61
# Value: 0.0370337908096, Index: (Weapon : 23, Target : 31)
# not enough Missile for Target 31
# Value: 0.0370013883356, Index: (Weapon : 41, Target : 23)
# not enough Missile for Target 23
# Value: 0.036937083941, Index: (Weapon : 25, Target : 49)
# not enough Missile for Target 49
# Value: 0.0365984447556, Index: (Weapon : 15, Target : 70)
# not enough Missile for Target 70
# Value: 0.036205915519, Index: (Weapon : 23, Target : 66)
# not enough Missile for Target 66
# Value: 0.0359139551022, Index: (Weapon : 31, Target : 4)
# not enough Missile for Target 4
# Value: 0.0355449511873, Index: (Weapon : 5, Target : 8)
# not enough Missile for Target 8
# Value: 0.0349400566401, Index: (Weapon : 4, Target : 32)
# not enough Missile for Target 32
# Value: 0.034917143004, Index: (Weapon : 34, Target : 14)
# not enough Missile for Target 14
# Value: 0.0347857277682, Index: (Weapon : 32, Target : 20)
# not enough Missile for Target 20
# Value: 0.0346138809549, Index: (Weapon : 28, Target : 5)
# not enough Missile for Target 5
# Value: 0.0345187549296, Index: (Weapon : 31, Target : 58)
# not enough Missile for Target 58
# Value: 0.0344855432067, Index: (Weapon : 41, Target : 45)
# not enough Missile for Target 45
# Value: 0.0340336329145, Index: (Weapon : 32, Target : 90)
# not enough Missile for Target 90
# Value: 0.0338641007574, Index: (Weapon : 43, Target : 60)
# not enough Missile for Target 60
# Value: 0.0337342144749, Index: (Weapon : 38, Target : 91)
# not enough Missile for Target 91
# Value: 0.0329901768854, Index: (Weapon : 31, Target : 18)
# not enough Missile on Weapon 31
# Value: 0.03274388574, Index: (Weapon : 17, Target : 28)
# not enough Missile for Target 28
# Value: 0.0322959003161, Index: (Weapon : 16, Target : 28)
# not enough Missile for Target 28
# Value: 0.0322258798917, Index: (Weapon : 49, Target : 11)
# not enough Missile for Target 11
# Value: 0.0322127251367, Index: (Weapon : 24, Target : 2)
# not enough Missile for Target 2
# Value: 0.0320163547167, Index: (Weapon : 15, Target : 24)
# not enough Missile for Target 24
# Value: 0.0319869986304, Index: (Weapon : 12, Target : 29)
# not enough Missile for Target 29
# Value: 0.0319479324037, Index: (Weapon : 4, Target : 57)
# not enough Missile for Target 57
# Value: 0.0319262856778, Index: (Weapon : 40, Target : 90)
# not enough Missile for Target 90
# Value: 0.0317630352014, Index: (Weapon : 45, Target : 7)
# not enough Missile for Target 7
# Value: 0.0315898764223, Index: (Weapon : 30, Target : 77)
# not enough Missile for Target 77
# Value: 0.0313398891875, Index: (Weapon : 4, Target : 60)
# not enough Missile for Target 60
# Value: 0.0313299394708, Index: (Weapon : 18, Target : 41)
# not enough Missile for Target 41
# Value: 0.0311618211991, Index: (Weapon : 5, Target : 25)
# not enough Missile for Target 25
# Value: 0.0303718696397, Index: (Weapon : 34, Target : 88)
# not enough Missile for Target 88
# Value: 0.0301854024672, Index: (Weapon : 31, Target : 21)
# not enough Missile for Target 21
# Value: 0.0300506781513, Index: (Weapon : 25, Target : 44)
# not enough Missile for Target 44
# Value: 0.0300059212355, Index: (Weapon : 18, Target : 24)
# not enough Missile for Target 24
# Value: 0.029777981549, Index: (Weapon : 1, Target : 63)
# not enough Missile for Target 63
# Value: 0.029734966846, Index: (Weapon : 10, Target : 38)
# not enough Missile for Target 38
# Value: 0.0294777424923, Index: (Weapon : 3, Target : 59)
# not enough Missile for Target 59
# Value: 0.0292864377629, Index: (Weapon : 17, Target : 54)
# not enough Missile for Target 54
# Value: 0.0288040331352, Index: (Weapon : 6, Target : 90)
# not enough Missile for Target 90
# Value: 0.0285063682055, Index: (Weapon : 17, Target : 57)
# not enough Missile for Target 57
# Value: 0.0283084123503, Index: (Weapon : 25, Target : 12)
# not enough Missile for Target 12
# Value: 0.0281206145387, Index: (Weapon : 11, Target : 16)
# not enough Missile for Target 16
# Value: 0.0279795285636, Index: (Weapon : 4, Target : 2)
# not enough Missile for Target 2
# Value: 0.0279412844141, Index: (Weapon : 26, Target : 29)
# not enough Missile for Target 29
# Value: 0.0269518626897, Index: (Weapon : 7, Target : 92)
# not enough Missile for Target 92
# Value: 0.0269447519369, Index: (Weapon : 34, Target : 79)
# not enough Missile for Target 79
# Value: 0.026296303478, Index: (Weapon : 11, Target : 72)
# not enough Missile for Target 72
# Value: 0.0259837845413, Index: (Weapon : 19, Target : 42)
# not enough Missile for Target 42
# Value: 0.025387126041, Index: (Weapon : 29, Target : 42)
# not enough Missile for Target 42
# Value: 0.0245909830251, Index: (Weapon : 28, Target : 56)
# not enough Missile for Target 56
# Value: 0.0242656547094, Index: (Weapon : 22, Target : 73)
# not enough Missile for Target 73
# Value: 0.0242488588863, Index: (Weapon : 10, Target : 76)
# not enough Missile for Target 76
# Value: 0.0241626477965, Index: (Weapon : 23, Target : 41)
# not enough Missile for Target 41
# Value: 0.0241420240661, Index: (Weapon : 16, Target : 47)
# not enough Missile for Target 47
# Value: 0.0241067316394, Index: (Weapon : 37, Target : 32)
# not enough Missile for Target 32
# Value: 0.0233505637659, Index: (Weapon : 10, Target : 24)
# not enough Missile for Target 24
# Value: 0.0232114303025, Index: (Weapon : 31, Target : 35)
# not enough Missile for Target 35
# Value: 0.0229955389777, Index: (Weapon : 41, Target : 77)
# not enough Missile for Target 77
# Value: 0.0225390359965, Index: (Weapon : 3, Target : 98)
# not enough Missile for Target 98
# Value: 0.0224325010541, Index: (Weapon : 21, Target : 61)
# not enough Missile for Target 61
# Value: 0.0224146213333, Index: (Weapon : 4, Target : 55)
# not enough Missile for Target 55
# Value: 0.0222955440239, Index: (Weapon : 49, Target : 46)
# not enough Missile for Target 46
# Value: 0.0222919631756, Index: (Weapon : 10, Target : 67)
# not enough Missile for Target 67
# Value: 0.0222484562742, Index: (Weapon : 30, Target : 61)
# not enough Missile for Target 61
# Value: 0.0222104754729, Index: (Weapon : 6, Target : 65)
# not enough Missile for Target 65
# Value: 0.0221445920557, Index: (Weapon : 20, Target : 70)
# not enough Missile for Target 70
# Value: 0.022036761172, Index: (Weapon : 42, Target : 50)
# not enough Missile for Target 50
# Value: 0.0219177648613, Index: (Weapon : 34, Target : 49)
# not enough Missile for Target 49
# Value: 0.0219175261912, Index: (Weapon : 5, Target : 53)
# not enough Missile for Target 53
# Value: 0.021846862391, Index: (Weapon : 42, Target : 0)
# not enough Missile for Target 0
# Value: 0.0216427783471, Index: (Weapon : 32, Target : 68)
# not enough Missile for Target 68
# Value: 0.0215838740296, Index: (Weapon : 19, Target : 94)
# not enough Missile for Target 94
# Value: 0.02157047465, Index: (Weapon : 1, Target : 60)
# not enough Missile for Target 60
# Value: 0.0215655740858, Index: (Weapon : 32, Target : 54)
# not enough Missile for Target 54
# Value: 0.0215319120543, Index: (Weapon : 13, Target : 21)
# not enough Missile for Target 21
# Value: 0.0213266450059, Index: (Weapon : 39, Target : 11)
# not enough Missile for Target 11
# Value: 0.0211011323519, Index: (Weapon : 28, Target : 79)
# not enough Missile for Target 79
# Value: 0.020916510392, Index: (Weapon : 14, Target : 67)
# not enough Missile for Target 67
# Value: 0.0207897370997, Index: (Weapon : 25, Target : 90)
# not enough Missile for Target 90
# Value: 0.0206702691882, Index: (Weapon : 33, Target : 22)
# not enough Missile for Target 22
# Value: 0.0205539066152, Index: (Weapon : 31, Target : 61)
# not enough Missile for Target 61
# Value: 0.0204435830217, Index: (Weapon : 49, Target : 27)
# not enough Missile for Target 27
# Value: 0.0203373639227, Index: (Weapon : 8, Target : 44)
# not enough Missile for Target 44
# Value: 0.0188341524188, Index: (Weapon : 28, Target : 1)
# not enough Missile for Target 1
# Value: 0.018505107219, Index: (Weapon : 4, Target : 47)
# not enough Missile for Target 47
# Value: 0.0184133115573, Index: (Weapon : 21, Target : 38)
# not enough Missile for Target 38
# Value: 0.0183872849035, Index: (Weapon : 14, Target : 18)
# not enough Missile on Weapon 14
# Value: 0.018182723131, Index: (Weapon : 45, Target : 28)
# not enough Missile for Target 28
# Value: 0.0180640200716, Index: (Weapon : 36, Target : 99)
# not enough Missile for Target 99
# Value: 0.0178206428707, Index: (Weapon : 42, Target : 6)
# not enough Missile for Target 6
# Value: 0.017575348161, Index: (Weapon : 41, Target : 79)
# not enough Missile for Target 79
# Value: 0.0175704530518, Index: (Weapon : 39, Target : 12)
# not enough Missile for Target 12
# Value: 0.017544996369, Index: (Weapon : 45, Target : 18)
# not enough Missile on Weapon 45
# Value: 0.0172002030927, Index: (Weapon : 21, Target : 83)
# not enough Missile for Target 83
# Value: 0.0171635409954, Index: (Weapon : 3, Target : 28)
# not enough Missile for Target 28
# Value: 0.0171328063053, Index: (Weapon : 20, Target : 66)
# not enough Missile for Target 66
# Value: 0.0170241102253, Index: (Weapon : 36, Target : 74)
# not enough Missile for Target 74
# Value: 0.0166841692368, Index: (Weapon : 3, Target : 66)
# not enough Missile for Target 66
# Value: 0.0164985630648, Index: (Weapon : 26, Target : 55)
# not enough Missile for Target 55
# Value: 0.01642823907, Index: (Weapon : 32, Target : 65)
# not enough Missile for Target 65
# Value: 0.016272717084, Index: (Weapon : 31, Target : 96)
# not enough Missile for Target 96
# Value: 0.0162625798554, Index: (Weapon : 10, Target : 51)
# not enough Missile for Target 51
# Value: 0.016209416386, Index: (Weapon : 30, Target : 63)
# not enough Missile for Target 63
# Value: 0.0159880630721, Index: (Weapon : 42, Target : 59)
# not enough Missile for Target 59
# Value: 0.0158647545397, Index: (Weapon : 4, Target : 73)
# not enough Missile for Target 73
# Value: 0.015678741884, Index: (Weapon : 48, Target : 60)
# not enough Missile for Target 60
# Value: 0.0155372147048, Index: (Weapon : 12, Target : 40)
# not enough Missile for Target 40
# Value: 0.0155151991702, Index: (Weapon : 42, Target : 67)
# not enough Missile for Target 67
# Value: 0.015477577096, Index: (Weapon : 28, Target : 91)
# not enough Missile for Target 91
# Value: 0.0154196242669, Index: (Weapon : 16, Target : 16)
# not enough Missile for Target 16
# Value: 0.0152626597623, Index: (Weapon : 0, Target : 81)
# not enough Missile for Target 81
# Value: 0.0149885076328, Index: (Weapon : 20, Target : 10)
# not enough Missile for Target 10
# Value: 0.0148776955343, Index: (Weapon : 24, Target : 42)
# not enough Missile for Target 42
# Value: 0.0147782358534, Index: (Weapon : 30, Target : 38)
# not enough Missile for Target 38
# Value: 0.0144655778723, Index: (Weapon : 35, Target : 52)
# not enough Missile for Target 52
# Value: 0.0142790462378, Index: (Weapon : 37, Target : 34)
# not enough Missile for Target 34
# Value: 0.014007433663, Index: (Weapon : 43, Target : 54)
# not enough Missile for Target 54
# Value: 0.0139974807389, Index: (Weapon : 8, Target : 17)
# not enough Missile for Target 17
# Value: 0.013935152946, Index: (Weapon : 17, Target : 92)
# not enough Missile for Target 92
# Value: 0.013932428545, Index: (Weapon : 48, Target : 18)

# %%
def simulation(theta_wt):
    W, T, M = theta_wt.shape
    result = []
    for m in range(M):
        indices = np.where(theta_wt[:,:,m] == 1)
        if len(indices[0]) == 0 :
            continue
        w = int(indices[0])
        t = int(indices[1])



        PK = PK_wt[w][t]
        result.append( [w, t, m, PK])

    if constraint2(theta_wt):
        print("제약조건 2 충족")
    if constraint3(theta_wt):
        print("제약조건 3 충족")
    # if constraint4(tau):
    #     print("제약조건 4 충족")
    # if constraint5(tau, theta_wt):
        print("제약조건 5 충족")
    if constraint6(theta_wt):
        print("제약조건 6 충족")

    result.sort()
    for res in result:

        print(f"발사대 {res[0]}, 타깃 {res[1]}을 향해 미사일 {res[2]} 발사, 요격 확률 : {res[3]:.2f}")

    objective_value = objective_fun_1(theta_wt)

    print(f"목표함수 값 : {objective_value}")

# %%
simulation(theta_wt)
# Out:
# 제약조건 2 충족
# 제약조건 3 충족
# 제약조건 5 충족
# 제약조건 6 충족
# 발사대 0, 타깃 31을 향해 미사일 57 발사, 요격 확률 : 0.97
# 발사대 0, 타깃 37을 향해 미사일 31 발사, 요격 확률 : 0.99
# 발사대 1, 타깃 12을 향해 미사일 74 발사, 요격 확률 : 0.96
# 발사대 1, 타깃 95을 향해 미사일 20 발사, 요격 확률 : 1.00
# 발사대 2, 타깃 19을 향해 미사일 51 발사, 요격 확률 : 0.98
# 발사대 2, 타깃 65을 향해 미사일 64 발사, 요격 확률 : 0.97
# 발사대 3, 타깃 39을 향해 미사일 78 발사, 요격 확률 : 0.95
# 발사대 3, 타깃 87을 향해 미사일 43 발사, 요격 확률 : 0.99
# 발사대 4, 타깃 43을 향해 미사일 23 발사, 요격 확률 : 0.99
# 발사대 4, 타깃 86을 향해 미사일 36 발사, 요격 확률 : 0.99
# 발사대 5, 타깃 55을 향해 미사일 67 발사, 요격 확률 : 0.97
# 발사대 5, 타깃 64을 향해 미사일 97 발사, 요격 확률 : 0.69
# 발사대 6, 타깃 22을 향해 미사일 92 발사, 요격 확률 : 0.86
# 발사대 6, 타깃 45을 향해 미사일 83 발사, 요격 확률 : 0.92
# 발사대 7, 타깃 7을 향해 미사일 66 발사, 요격 확률 : 0.97
# 발사대 7, 타깃 58을 향해 미사일 17 발사, 요격 확률 : 1.00
# 발사대 8, 타깃 90을 향해 미사일 76 발사, 요격 확률 : 0.96
# 발사대 8, 타깃 92을 향해 미사일 54 발사, 요격 확률 : 0.98
# 발사대 9, 타깃 33을 향해 미사일 12 발사, 요격 확률 : 1.00
# 발사대 9, 타깃 66을 향해 미사일 1 발사, 요격 확률 : 1.00
# 발사대 10, 타깃 47을 향해 미사일 3 발사, 요격 확률 : 1.00
# 발사대 10, 타깃 54을 향해 미사일 25 발사, 요격 확률 : 0.99
# 발사대 11, 타깃 32을 향해 미사일 85 발사, 요격 확률 : 0.92
# 발사대 11, 타깃 99을 향해 미사일 24 발사, 요격 확률 : 0.99
# 발사대 12, 타깃 5을 향해 미사일 18 발사, 요격 확률 : 1.00
# 발사대 12, 타깃 27을 향해 미사일 7 발사, 요격 확률 : 1.00
# 발사대 13, 타깃 13을 향해 미사일 14 발사, 요격 확률 : 1.00
# 발사대 13, 타깃 62을 향해 미사일 4 발사, 요격 확률 : 1.00
# 발사대 14, 타깃 79을 향해 미사일 0 발사, 요격 확률 : 1.00
# 발사대 14, 타깃 85을 향해 미사일 52 발사, 요격 확률 : 0.98
# 발사대 15, 타깃 4을 향해 미사일 32 발사, 요격 확률 : 0.99
# 발사대 15, 타깃 46을 향해 미사일 46 발사, 요격 확률 : 0.99
# 발사대 16, 타깃 78을 향해 미사일 60 발사, 요격 확률 : 0.97
# 발사대 16, 타깃 93을 향해 미사일 86 발사, 요격 확률 : 0.91
# 발사대 17, 타깃 34을 향해 미사일 45 발사, 요격 확률 : 0.99
# 발사대 17, 타깃 96을 향해 미사일 13 발사, 요격 확률 : 1.00
# 발사대 18, 타깃 0을 향해 미사일 34 발사, 요격 확률 : 0.99
# 발사대 18, 타깃 36을 향해 미사일 38 발사, 요격 확률 : 0.99
# 발사대 19, 타깃 14을 향해 미사일 6 발사, 요격 확률 : 1.00
# 발사대 19, 타깃 73을 향해 미사일 2 발사, 요격 확률 : 1.00
# 발사대 20, 타깃 40을 향해 미사일 47 발사, 요격 확률 : 0.98
# 발사대 20, 타깃 89을 향해 미사일 62 발사, 요격 확률 : 0.97
# 발사대 21, 타깃 67을 향해 미사일 71 발사, 요격 확률 : 0.96
# 발사대 21, 타깃 82을 향해 미사일 87 발사, 요격 확률 : 0.90
# 발사대 22, 타깃 17을 향해 미사일 59 발사, 요격 확률 : 0.97
# 발사대 22, 타깃 76을 향해 미사일 72 발사, 요격 확률 : 0.96
# 발사대 23, 타깃 52을 향해 미사일 65 발사, 요격 확률 : 0.97
# 발사대 23, 타깃 69을 향해 미사일 15 발사, 요격 확률 : 1.00
# 발사대 24, 타깃 51을 향해 미사일 37 발사, 요격 확률 : 0.99
# 발사대 24, 타깃 71을 향해 미사일 50 발사, 요격 확률 : 0.98
# 발사대 25, 타깃 74을 향해 미사일 19 발사, 요격 확률 : 1.00
# 발사대 25, 타깃 91을 향해 미사일 9 발사, 요격 확률 : 1.00
# 발사대 26, 타깃 1을 향해 미사일 8 발사, 요격 확률 : 1.00
# 발사대 26, 타깃 63을 향해 미사일 11 발사, 요격 확률 : 1.00
# 발사대 27, 타깃 48을 향해 미사일 5 발사, 요격 확률 : 1.00
# 발사대 27, 타깃 49을 향해 미사일 44 발사, 요격 확률 : 0.99
# 발사대 28, 타깃 23을 향해 미사일 55 발사, 요격 확률 : 0.98
# 발사대 28, 타깃 83을 향해 미사일 96 발사, 요격 확률 : 0.78
# 발사대 29, 타깃 11을 향해 미사일 90 발사, 요격 확률 : 0.88
# 발사대 29, 타깃 38을 향해 미사일 27 발사, 요격 확률 : 0.99
# 발사대 30, 타깃 21을 향해 미사일 53 발사, 요격 확률 : 0.98
# 발사대 30, 타깃 42을 향해 미사일 21 발사, 요격 확률 : 0.99
# 발사대 31, 타깃 20을 향해 미사일 26 발사, 요격 확률 : 0.99
# 발사대 31, 타깃 28을 향해 미사일 61 발사, 요격 확률 : 0.97
# 발사대 32, 타깃 2을 향해 미사일 94 발사, 요격 확률 : 0.84
# 발사대 32, 타깃 41을 향해 미사일 98 발사, 요격 확률 : 0.66
# 발사대 33, 타깃 10을 향해 미사일 68 발사, 요격 확률 : 0.97
# 발사대 33, 타깃 88을 향해 미사일 77 발사, 요격 확률 : 0.95
# 발사대 34, 타깃 9을 향해 미사일 22 발사, 요격 확률 : 0.99
# 발사대 34, 타깃 94을 향해 미사일 79 발사, 요격 확률 : 0.94
# 발사대 35, 타깃 50을 향해 미사일 58 발사, 요격 확률 : 0.97
# 발사대 35, 타깃 57을 향해 미사일 81 발사, 요격 확률 : 0.93
# 발사대 36, 타깃 44을 향해 미사일 73 발사, 요격 확률 : 0.96
# 발사대 36, 타깃 59을 향해 미사일 91 발사, 요격 확률 : 0.86
# 발사대 37, 타깃 30을 향해 미사일 40 발사, 요격 확률 : 0.99
# 발사대 37, 타깃 72을 향해 미사일 10 발사, 요격 확률 : 1.00
# 발사대 38, 타깃 68을 향해 미사일 84 발사, 요격 확률 : 0.92
# 발사대 38, 타깃 97을 향해 미사일 89 발사, 요격 확률 : 0.88
# 발사대 39, 타깃 24을 향해 미사일 39 발사, 요격 확률 : 0.99
# 발사대 39, 타깃 98을 향해 미사일 16 발사, 요격 확률 : 1.00
# 발사대 40, 타깃 29을 향해 미사일 30 발사, 요격 확률 : 0.99
# 발사대 40, 타깃 53을 향해 미사일 63 발사, 요격 확률 : 0.97
# 발사대 41, 타깃 3을 향해 미사일 28 발사, 요격 확률 : 0.99
# 발사대 41, 타깃 25을 향해 미사일 82 발사, 요격 확률 : 0.93
# 발사대 42, 타깃 75을 향해 미사일 49 발사, 요격 확률 : 0.98
# 발사대 42, 타깃 84을 향해 미사일 48 발사, 요격 확률 : 0.98
# 발사대 43, 타깃 26을 향해 미사일 35 발사, 요격 확률 : 0.99
# 발사대 43, 타깃 35을 향해 미사일 33 발사, 요격 확률 : 0.99
# 발사대 44, 타깃 6을 향해 미사일 42 발사, 요격 확률 : 0.99
# 발사대 44, 타깃 56을 향해 미사일 29 발사, 요격 확률 : 0.99
# 발사대 45, 타깃 15을 향해 미사일 80 발사, 요격 확률 : 0.94
# 발사대 45, 타깃 60을 향해 미사일 56 발사, 요격 확률 : 0.98
# 발사대 46, 타깃 8을 향해 미사일 75 발사, 요격 확률 : 0.96
# 발사대 46, 타깃 61을 향해 미사일 95 발사, 요격 확률 : 0.80
# 발사대 47, 타깃 70을 향해 미사일 41 발사, 요격 확률 : 0.99
# 발사대 47, 타깃 77을 향해 미사일 88 발사, 요격 확률 : 0.90
# 발사대 48, 타깃 16을 향해 미사일 93 발사, 요격 확률 : 0.85
# 발사대 48, 타깃 18을 향해 미사일 99 발사, 요격 확률 : 0.01
# 발사대 49, 타깃 80을 향해 미사일 70 발사, 요격 확률 : 0.96
# 발사대 49, 타깃 81을 향해 미사일 69 발사, 요격 확률 : 0.97
# 목표함수 값 : 95.08135945203703
