# %% [markdown]
# 1. $m_w$ 추가 발사대에 적재된 유도탄 수량, M을 W로 나눈 뒤 남은 값은 w_1 부터 차레로 적재
#
# ---
#
# # 230828
# 제약 조건 (4), (5) 구현 시도
#
# - 한 발사대가 연속발사를 하기 위해서는 발사절차 및 발사대 안정화를 위한 시간을 고려하여야 하므로, 수식 (4)과 같이 한 발사대 상의 연속적 발사를 위한 최소 발사 간격을 제약으로 고려한다.
# - 각 발사대에서 발사된 유도탄은 제한된 공간 영역 상에서 표적을 요격할 수 있다. 표적의 예상 궤적과 발사대 위치에 따른 요격 공간으로부터 교전 가능한 유도탄 발사 시간이 계산되어진다. 위협 표적에 대해서 교전 가능한 발사 시간 구간 내에서 발사 시점이 산출되어야만 교전 가능하므로, 수식 (5)와 같이 표적 $t$에 대한 발사대 $w$에서 발사 가능한 시간에 대한 제약 조건을 고려해야 한다.
#
# - 문제는 요격탄 발사 간격이 1초일 경우, 제한된 시간이 10초 이내 라면, 10개 이상을 발사할 수가 없을텐데,

# %%
import numpy as np
# 시드를 고정
np.random.seed(42)

# 발사대를 5대로 가정하여 진행
W = 5
# 위협 표적의 개수를 10개에서 100개까지 10개씩 증가시키며 실행
T = 100
# 표적 t에 할당할 수 있는 유도탄의 개수는 1개로 가정
FN_T = [1] * T

M = sum(FN_T)

# 0에서 4 사이의 랜덤한 값으로 구성된 W*T 행렬 생성 : 최초발사가능시점
ft_wt = np.random.rand(W, T) * 4

# 최소 3초 이상의 간격을 갖도록 설정
min_lt_wt = ft_wt + 3

# 발사가능시점으로부터 최소 3초 이상~ 전체 시간 10초 이내의 간격 행렬 생성
inter_lt_wt = 10 - min_lt_wt

# 3에서 10 사이의 랜덤한 값으로 구성된 W*T 행렬 생성 : 최후발사가능시점
lt_wt = np.random.rand(W, T) * inter_lt_wt + min_lt_wt

# 최초발사가능 시점과 최후발사가능 시점 사이의 간격이 3초 이상을 갖는지 확인
time_intervals_diff = lt_wt - ft_wt

# 0과 99 사이의 실수로 PK_wt 배열 초기화
PK_wt = np.random.uniform(0, 99, (W, T))

# 표적 t에 발사대 w를 할당할 때의 보상(요격확률) 행렬 생성
# PK_wt = np.random.rand(W, T)

# %%
# tau 정의 : 발사대 w에서 유도탄 m의 발사 시점 (튜플(발사시점, 유도탄 m)로 구성된 리스트)

# 발사대 만큼의 빈 리스트로 구성
tau = [[] for _ in range(W)]

# %%
# M을 W로 나누어 리스트에 적절히 분배
quotient, remainder = divmod(M, W)
m_w = [quotient] * W

# 나머지 값을 리스트의 앞부분에 추가
for i in range(remainder):
    m_w[i] += 1

print(m_w)
# Out:
# [20, 20, 20, 20, 20]

# %%
"""
목표함수 (1)
해당 목적함수는 결정변수 theta_wt와 요격확률의 곱의 합을 최대화함으로써 요격확률이 높을 때 표적-발사대 쌍의 발사 시점에 무기할당을 하는 의미로 해석할 수 있다.
"""
def objective_fun_1(theta_wt):
    res = 0
    for t in range(T):
        
        a = 1
        for w in range(W):
            for m in range(M):
                p = 1 - PK_wt[w,t] * theta_wt[w,t,m]
                a *= p
        
        # print(f"타깃 {t}에 대한 성공 값 : {1-a}")
        res += 1-a
    return res

# %%
import copy
# Initialize a 3D binary matrix of zeros
theta_wt = np.zeros((W, T, M), dtype=int)

# 미사일이 소모되는 리스트 left_FN_T으로 복사
left_FN_T = copy.copy(FN_T)

# 발사대에 적재된 유도탄 수량 리스트 left_m_w로 복사
left_m_w = copy.copy(m_w)

# 행렬의 원소들을 1차원 배열로 변환
flattened = PK_wt.flatten()

# 원소들을 내림차순으로 정렬
sorted_indices = np.argsort(flattened)[::-1]


i = 0
m = 0
indices_list = []
while True :
    if i == T * W :
        break
    # i번째 요격확률의 인덱스 v
    v = sorted_indices[i]
    
    row = v // T # Weapon
    col = v % T # Target
    print(f"Value: {flattened[v]}, Index: (Weapon : {row}, Target : {col})")
    
    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있다면,
    # 해당 Weapon의 적재된 유도탄이 남아 있다면,
    if left_FN_T[col] > 0 and left_m_w[row] > 0:
        
        

        # 빈 리스트 일 경우 최초 요격 가능 시간 부여
        if len(tau[row]) == 0:
            tau[row].append((ft_wt[row][col], m))
        else : 
            last_launch_time = tau[row][-1][0]
            # 요격 가능 할 경우,
            if last_launch_time+1 <=  lt_wt[row][col] and ft_wt[row][col] <= 10:
                tau[row].append((max(last_launch_time+1.0001, ft_wt[row][col]) , m))

            else :  
                # 할당하지 않고 다음 인덱스로 이동
                i += 1
                continue
            
        
             
        # 할당할 유도탄 개수 감소
        left_FN_T[col] -= 1
        left_m_w[row] -= 1
        # 해당 W T M에 1 부여
        theta_wt[row][col][m] = 1
        # 무기가 할당된 indices_list에 추가
        indices_list.append(v)

        # 다음 미사일 인덱스로 이동
        m += 1

    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있지 않다면,
    elif left_FN_T[col] > 0:
        print(f"not enough Missile on Weapon {row}")
    
    else :
        print(f"not enough Missile for Target {col}")
    
    # 할당할 수 있는 유도탄의 개수를 모두 소모했다면 종료.
    if sum(left_FN_T) == 0:
        break
    

    # 다음으로 요격확률이 높은 인덱스로 이동
    i += 1
# Out:
# Value: 98.941958851296, Index: (Weapon : 4, Target : 64)
# Value: 98.7954769428004, Index: (Weapon : 0, Target : 54)
# Value: 98.7153255156134, Index: (Weapon : 2, Target : 9)
# Value: 98.63705768961745, Index: (Weapon : 3, Target : 33)
# Value: 98.49587444199709, Index: (Weapon : 1, Target : 4)
# Value: 98.12569398756068, Index: (Weapon : 0, Target : 88)
# Value: 97.78451658386712, Index: (Weapon : 0, Target : 74)
# Value: 97.77913279166805, Index: (Weapon : 0, Target : 11)
# Value: 97.77730680986973, Index: (Weapon : 3, Target : 48)
# Value: 97.6795967334475, Index: (Weapon : 2, Target : 77)
# Value: 97.67638217292584, Index: (Weapon : 4, Target : 24)
# Value: 97.42426345073022, Index: (Weapon : 0, Target : 61)
# Value: 97.41378714802299, Index: (Weapon : 2, Target : 28)
# Value: 97.13743162471492, Index: (Weapon : 1, Target : 71)
# Value: 66.0917451707949, Index: (Weapon : 4, Target : 75)
# Value: 66.01956149706433, Index: (Weapon : 4, Target : 33)
# not enough Missile for Target 33
# Value: 65.7166482345587, Index: (Weapon : 4, Target : 4)
# not enough Missile for Target 4
# Value: 65.22966155303307, Index: (Weapon : 4, Target : 59)
# Value: 65.21955330436101, Index: (Weapon : 0, Target : 5)
# not enough Missile for Target 5
# Value: 65.21206977458674, Index: (Weapon : 3, Target : 28)
# not enough Missile for Target 28
# Value: 65.18673163118413, Index: (Weapon : 1, Target : 47)
# Value: 65.12668515570057, Index: (Weapon : 4, Target : 63)
# Value: 65.01692978958793, Index: (Weapon : 3, Target : 84)
# not enough Missile for Target 84
# Value: 64.86895608326316, Index: (Weapon : 1, Target : 24)
# not enough Missile for Target 24
# Value: 64.7966102138324, Index: (Weapon : 2, Target : 18)
# Value: 64.51501571221262, Index: (Weapon : 2, Target : 34)
# not enough Missile for Target 34
# Value: 64.47206472710772, Index: (Weapon : 4, Target : 61)
# Value: 64.38224294834676, Index: (Weapon : 3, Target : 35)
# Value: 64.31501825024448, Index: (Weapon : 0, Target : 91)
# Value: 63.71419182445597, Index: (Weapon : 3, Target : 15)
# Value: 63.27287384373454, Index: (Weapon : 4, Target : 28)
# not enough Missile for Target 28
# Value: 63.21406881874447, Index: (Weapon : 2, Target : 25)
# Value: 63.00659470482003, Index: (Weapon : 2, Target : 98)
# Value: 62.76656460686152, Index: (Weapon : 1, Target : 74)
# not enough Missile for Target 74
# Value: 62.62956742026086, Index: (Weapon : 1, Target : 82)
# not enough Missile for Target 82
# Value: 62.54953917465017, Index: (Weapon : 1, Target : 72)
# not enough Missile for Target 72
# Value: 62.52446178915953, Index: (Weapon : 3, Target : 63)
# Value: 62.12304085861864, Index: (Weapon : 0, Target : 59)
# Value: 61.995811841510125, Index: (Weapon : 2, Target : 45)
# Value: 61.9632462672639, Index: (Weapon : 0, Target : 43)
# Value: 61.67369177278479, Index: (Weapon : 3, Target : 62)
# Value: 61.470636258980235, Index: (Weapon : 1, Target : 93)
# Value: 61.329544254951834, Index: (Weapon : 4, Target : 96)
# not enough Missile for Target 96
# Value: 61.24252644330325, Index: (Weapon : 1, Target : 54)
# not enough Missile for Target 54
# Value: 61.19741769749379, Index: (Weapon : 2, Target : 80)
# not enough Missile for Target 80
# Value: 61.16687677992017, Index: (Weapon : 4, Target : 51)
# Value: 61.09735367379898, Index: (Weapon : 3, Target : 98)
# Value: 61.07576491919848, Index: (Weapon : 1, Target : 70)
# not enough Missile for Target 70
# Value: 61.048381137553065, Index: (Weapon : 2, Target : 49)
# Value: 60.97045563004815, Index: (Weapon : 0, Target : 45)
# Value: 60.72772753186006, Index: (Weapon : 0, Target : 86)
# Value: 60.165942693007054, Index: (Weapon : 0, Target : 92)
# Value: 59.741410744756415, Index: (Weapon : 4, Target : 94)
# Value: 59.40203426381107, Index: (Weapon : 2, Target : 68)
# Value: 59.03071796972325, Index: (Weapon : 0, Target : 31)
# Value: 58.70213429205781, Index: (Weapon : 3, Target : 79)
# Value: 58.70105354932861, Index: (Weapon : 1, Target : 14)
# Value: 58.64837068129224, Index: (Weapon : 1, Target : 39)
# Value: 58.64268253074286, Index: (Weapon : 3, Target : 59)
# Value: 57.95008207527846, Index: (Weapon : 4, Target : 8)
# Value: 57.63487555745105, Index: (Weapon : 1, Target : 91)
# Value: 57.61516878952548, Index: (Weapon : 2, Target : 59)
# Value: 57.4285345759433, Index: (Weapon : 1, Target : 15)
# Value: 57.28886544866695, Index: (Weapon : 3, Target : 51)
# Value: 56.490364917244136, Index: (Weapon : 4, Target : 53)
# Value: 56.22657782471032, Index: (Weapon : 0, Target : 17)
# not enough Missile for Target 17
# Value: 56.18654397789426, Index: (Weapon : 2, Target : 92)
# Value: 56.13460983768011, Index: (Weapon : 4, Target : 70)
# not enough Missile for Target 70
# Value: 56.007464435583316, Index: (Weapon : 1, Target : 43)
# Value: 55.4052196652045, Index: (Weapon : 2, Target : 82)
# not enough Missile for Target 82
# Value: 54.98099154282549, Index: (Weapon : 3, Target : 30)
# not enough Missile for Target 30
# Value: 54.53487969030479, Index: (Weapon : 1, Target : 25)
# Value: 54.21164523921989, Index: (Weapon : 3, Target : 12)
# not enough Missile for Target 12
# Value: 53.904420698124106, Index: (Weapon : 4, Target : 82)
# not enough Missile for Target 82
# Value: 53.648193790457455, Index: (Weapon : 0, Target : 1)
# not enough Missile for Target 1
# Value: 53.58833719480597, Index: (Weapon : 3, Target : 3)
# Value: 53.585391288934915, Index: (Weapon : 1, Target : 79)
# Value: 53.45855259186969, Index: (Weapon : 1, Target : 75)
# Value: 53.40963794515839, Index: (Weapon : 0, Target : 40)
# not enough Missile for Target 40
# Value: 53.160467866447945, Index: (Weapon : 1, Target : 13)
# not enough Missile for Target 13
# Value: 52.58578327210217, Index: (Weapon : 4, Target : 14)
# Value: 52.36477626869399, Index: (Weapon : 0, Target : 51)
# Value: 52.11386343267521, Index: (Weapon : 3, Target : 16)
# Value: 51.45762090704575, Index: (Weapon : 3, Target : 93)
# Value: 51.25345269508643, Index: (Weapon : 2, Target : 85)
# Value: 51.044006829345776, Index: (Weapon : 4, Target : 31)
# Value: 50.96691803903933, Index: (Weapon : 3, Target : 77)
# not enough Missile for Target 77
# Value: 50.75616259063435, Index: (Weapon : 0, Target : 93)
# Value: 50.23930564232278, Index: (Weapon : 1, Target : 67)
# not enough Missile for Target 67
# Value: 50.21624606015085, Index: (Weapon : 4, Target : 21)
# Value: 49.38992719168425, Index: (Weapon : 2, Target : 79)
# Value: 49.32137592886076, Index: (Weapon : 3, Target : 29)
# Value: 49.2203016368343, Index: (Weapon : 4, Target : 50)
# Value: 49.09169777279831, Index: (Weapon : 1, Target : 31)
# Value: 49.01950617438346, Index: (Weapon : 1, Target : 37)
# Value: 48.73550778835544, Index: (Weapon : 3, Target : 73)
# Value: 48.66786012740225, Index: (Weapon : 2, Target : 57)
# Value: 48.45307140067091, Index: (Weapon : 0, Target : 9)
# not enough Missile for Target 9
# Value: 48.3958114454351, Index: (Weapon : 4, Target : 32)
# Value: 48.37567585006191, Index: (Weapon : 2, Target : 4)
# not enough Missile for Target 4
# Value: 48.18022520104558, Index: (Weapon : 3, Target : 54)
# not enough Missile for Target 54
# Value: 47.67071279974246, Index: (Weapon : 2, Target : 51)
# Value: 47.57807115533815, Index: (Weapon : 1, Target : 38)
# not enough Missile for Target 38
# Value: 47.57018777852507, Index: (Weapon : 2, Target : 74)
# not enough Missile for Target 74
# Value: 47.51394463699523, Index: (Weapon : 2, Target : 67)
# not enough Missile for Target 67
# Value: 47.507686410086976, Index: (Weapon : 0, Target : 58)
# Value: 46.98845669923158, Index: (Weapon : 4, Target : 5)
# not enough Missile for Target 5
# Value: 46.947207449088914, Index: (Weapon : 0, Target : 25)
# Value: 46.84778076246416, Index: (Weapon : 2, Target : 37)
# Value: 46.272749613737105, Index: (Weapon : 0, Target : 85)
# Value: 45.885910336256664, Index: (Weapon : 4, Target : 97)
# not enough Missile for Target 97
# Value: 45.799672717192315, Index: (Weapon : 3, Target : 41)
# Value: 45.06679475909832, Index: (Weapon : 2, Target : 63)
# Value: 45.01924570775205, Index: (Weapon : 4, Target : 30)
# not enough Missile for Target 30
# Value: 44.92516459698029, Index: (Weapon : 3, Target : 89)
# Value: 44.77951016731171, Index: (Weapon : 3, Target : 14)
# Value: 44.76770380006009, Index: (Weapon : 4, Target : 18)
# Value: 44.68731540863787, Index: (Weapon : 2, Target : 11)
# not enough Missile for Target 11
# Value: 44.420668639630534, Index: (Weapon : 4, Target : 89)
# Value: 44.144367931298085, Index: (Weapon : 2, Target : 7)
# not enough Missile for Target 7
# Value: 44.08522024526388, Index: (Weapon : 3, Target : 76)
# Value: 43.93127171115254, Index: (Weapon : 4, Target : 43)
# Value: 43.42292649976945, Index: (Weapon : 3, Target : 52)
# Value: 43.12274816648036, Index: (Weapon : 4, Target : 79)
# Value: 42.80114530321759, Index: (Weapon : 2, Target : 22)
# not enough Missile for Target 22
# Value: 42.65786484251879, Index: (Weapon : 3, Target : 96)
# not enough Missile for Target 96
# Value: 42.600283595046804, Index: (Weapon : 2, Target : 55)
# Value: 42.34954023985037, Index: (Weapon : 0, Target : 75)
# Value: 42.19194892136132, Index: (Weapon : 2, Target : 10)
# Value: 42.12384011035946, Index: (Weapon : 3, Target : 45)
# Value: 41.750371760472085, Index: (Weapon : 3, Target : 57)
# Value: 41.71434322542995, Index: (Weapon : 0, Target : 64)
# not enough Missile for Target 64
# Value: 41.55300437568611, Index: (Weapon : 2, Target : 24)
# not enough Missile for Target 24
# Value: 41.35891143456604, Index: (Weapon : 0, Target : 63)
# Value: 41.34049680270791, Index: (Weapon : 0, Target : 82)
# not enough Missile for Target 82
# Value: 40.524066625189256, Index: (Weapon : 2, Target : 29)
# Value: 40.43686809399917, Index: (Weapon : 1, Target : 27)
# not enough Missile for Target 27
# Value: 40.28388811156419, Index: (Weapon : 4, Target : 67)
# not enough Missile for Target 67
# Value: 40.009891843452266, Index: (Weapon : 4, Target : 73)
# Value: 29.437551729882525, Index: (Weapon : 0, Target : 21)
# Value: 29.334503925143018, Index: (Weapon : 0, Target : 70)
# not enough Missile for Target 70
# Value: 28.87459529222102, Index: (Weapon : 2, Target : 69)
# Value: 28.436660173754092, Index: (Weapon : 0, Target : 69)
# Value: 28.416775184316364, Index: (Weapon : 1, Target : 69)
# Value: 27.405951926270106, Index: (Weapon : 3, Target : 58)
# Value: 27.147305032518332, Index: (Weapon : 2, Target : 27)
# not enough Missile for Target 27
# Value: 27.08903996188492, Index: (Weapon : 2, Target : 8)
# Value: 27.052693172822725, Index: (Weapon : 2, Target : 19)
# Value: 26.70521154018197, Index: (Weapon : 4, Target : 12)
# not enough Missile for Target 12
# Value: 26.63034703907467, Index: (Weapon : 2, Target : 60)
# not enough Missile for Target 60
# Value: 26.43579874677271, Index: (Weapon : 1, Target : 44)
# Value: 26.2944042162819, Index: (Weapon : 1, Target : 18)
# Value: 25.72055452535182, Index: (Weapon : 1, Target : 73)
# Value: 25.715624592272295, Index: (Weapon : 1, Target : 29)
# Value: 25.555209837411628, Index: (Weapon : 3, Target : 83)
# Value: 25.510605962610153, Index: (Weapon : 3, Target : 40)
# not enough Missile for Target 40
# Value: 24.71713287705941, Index: (Weapon : 0, Target : 8)
# Value: 24.62271298617536, Index: (Weapon : 3, Target : 97)
# not enough Missile for Target 97
# Value: 24.475876365914527, Index: (Weapon : 3, Target : 74)
# not enough Missile for Target 74
# Value: 24.463220167004497, Index: (Weapon : 3, Target : 20)
# not enough Missile for Target 20
# Value: 23.96245657039022, Index: (Weapon : 2, Target : 76)
# Value: 23.63893743106193, Index: (Weapon : 0, Target : 66)
# not enough Missile for Target 66
# Value: 23.51686895655842, Index: (Weapon : 4, Target : 90)
# Value: 23.516789167463887, Index: (Weapon : 3, Target : 69)
# Value: 23.36899587129993, Index: (Weapon : 3, Target : 90)
# Value: 23.127167353941083, Index: (Weapon : 0, Target : 71)
# not enough Missile for Target 71
# Value: 23.062988000609742, Index: (Weapon : 0, Target : 46)
# Value: 22.935498436960895, Index: (Weapon : 0, Target : 89)
# Value: 22.83631136005811, Index: (Weapon : 0, Target : 94)
# Value: 22.770874891482602, Index: (Weapon : 0, Target : 32)
# not enough Missile for Target 32
# Value: 22.765505983217533, Index: (Weapon : 2, Target : 31)
# Value: 22.617019391798575, Index: (Weapon : 3, Target : 32)
# not enough Missile for Target 32
# Value: 22.499693099051996, Index: (Weapon : 4, Target : 92)
# Value: 22.219616611829405, Index: (Weapon : 1, Target : 11)
# not enough Missile for Target 11
# Value: 22.157943867439684, Index: (Weapon : 1, Target : 12)
# not enough Missile for Target 12
# Value: 21.89973474014062, Index: (Weapon : 0, Target : 10)
# Value: 21.85619166608728, Index: (Weapon : 2, Target : 15)
# Value: 21.82813469794736, Index: (Weapon : 0, Target : 96)
# not enough Missile for Target 96
# Value: 21.79813699303132, Index: (Weapon : 1, Target : 33)
# not enough Missile for Target 33
# Value: 21.70218474844639, Index: (Weapon : 3, Target : 23)
# not enough Missile for Target 23
# Value: 21.607134898641352, Index: (Weapon : 0, Target : 78)
# not enough Missile for Target 78
# Value: 21.351840087374, Index: (Weapon : 4, Target : 58)
# Value: 21.097365698483248, Index: (Weapon : 2, Target : 32)
# not enough Missile for Target 32
# Value: 20.85555671156099, Index: (Weapon : 3, Target : 61)
# Value: 20.378279793640058, Index: (Weapon : 4, Target : 10)
# Value: 19.983491760171887, Index: (Weapon : 4, Target : 38)
# not enough Missile for Target 38
# Value: 19.851947943333336, Index: (Weapon : 2, Target : 56)
# Value: 19.8148741802362, Index: (Weapon : 2, Target : 95)
# Value: 19.754702641985368, Index: (Weapon : 3, Target : 36)
# Value: 18.4573879522812, Index: (Weapon : 0, Target : 97)
# not enough Missile for Target 97
# Value: 18.367026054608992, Index: (Weapon : 2, Target : 39)
# Value: 18.328159955023345, Index: (Weapon : 0, Target : 0)
# Value: 18.02967365318123, Index: (Weapon : 3, Target : 26)
# Value: 17.916718318239486, Index: (Weapon : 3, Target : 71)
# not enough Missile for Target 71
# Value: 17.87695916760602, Index: (Weapon : 0, Target : 16)
# Value: 17.788627778153955, Index: (Weapon : 3, Target : 68)
# Value: 17.537829155291206, Index: (Weapon : 4, Target : 45)
# Value: 17.476275168545317, Index: (Weapon : 0, Target : 95)
# Value: 17.215629672729243, Index: (Weapon : 1, Target : 5)
# not enough Missile for Target 5
# Value: 16.806032603666534, Index: (Weapon : 3, Target : 92)
# Value: 16.59430241254345, Index: (Weapon : 4, Target : 1)
# not enough Missile for Target 1
# Value: 16.580775643647907, Index: (Weapon : 2, Target : 96)
# not enough Missile for Target 96
# Value: 16.537148882194035, Index: (Weapon : 4, Target : 0)
# Value: 16.53636066311545, Index: (Weapon : 0, Target : 87)
# Value: 16.19875829797525, Index: (Weapon : 2, Target : 12)
# not enough Missile for Target 12
# Value: 16.188863385917255, Index: (Weapon : 3, Target : 80)
# not enough Missile for Target 80
# Value: 15.915229708782512, Index: (Weapon : 1, Target : 64)
# not enough Missile for Target 64
# Value: 15.794923331205645, Index: (Weapon : 3, Target : 21)
# Value: 15.701905424014296, Index: (Weapon : 1, Target : 56)
# Value: 15.235694727645651, Index: (Weapon : 1, Target : 9)
# not enough Missile for Target 9
# Value: 14.954731286309123, Index: (Weapon : 2, Target : 21)
# Value: 14.685976895246798, Index: (Weapon : 4, Target : 23)
# not enough Missile for Target 23
# Value: 14.107058747249809, Index: (Weapon : 2, Target : 78)
# not enough Missile for Target 78
# Value: 13.825474220874977, Index: (Weapon : 4, Target : 34)
# not enough Missile for Target 34
# Value: 13.138859650262974, Index: (Weapon : 2, Target : 91)
# Value: 13.02520082759872, Index: (Weapon : 3, Target : 65)
# Value: 12.99324289055637, Index: (Weapon : 2, Target : 46)
# Value: 12.956492411116633, Index: (Weapon : 3, Target : 87)
# Value: 12.878537772932566, Index: (Weapon : 1, Target : 99)
# Value: 12.821977206997612, Index: (Weapon : 1, Target : 19)
# Value: 12.758116879871075, Index: (Weapon : 1, Target : 61)
# Value: 12.393393428052493, Index: (Weapon : 2, Target : 53)
# Value: 12.088881486992653, Index: (Weapon : 4, Target : 17)
# not enough Missile for Target 17
# Value: 11.936121691950602, Index: (Weapon : 0, Target : 33)
# not enough Missile for Target 33
# Value: 11.900696481690236, Index: (Weapon : 4, Target : 81)
# Value: 11.613510707277053, Index: (Weapon : 2, Target : 52)
# Value: 11.08004232037506, Index: (Weapon : 4, Target : 11)
# not enough Missile for Target 11
# Value: 10.936937200008071, Index: (Weapon : 0, Target : 67)
# not enough Missile for Target 67
# Value: 10.591083243868882, Index: (Weapon : 1, Target : 77)
# not enough Missile for Target 77
# Value: 10.552710000491082, Index: (Weapon : 4, Target : 62)
# Value: 10.388087663399311, Index: (Weapon : 2, Target : 75)
# Value: 10.352216193105624, Index: (Weapon : 2, Target : 97)
# not enough Missile for Target 97
# Value: 10.148463071077247, Index: (Weapon : 1, Target : 84)
# not enough Missile for Target 84
# Value: 9.29617086315242, Index: (Weapon : 4, Target : 41)
# Value: 9.057196902377733, Index: (Weapon : 1, Target : 16)
# Value: 8.851689228913692, Index: (Weapon : 0, Target : 81)
# Value: 8.698783415338502, Index: (Weapon : 2, Target : 86)
# Value: 8.611689231229605, Index: (Weapon : 1, Target : 26)
# Value: 8.155723515968427, Index: (Weapon : 2, Target : 16)
# Value: 8.081368221028368, Index: (Weapon : 3, Target : 18)
# Value: 8.023575374857145, Index: (Weapon : 1, Target : 32)
# not enough Missile for Target 32
# Value: 7.931369792082839, Index: (Weapon : 3, Target : 10)
# Value: 7.779271218347054, Index: (Weapon : 2, Target : 89)
# Value: 7.618366961291707, Index: (Weapon : 0, Target : 34)
# not enough Missile for Target 34
# Value: 7.536955089539719, Index: (Weapon : 1, Target : 35)
# Value: 7.276177985671253, Index: (Weapon : 3, Target : 91)
# Value: 7.246396453075921, Index: (Weapon : 4, Target : 93)
# Value: 7.172241891661329, Index: (Weapon : 2, Target : 65)
# Value: 7.147642488938408, Index: (Weapon : 3, Target : 38)
# not enough Missile for Target 38
# Value: 6.715868851412019, Index: (Weapon : 1, Target : 87)
# Value: 6.667709545408398, Index: (Weapon : 1, Target : 90)
# Value: 6.470277739095295, Index: (Weapon : 0, Target : 38)
# not enough Missile for Target 38
# Value: 6.3566847704382745, Index: (Weapon : 2, Target : 58)
# Value: 5.974856315065816, Index: (Weapon : 3, Target : 19)
# Value: 5.72642497977624, Index: (Weapon : 1, Target : 0)
# Value: 5.651598752842171, Index: (Weapon : 4, Target : 13)
# not enough Missile for Target 13
# Value: 5.145157081495769, Index: (Weapon : 3, Target : 2)
# Value: 4.772991847195047, Index: (Weapon : 4, Target : 65)
# Value: 4.528461347438772, Index: (Weapon : 1, Target : 94)
# Value: 4.167225773999826, Index: (Weapon : 0, Target : 72)
# not enough Missile for Target 72
# Value: 4.115713045988818, Index: (Weapon : 4, Target : 22)
# not enough Missile for Target 22
# Value: 3.9708099498357656, Index: (Weapon : 3, Target : 49)
# Value: 3.9222637094873574, Index: (Weapon : 2, Target : 73)
# Value: 3.903254325482084, Index: (Weapon : 0, Target : 13)
# not enough Missile for Target 13
# Value: 3.895010526182455, Index: (Weapon : 4, Target : 16)
# Value: 3.6637558368337695, Index: (Weapon : 0, Target : 30)
# not enough Missile for Target 30
# Value: 3.6304712664207544, Index: (Weapon : 4, Target : 2)
# Value: 3.3606518799940854, Index: (Weapon : 0, Target : 19)
# Value: 3.28710777034529, Index: (Weapon : 2, Target : 88)
# not enough Missile for Target 88
# Value: 3.2200917696339397, Index: (Weapon : 2, Target : 47)
# Value: 3.1270283377385617, Index: (Weapon : 3, Target : 0)
# Value: 3.0822742055666246, Index: (Weapon : 2, Target : 33)
# not enough Missile for Target 33
# Value: 3.0345977183748003, Index: (Weapon : 3, Target : 39)
# Value: 3.008318909986849, Index: (Weapon : 4, Target : 54)
# not enough Missile for Target 54
# Value: 2.9673853973951174, Index: (Weapon : 4, Target : 35)
# Value: 2.8954810204213555, Index: (Weapon : 1, Target : 59)
# Value: 2.4341047294213496, Index: (Weapon : 2, Target : 1)
# not enough Missile for Target 1
# Value: 2.415677374097264, Index: (Weapon : 0, Target : 47)
# Value: 2.190231601370728, Index: (Weapon : 2, Target : 2)
# Value: 2.1056716741883266, Index: (Weapon : 0, Target : 49)
# Value: 1.7695195386079672, Index: (Weapon : 0, Target : 73)
# Value: 1.150433450901963, Index: (Weapon : 2, Target : 64)
# not enough Missile for Target 64
# Value: 0.9673138944991823, Index: (Weapon : 2, Target : 83)
# Value: 0.6322012999665244, Index: (Weapon : 1, Target : 68)
# Value: 0.5701073893140355, Index: (Weapon : 4, Target : 83)
# Value: 0.48905811250655196, Index: (Weapon : 4, Target : 26)

# %%
print(objective_fun_1(theta_wt))
# Out:
# 3742.083661015633

# %%
indices = np.where(theta_wt == 1)


# Convert the indices to a list of tuples
indices_list = list(zip(*indices))

# Sort the indices by the second index (M)
indices_list.sort(key=lambda x: x[1])
print(f"목표 함수 값 : {objective_fun_1(theta_wt):.2f}")

for i, group in enumerate(indices_list):
    # Iterate over each group
    print(f"타깃 {group[1]}에 대하여 발사대 {group[0]}가 미사일을 발사합니다. 요격확률 : {PK_wt[group[0], group[1]]:.2f}")
# Out:
# 목표 함수 값 : 3742.08
# 타깃 1에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 95.94
# 타깃 4에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 98.50
# 타깃 5에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 86.23
# 타깃 6에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 83.57
# 타깃 7에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 79.37
# 타깃 9에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 98.72
# 타깃 11에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 97.78
# 타깃 12에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 93.46
# 타깃 13에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 80.91
# 타깃 17에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 67.37
# 타깃 20에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 94.14
# 타깃 22에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 91.52
# 타깃 23에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 96.13
# 타깃 24에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 97.68
# 타깃 27에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 94.23
# 타깃 28에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 97.41
# 타깃 30에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 88.52
# 타깃 32에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 48.40
# 타깃 33에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 98.64
# 타깃 34에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 96.50
# 타깃 38에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 95.85
# 타깃 40에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 85.99
# 타깃 42에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 76.32
# 타깃 48에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 97.78
# 타깃 54에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 98.80
# 타깃 60에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 90.32
# 타깃 64에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 98.94
# 타깃 66에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 96.74
# 타깃 67에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 89.99
# 타깃 70에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 96.17
# 타깃 71에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 97.14
# 타깃 72에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 86.97
# 타깃 74에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 97.78
# 타깃 77에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 97.68
# 타깃 78에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 75.34
# 타깃 80에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 95.34
# 타깃 82에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 95.97
# 타깃 84에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 93.53
# 타깃 88에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 98.13
# 타깃 96에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 96.38
# 타깃 97에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 95.92

# %%
"""
제약조건 (2)
수식 (2)는 동일 유도탄이 다수의 표적에 중복하여 할당되지 않기 위한 제약 조건이다.
"""

# 동일 유도탄이 다수의 표적에 중복 할당 X
def constraint2(theta_wt):
    W, T, M = theta_wt.shape
    for m in range(M):
        for w in range(W):
            # If the sum exceeds 1, immediately return False
            if np.sum(theta_wt[w,:,m]) > 1:
                return False
    # If none of the sums exceed 1, return True
    return True

# Now we can check the constraint:
print(constraint2(theta_wt))
# Out:
# True

# %%
"""
제약조건 (3)
각 위협 표적에 할당할 수 있는 유도탄의 개수를 제한하기 위하여 수식 (3)과 같은 제약식을 적용한다.
"""
# constraint3
def constraint3(theta_wt):
    W, T, M = theta_wt.shape
    for t in range(T):
        if np.sum(theta_wt[:,t,:]) > FN_T[t]:
            return False
    return True

print(constraint3(theta_wt))
# Out:
# True

# %%
"""
제약조건 (4)
한 발사대가 연속발사를 하기 위해서는 발사절차 및 발사대 안정화를 위한 시간을 고려하여야 하므로, 수식 (4)과 같이 한 발사대 상의 연속적 발사를 위한 최소 발사 간격을 제약으로 고려한다.
"""

def constraint4(tau):
    for t in tau:
        for i in range(len(t)-1):
            if t[i+1][0]-t[i][0] < 1 :
                print (t[i+1][0]-t[i][0]) # 0.9999999999999996 으로 나와서
                return False
        
    return True

print(constraint4(tau))
# Out:
# True

# %%
"""
제약조건 (5)
각 발사대에서 발사된 유도탄은 제한된 공간 영역 상에서 표적을 요격할 수 있다.
표적의 예상 궤적과 발사대 위치에 따른 요격 공간으로부터 교전 가능한 유도탄 발사 시간이 계산되어진다.
위협 표적에 대해 서 교전 가능한 발사 시간 구간 내에서 발사 시점이 산출되어야만 교전 가능하므로, 수식 (5)와 같이 표적 t에 대한 발사대 w에서 발사 가능한 시간에 대한 제약 조건을 고려해야 한다.
"""
def constraint5(tau, theta_wt):
    W, T, M = theta_wt.shape
    for m in range(M):
        indices = np.where(theta_wt[:,:,m] == 1)
        if len(indices[0]) == 0 :
            continue

        w = int(indices[0])
        t = int(indices[1])
        
        ft = ft_wt[w][t]
        lt = lt_wt[w][t]

        tau_wm_m_filtered = list(filter(lambda x: x[1] == m, tau[w]))
        if len(tau_wm_m_filtered) == 1:
            # print(f"Found tuple: {tau_wm_m_filtered[0]}")
            tau_wm_m = tau_wm_m_filtered[0]

        tau_wm = tau_wm_m[0]
        if ft > tau_wm or tau_wm > lt:
            print(f"미사일 {m}, 발사대 {w}로 타깃 {t} (공격 시간 : {tau_wm})")
            print(f"최초 공격 가능 시점 : {ft}, 최후 발사 가능 시점 : {lt}")
            
            return False
    return True

print(constraint5(tau,theta_wt))
# Out:
# True

# %%
"""
제약조건 (6)
각 발사대는 적재된 수량만큼 유도탄을 사용할 수 있으므로, 수식 (6)과 같이 한 발사대에서 할당할 수 있는 유도탄의 개수는 적재량 이하여야 한다는 제약 조건을 고려한다.
"""
def constraint6(theta_wt):
    W, T, M = theta_wt.shape
    for w in range(W):
        if np.sum(theta_wt[w,:,:]) > m_w[w]:
            return False
    return True

print(constraint6(theta_wt))
# Out:
# True

# %% [markdown]
# 타격 가능 시간 오름차순으로 정렬: 가장 먼저 타격 가능 시간이 빠른 타겟부터 발사할 계획을 세우면, 나중에 남는 시간을 더 유연하게 사용할 수 있습니다.
#
# 발사대 사용 계획: 발사대는 1초에 한 번씩만 발사가 가능하므로, 가능한 한 빠르게 그리고 빠르게 발사해야 하는 타겟을 먼저 선택합니다.
#
# 제한 시간 확인: 제한 시간이 10초라면, 최대 10번의 발사가 가능합니다. 따라서 가능한 한 빠른 시간 내에 많은 타겟을 처리해야 합니다.
#
# 동일 시간대의 타겟 처리: 만약 두 개 이상의 타겟이 동일한 시간에 발사해야 하는 경우, 그 중 하나는 놓치게 됩니다. 이러한 상황을 최소화하기 위해 가능한 한 빠른 시간대의 타겟을 우선적으로 처리합니다.
#
# 여기에 따라 간단한 알고리즘을 생각해볼 수 있습니다:
#
# 타겟의 '타격 가능 시간'을 오름차순으로 정렬합니다.
#
# 제한 시간 (10초) 내에 발사대가 발사할 수 있는 최대 횟수는 10번입니다.
#
# 정렬된 목록을 차례대로 확인하면서, 해당 타겟을 발사대가 처리할 수 있는지 확인합니다.

# %%
W, T, M = theta_wt.shape
for w in range(W):
    Target_Miassile_indices = np.where(theta_wt[w,:,:] == 1)

    Target_indices_list = Target_Miassile_indices[0]
    Miassile_indices_list = Target_Miassile_indices[1]

    print(Target_indices_list)
    ft_lt_w_t_list = []
    
    for w_t in Target_indices_list:
        ft_lt_w_t_list.append((ft_wt[w,w_t],lt_wt[w,w_t],w_t))
        # 최초발사가능시점,최후발사가능시점,t index
        sorted_ft_lt_w_t_list = sorted(ft_lt_w_t_list, key=lambda x: x[0])
        print(sorted_ft_lt_w_t_list)
# Out:
# [11 12 22 23 54 74 84 88]
# [(3.8796394086479773, 8.184708496696638, 11)]
# [(3.329770563201687, 9.753098099347831, 12), (3.8796394086479773, 8.184708496696638, 11)]
# [(1.1685785941408726, 9.824558175407915, 22), (3.329770563201687, 9.753098099347831, 12), (3.8796394086479773, 8.184708496696638, 11)]
# [(1.1685785941408726, 9.824558175407915, 22), (1.4654473731747668, 9.12619887131474, 23), (3.329770563201687, 9.753098099347831, 12), (3.8796394086479773, 8.184708496696638, 11)]
# [(1.1685785941408726, 9.824558175407915, 22), (1.4654473731747668, 9.12619887131474, 23), (2.3915999152443406, 9.43157045203641, 54), (3.329770563201687, 9.753098099347831, 12), (3.8796394086479773, 8.184708496696638, 11)]
# [(1.1685785941408726, 9.824558175407915, 22), (1.4654473731747668, 9.12619887131474, 23), (2.3915999152443406, 9.43157045203641, 54), (2.8274293753904685, 9.425702854236468, 74), (3.329770563201687, 9.753098099347831, 12), (3.8796394086479773, 8.184708496696638, 11)]
# [(1.1685785941408726, 9.824558175407915, 22), (1.2439292868626488, 7.889829394071333, 84), (1.4654473731747668, 9.12619887131474, 23), (2.3915999152443406, 9.43157045203641, 54), (2.8274293753904685, 9.425702854236468, 74), (3.329770563201687, 9.753098099347831, 12), (3.8796394086479773, 8.184708496696638, 11)]
# [(1.1685785941408726, 9.824558175407915, 22), (1.2439292868626488, 7.889829394071333, 84), (1.4654473731747668, 9.12619887131474, 23), (2.3915999152443406, 9.43157045203641, 54), (2.8274293753904685, 9.425702854236468, 74), (3.329770563201687, 9.753098099347831, 12), (3.548850970305306, 6.990756243180866, 88), (3.8796394086479773, 8.184708496696638, 11)]
# [(0.23023504006657713, 6.108830523112887, 24), (1.5568067149366525, 9.006310021109599, 6), (3.550816731033199, 8.419012402141433, 27)]
# [(0.23023504006657713, 6.108830523112887, 24), (1.5568067149366525, 9.006310021109599, 6), (2.4728722532650442, 9.929386679474494, 32), (3.550816731033199, 8.419012402141433, 27)]
# [(0.23023504006657713, 6.108830523112887, 24), (1.5568067149366525, 9.006310021109599, 6), (2.4728722532650442, 9.929386679474494, 32), (3.550816731033199, 8.419012402141433, 27), (3.8486901938981677, 7.7584535975438556, 64)]
# [(0.23023504006657713, 6.108830523112887, 24), (1.142848345127443, 8.354409258606683, 66), (1.5568067149366525, 9.006310021109599, 6), (2.4728722532650442, 9.929386679474494, 32), (3.550816731033199, 8.419012402141433, 27), (3.8486901938981677, 7.7584535975438556, 64)]
# [(0.17263964780230445, 8.174173339421884, 72), (0.23023504006657713, 6.108830523112887, 24), (1.142848345127443, 8.354409258606683, 66), (1.5568067149366525, 9.006310021109599, 6), (2.4728722532650442, 9.929386679474494, 32), (3.550816731033199, 8.419012402141433, 27), (3.8486901938981677, 7.7584535975438556, 64)]

# %%
def simulation(tau, theta_wt):
    W, T, M = theta_wt.shape
    result = []
    for m in range(M):
        indices = np.where(theta_wt[:,:,m] == 1)
        if len(indices[0]) == 0 :
            continue
        w = int(indices[0])
        t = int(indices[1])
        
        ft = ft_wt[w][t]
        lt = lt_wt[w][t]

        tau_wm_m_filtered = list(filter(lambda x: x[1] == m, tau[w]))
        if len(tau_wm_m_filtered) == 1:
            # print(f"Found tuple: {tau_wm_m_filtered[0]}")
            tau_wm_m = tau_wm_m_filtered[0]

        tau_wm = tau_wm_m[0]
        PK = PK_wt[w][t]
        result.append((tau_wm, w, t, m, PK))

    if constraint2(theta_wt):
        print("제약조건 2 충족")
    if constraint3(theta_wt):
        print("제약조건 3 충족")
    if constraint4(tau):
        print("제약조건 4 충족")
    if constraint5(tau, theta_wt):
        print("제약조건 5 충족")
    if constraint6(theta_wt):
        print("제약조건 6 충족")

    result.sort()
    for res in result:

        print(f"{res[0]:.2f}초, 발사대 {res[1]}, 타깃 {res[2]}을 향해 미사일 {res[3]} 발사, 요격 확률 : {res[4]:.2f}")

    objective_value = objective_fun_1(theta_wt)

    print(f"목표함수 값 : {objective_value}")

# %%
simulation(tau, theta_wt)
# Out:
# 제약조건 2 충족
# 제약조건 3 충족
# 제약조건 4 충족
# 제약조건 5 충족
# 제약조건 6 충족
# 0.26초, 발사대 4, 타깃 27을 향해 미사일 0 발사, 요격 확률 : 98.80
# 2.09초, 발사대 0, 타깃 28을 향해 미사일 3 발사, 요격 확률 : 98.59
# 2.43초, 발사대 1, 타깃 25을 향해 미사일 1 발사, 요격 확률 : 98.80
# 2.91초, 발사대 3, 타깃 19을 향해 미사일 4 발사, 요격 확률 : 98.43
# 3.09초, 발사대 0, 타깃 77을 향해 미사일 15 발사, 요격 확률 : 96.53
# 3.43초, 발사대 1, 타깃 26을 향해 미사일 6 발사, 요격 확률 : 97.80
# 3.48초, 발사대 4, 타깃 4을 향해 미사일 5 발사, 요격 확률 : 98.05
# 3.89초, 발사대 2, 타깃 98을 향해 미사일 2 발사, 요격 확률 : 98.61
# 3.91초, 발사대 3, 타깃 97을 향해 미사일 7 발사, 요격 확률 : 97.55
# 4.09초, 발사대 0, 타깃 49을 향해 미사일 17 발사, 요격 확률 : 95.95
# 4.43초, 발사대 1, 타깃 74을 향해 미사일 8 발사, 요격 확률 : 97.40
# 4.48초, 발사대 4, 타깃 60을 향해 미사일 9 발사, 요격 확률 : 97.36
# 4.89초, 발사대 2, 타깃 20을 향해 미사일 11 발사, 요격 확률 : 97.32
# 4.91초, 발사대 3, 타깃 32을 향해 미사일 12 발사, 요격 확률 : 97.26
# 5.09초, 발사대 0, 타깃 83을 향해 미사일 18 발사, 요격 확률 : 95.77
# 5.43초, 발사대 1, 타깃 22을 향해 미사일 22 발사, 요격 확률 : 95.28
# 5.48초, 발사대 4, 타깃 94을 향해 미사일 10 발사, 요격 확률 : 97.34
# 5.89초, 발사대 2, 타깃 21을 향해 미사일 13 발사, 요격 확률 : 97.24
# 5.91초, 발사대 3, 타깃 17을 향해 미사일 19 발사, 요격 확률 : 95.69
# 6.09초, 발사대 0, 타깃 67을 향해 미사일 20 발사, 요격 확률 : 95.59
# 6.43초, 발사대 1, 타깃 55을 향해 미사일 24 발사, 요격 확률 : 94.60
# 6.48초, 발사대 4, 타깃 85을 향해 미사일 21 발사, 요격 확률 : 95.46
# 6.89초, 발사대 2, 타깃 65을 향해 미사일 14 발사, 요격 확률 : 96.95
# 6.91초, 발사대 3, 타깃 93을 향해 미사일 23 발사, 요격 확률 : 94.85
# 7.09초, 발사대 0, 타깃 23을 향해 미사일 27 발사, 요격 확률 : 93.91
# 7.43초, 발사대 1, 타깃 88을 향해 미사일 29 발사, 요격 확률 : 91.87
# 7.48초, 발사대 4, 타깃 58을 향해 미사일 28 발사, 요격 확률 : 92.83
# 7.89초, 발사대 2, 타깃 48을 향해 미사일 16 발사, 요격 확률 : 96.20
# 7.91초, 발사대 3, 타깃 43을 향해 미사일 26 발사, 요격 확률 : 93.98
# 8.09초, 발사대 0, 타깃 84을 향해 미사일 33 발사, 요격 확률 : 85.25
# 8.43초, 발사대 1, 타깃 90을 향해 미사일 35 발사, 요격 확률 : 80.80
# 8.48초, 발사대 4, 타깃 5을 향해 미사일 30 발사, 요격 확률 : 90.30
# 8.89초, 발사대 2, 타깃 64을 향해 미사일 25 발사, 요격 확률 : 94.55
# 8.91초, 발사대 3, 타깃 8을 향해 미사일 31 발사, 요격 확률 : 87.55
# 9.09초, 발사대 0, 타깃 68을 향해 미사일 34 발사, 요격 확률 : 85.04
# 9.43초, 발사대 1, 타깃 59을 향해 미사일 37 발사, 요격 확률 : 62.76
# 9.48초, 발사대 4, 타깃 12을 향해 미사일 36 발사, 요격 확률 : 63.78
# 9.89초, 발사대 2, 타깃 66을 향해 미사일 32 발사, 요격 확률 : 85.30
# 목표함수 값 : 3531.3426101561963
