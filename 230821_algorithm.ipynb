# %% [markdown]
# 1. $m_w$ 추가 발사대에 적재된 유도탄 수량, M을 W로 나눈 뒤 남은 값은 w_1 부터 차레로 적재

# %%
import numpy as np
# 시드를 고정
np.random.seed(0)

# 발사대를 5대로 가정하여 진행
W = 5
# 위협 표적의 개수를 10개에서 100개까지 10개씩 증가시키며 실행
T = 100
# 표적 t에 할당할 수 있는 유도탄의 개수는 1개로 가정
FN_T = [1] * T

M = sum(FN_T)

# 0에서 4 사이의 랜덤한 값으로 구성된 W*T 행렬 생성 : 최초발사가능시점
ft_wt = np.random.rand(W, T) * 4

# 최소 3초 이상의 간격을 갖도록 설정
min_lt_wt = ft_wt + 3

# 발사가능시점으로부터 최소 3초 이상~ 전체 시간 10초 이내의 간격 행렬 생성
inter_lt_wt = 10 - min_lt_wt

# 3에서 10 사이의 랜덤한 값으로 구성된 W*T 행렬 생성 : 최후발사가능시점
lt_wt = np.random.rand(W, T) * inter_lt_wt + min_lt_wt

# 최초발사가능 시점과 최후발사가능 시점 사이의 간격이 3초 이상을 갖는지 확인
time_intervals_diff = lt_wt - ft_wt

# 0과 99 사이의 실수로 PK_wt 배열 초기화
PK_wt = np.random.uniform(0, 99, (W, T))

# 표적 t에 발사대 w를 할당할 때의 보상(요격확률) 행렬 생성
# PK_wt = np.random.rand(W, T)

# %%
# M을 W로 나누어 리스트에 적절히 분배
quotient, remainder = divmod(M, W)
m_w = [quotient] * W

# 나머지 값을 리스트의 앞부분에 추가
for i in range(remainder):
    m_w[i] += 1

print(m_w)
# Out:
# [20, 20, 20, 20, 20]

# %%
"""
목표함수 (1)
해당 목적함수는 결정변수 theta_wt와 요격확률의 곱의 합을 최대화함으로써 요격확률이 높을 때 표적-발사대 쌍의 발사 시점에 무기할당을 하는 의미로 해석할 수 있다.
"""
def objective_fun_1(theta_wt):
    res = 0
    for t in range(T):
        
        a = 1
        for w in range(W):
            for m in range(M):
                p = 1 - PK_wt[w,t] * theta_wt[w,t,m]
                a *= p
        
        #print(f"타깃 {t}에 대한 성공 값 : {1-a}")
        res += 1-a
    return res

# %%
import copy
# Initialize a 3D binary matrix of zeros
theta_wt = np.zeros((W, T, M), dtype=int)

# 미사일이 소모되는 리스트 left_FN_T으로 복사
left_FN_T = copy.copy(FN_T)

# 발사대에 적재된 유도탄 수량 리스트 left_m_w로 복사
left_m_w = copy.copy(m_w)

# 행렬의 원소들을 1차원 배열로 변환
flattened = PK_wt.flatten()

# 원소들을 내림차순으로 정렬
sorted_indices = np.argsort(flattened)[::-1]


i = 0
m = 0
indices_list = []
while True :
    # i번째 요격확률의 인덱스 v
    v = sorted_indices[i]
    
    row = v // T
    col = v % T
    print(f"Value: {flattened[v]}, Index: (Weapon : {row}, Target : {col})")
    
    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있다면,
    # 해당 Weapon의 적재된 유도탄이 남아 있다면,
    if left_FN_T[col] > 0 and left_m_w[row] > 0:
        # 할당할 유도탄 개수 감소
        left_FN_T[col] -= 1
        left_m_w[row] -= 1
        # 해당 W T M에 1 부여
        theta_wt[row][col][m] = 1
        # 무기가 할당된 indices_list에 추가
        indices_list.append(v)
        # 다음 미사일 인덱스로 이동
        m += 1

    # 해당 Target의 할당할 수 있는 유도탄의 개수가 남아 있지 않다면,
    elif left_FN_T[col] > 0:
        print(f"not enough Missile on Weapon {row}")
    
    else :
        print(f"not enough Missile for Target {col}")
    
    # 할당할 수 있는 유도탄의 개수를 모두 소모했다면 종료.
    if sum(left_FN_T) == 0:
        break
    
    # 다음으로 요격확률이 높은 인덱스로 이동
    i += 1
# Out:
# Value: 98.80425598805196, Index: (Weapon : 4, Target : 27)
# Value: 98.8014060926302, Index: (Weapon : 1, Target : 25)
# Value: 98.61105583000854, Index: (Weapon : 2, Target : 98)
# Value: 98.58571400300387, Index: (Weapon : 0, Target : 28)
# Value: 98.42907523885545, Index: (Weapon : 3, Target : 19)
# Value: 98.27403235296237, Index: (Weapon : 2, Target : 22)
# Value: 98.04648369181838, Index: (Weapon : 4, Target : 4)
# Value: 97.80102776401908, Index: (Weapon : 1, Target : 26)
# Value: 97.55247789214349, Index: (Weapon : 3, Target : 97)
# Value: 97.52575925437607, Index: (Weapon : 1, Target : 4)
# not enough Missile for Target 4
# Value: 97.40152913848006, Index: (Weapon : 1, Target : 74)
# Value: 97.35996384522305, Index: (Weapon : 4, Target : 60)
# Value: 97.34421163996537, Index: (Weapon : 4, Target : 94)
# Value: 97.31691435673672, Index: (Weapon : 2, Target : 20)
# Value: 97.31602088582612, Index: (Weapon : 2, Target : 85)
# Value: 97.26204341707027, Index: (Weapon : 3, Target : 32)
# Value: 97.24252995154606, Index: (Weapon : 2, Target : 21)
# Value: 96.94934567892857, Index: (Weapon : 2, Target : 65)
# Value: 96.5343733409926, Index: (Weapon : 0, Target : 77)
# Value: 96.20454453528116, Index: (Weapon : 2, Target : 48)
# Value: 95.95138130005084, Index: (Weapon : 0, Target : 49)
# Value: 95.76644240166124, Index: (Weapon : 0, Target : 83)
# Value: 95.73843688964473, Index: (Weapon : 0, Target : 97)
# not enough Missile for Target 97
# Value: 95.69093558549223, Index: (Weapon : 3, Target : 17)
# Value: 95.60769352004779, Index: (Weapon : 3, Target : 94)
# not enough Missile for Target 94
# Value: 95.58614727460986, Index: (Weapon : 0, Target : 67)
# Value: 95.54440234857897, Index: (Weapon : 2, Target : 42)
# Value: 95.52756914399552, Index: (Weapon : 0, Target : 33)
# Value: 95.45584152602338, Index: (Weapon : 4, Target : 85)
# not enough Missile for Target 85
# Value: 95.27711230726925, Index: (Weapon : 1, Target : 22)
# not enough Missile for Target 22
# Value: 95.1204403534451, Index: (Weapon : 3, Target : 26)
# not enough Missile for Target 26
# Value: 94.84865062135006, Index: (Weapon : 3, Target : 93)
# Value: 94.73018634145899, Index: (Weapon : 3, Target : 66)
# Value: 94.69786636413599, Index: (Weapon : 4, Target : 83)
# not enough Missile for Target 83
# Value: 94.65619279643603, Index: (Weapon : 1, Target : 32)
# not enough Missile for Target 32
# Value: 94.60127100406166, Index: (Weapon : 1, Target : 55)
# Value: 94.5911273972723, Index: (Weapon : 2, Target : 53)
# Value: 94.54962141962201, Index: (Weapon : 2, Target : 64)
# Value: 94.41389394630399, Index: (Weapon : 0, Target : 9)
# Value: 93.97871010427107, Index: (Weapon : 3, Target : 43)
# Value: 93.90548981175526, Index: (Weapon : 0, Target : 23)
# Value: 93.83436682404736, Index: (Weapon : 1, Target : 36)
# Value: 93.7339099235077, Index: (Weapon : 2, Target : 91)
# Value: 93.51794612379028, Index: (Weapon : 1, Target : 78)
# Value: 93.47606907348026, Index: (Weapon : 4, Target : 29)
# Value: 93.45921417638183, Index: (Weapon : 3, Target : 72)
# Value: 93.44123487773113, Index: (Weapon : 0, Target : 32)
# not enough Missile for Target 32
# Value: 93.27628718278675, Index: (Weapon : 2, Target : 1)
# Value: 93.22511174358588, Index: (Weapon : 0, Target : 71)
# Value: 92.88735755943226, Index: (Weapon : 2, Target : 24)
# Value: 92.84857306995987, Index: (Weapon : 3, Target : 5)
# Value: 92.82864630249165, Index: (Weapon : 4, Target : 58)
# Value: 92.58089069570474, Index: (Weapon : 4, Target : 37)
# Value: 91.99987548540857, Index: (Weapon : 1, Target : 1)
# not enough Missile for Target 1
# Value: 91.86964049323743, Index: (Weapon : 1, Target : 88)
# Value: 91.61410750395163, Index: (Weapon : 1, Target : 81)
# Value: 91.42209828220656, Index: (Weapon : 1, Target : 69)
# Value: 90.72548205940944, Index: (Weapon : 4, Target : 53)
# not enough Missile for Target 53
# Value: 90.71769265382085, Index: (Weapon : 2, Target : 59)
# Value: 90.4151497476626, Index: (Weapon : 0, Target : 88)
# not enough Missile for Target 88
# Value: 90.41507604033633, Index: (Weapon : 3, Target : 29)
# not enough Missile for Target 29
# Value: 90.30294434814729, Index: (Weapon : 4, Target : 5)
# not enough Missile for Target 5
# Value: 90.23363665972546, Index: (Weapon : 1, Target : 91)
# not enough Missile for Target 91
# Value: 89.88194729355219, Index: (Weapon : 4, Target : 46)
# Value: 89.71691055894114, Index: (Weapon : 1, Target : 18)
# Value: 89.31099026561898, Index: (Weapon : 4, Target : 61)
# Value: 89.13637770881833, Index: (Weapon : 4, Target : 93)
# not enough Missile for Target 93
# Value: 88.96512917241836, Index: (Weapon : 4, Target : 8)
# Value: 88.91068775757138, Index: (Weapon : 4, Target : 73)
# Value: 88.37800926064918, Index: (Weapon : 1, Target : 63)
# Value: 87.93823901386031, Index: (Weapon : 2, Target : 2)
# Value: 87.88238273700466, Index: (Weapon : 2, Target : 68)
# Value: 87.84103197228342, Index: (Weapon : 3, Target : 98)
# not enough Missile for Target 98
# Value: 87.61716326996881, Index: (Weapon : 0, Target : 93)
# not enough Missile for Target 93
# Value: 87.59171740763861, Index: (Weapon : 4, Target : 38)
# Value: 87.55167596095308, Index: (Weapon : 3, Target : 8)
# not enough Missile for Target 8
# Value: 87.42468213459439, Index: (Weapon : 3, Target : 16)
# Value: 87.23763688953456, Index: (Weapon : 4, Target : 52)
# Value: 87.07262681934928, Index: (Weapon : 0, Target : 5)
# not enough Missile for Target 5
# Value: 86.45862336228846, Index: (Weapon : 3, Target : 82)
# Value: 85.84433961777262, Index: (Weapon : 3, Target : 0)
# Value: 85.81923045227812, Index: (Weapon : 1, Target : 89)
# Value: 85.74733592614837, Index: (Weapon : 3, Target : 25)
# not enough Missile for Target 25
# Value: 85.29750542863079, Index: (Weapon : 2, Target : 66)
# not enough Missile for Target 66
# Value: 85.25117779851288, Index: (Weapon : 0, Target : 84)
# Value: 85.17075715599854, Index: (Weapon : 2, Target : 3)
# Value: 85.0412613261478, Index: (Weapon : 0, Target : 68)
# not enough Missile for Target 68
# Value: 84.47135163969277, Index: (Weapon : 0, Target : 47)
# Value: 84.32904969296708, Index: (Weapon : 1, Target : 21)
# not enough Missile for Target 21
# Value: 83.9861817092106, Index: (Weapon : 0, Target : 25)
# not enough Missile for Target 25
# Value: 83.67025461257631, Index: (Weapon : 2, Target : 92)
# Value: 83.45435634370733, Index: (Weapon : 4, Target : 69)
# not enough Missile for Target 69
# Value: 82.72895772076409, Index: (Weapon : 4, Target : 50)
# Value: 82.27208028554244, Index: (Weapon : 2, Target : 95)
# Value: 82.217158166975, Index: (Weapon : 4, Target : 79)
# Value: 81.9865147084528, Index: (Weapon : 1, Target : 3)
# not enough Missile for Target 3
# Value: 81.8537217665385, Index: (Weapon : 1, Target : 57)
# Value: 81.54804953029377, Index: (Weapon : 0, Target : 54)
# Value: 81.52370018768617, Index: (Weapon : 3, Target : 24)
# not enough Missile for Target 24
# Value: 81.36848693237903, Index: (Weapon : 3, Target : 14)
# Value: 80.92787309819845, Index: (Weapon : 4, Target : 63)
# not enough Missile for Target 63
# Value: 80.82568209022122, Index: (Weapon : 2, Target : 11)
# Value: 80.82006624646576, Index: (Weapon : 1, Target : 19)
# not enough Missile for Target 19
# Value: 80.79892447437047, Index: (Weapon : 1, Target : 90)
# Value: 80.7072790309209, Index: (Weapon : 2, Target : 7)
# not enough Missile on Weapon 2
# Value: 80.21990607277999, Index: (Weapon : 3, Target : 53)
# not enough Missile for Target 53
# Value: 79.94881661182748, Index: (Weapon : 2, Target : 12)
# not enough Missile on Weapon 2
# Value: 79.74078130309466, Index: (Weapon : 2, Target : 44)
# not enough Missile on Weapon 2
# Value: 79.40478386566578, Index: (Weapon : 4, Target : 87)
# Value: 79.30641314527517, Index: (Weapon : 2, Target : 9)
# not enough Missile for Target 9
# Value: 79.27906130769547, Index: (Weapon : 2, Target : 78)
# not enough Missile for Target 78
# Value: 79.22530475476883, Index: (Weapon : 1, Target : 54)
# not enough Missile for Target 54
# Value: 79.07023563950636, Index: (Weapon : 1, Target : 68)
# not enough Missile for Target 68
# Value: 78.75019615085515, Index: (Weapon : 3, Target : 3)
# not enough Missile for Target 3
# Value: 78.56316943678684, Index: (Weapon : 2, Target : 76)
# not enough Missile on Weapon 2
# Value: 78.53488560294777, Index: (Weapon : 3, Target : 68)
# not enough Missile for Target 68
# Value: 78.45739165528273, Index: (Weapon : 4, Target : 49)
# not enough Missile for Target 49
# Value: 78.38438069685671, Index: (Weapon : 1, Target : 39)
# Value: 78.33151567089212, Index: (Weapon : 0, Target : 57)
# not enough Missile for Target 57
# Value: 78.00365934443374, Index: (Weapon : 2, Target : 50)
# not enough Missile for Target 50
# Value: 77.83266144704102, Index: (Weapon : 2, Target : 74)
# not enough Missile for Target 74
# Value: 77.55626790596577, Index: (Weapon : 1, Target : 5)
# not enough Missile for Target 5
# Value: 77.37659104047916, Index: (Weapon : 2, Target : 57)
# not enough Missile for Target 57
# Value: 77.33809155227668, Index: (Weapon : 3, Target : 45)
# Value: 77.04934056234794, Index: (Weapon : 0, Target : 24)
# not enough Missile for Target 24
# Value: 76.71309815539279, Index: (Weapon : 3, Target : 71)
# not enough Missile for Target 71
# Value: 76.70001380505737, Index: (Weapon : 3, Target : 18)
# not enough Missile for Target 18
# Value: 76.675594533536, Index: (Weapon : 0, Target : 81)
# not enough Missile for Target 81
# Value: 76.5526534806353, Index: (Weapon : 2, Target : 18)
# not enough Missile for Target 18
# Value: 76.24268429496664, Index: (Weapon : 2, Target : 72)
# not enough Missile for Target 72
# Value: 76.14639697387052, Index: (Weapon : 3, Target : 9)
# not enough Missile for Target 9
# Value: 76.13565243769392, Index: (Weapon : 4, Target : 64)
# not enough Missile for Target 64
# Value: 76.05127178181519, Index: (Weapon : 3, Target : 36)
# not enough Missile for Target 36
# Value: 75.9537965393556, Index: (Weapon : 3, Target : 61)
# not enough Missile for Target 61
# Value: 75.89251401000968, Index: (Weapon : 3, Target : 58)
# not enough Missile for Target 58
# Value: 75.74192496665586, Index: (Weapon : 3, Target : 99)
# Value: 75.13947092048186, Index: (Weapon : 0, Target : 95)
# not enough Missile for Target 95
# Value: 75.06117791902855, Index: (Weapon : 2, Target : 61)
# not enough Missile for Target 61
# Value: 74.98324902635086, Index: (Weapon : 2, Target : 27)
# not enough Missile for Target 27
# Value: 74.87243591861046, Index: (Weapon : 3, Target : 75)
# Value: 74.73520930961926, Index: (Weapon : 0, Target : 92)
# not enough Missile for Target 92
# Value: 74.57077183962551, Index: (Weapon : 0, Target : 19)
# not enough Missile for Target 19
# Value: 74.35219765395696, Index: (Weapon : 1, Target : 60)
# not enough Missile for Target 60
# Value: 74.30312868980921, Index: (Weapon : 4, Target : 26)
# not enough Missile for Target 26
# Value: 74.05425713498371, Index: (Weapon : 2, Target : 75)
# not enough Missile for Target 75
# Value: 73.22361761681498, Index: (Weapon : 3, Target : 65)
# not enough Missile for Target 65
# Value: 72.12731426499919, Index: (Weapon : 1, Target : 37)
# not enough Missile for Target 37
# Value: 72.02681734948423, Index: (Weapon : 0, Target : 43)
# not enough Missile for Target 43
# Value: 71.30631939797105, Index: (Weapon : 1, Target : 80)
# Value: 71.21951713839339, Index: (Weapon : 0, Target : 34)
# Value: 70.79918195051064, Index: (Weapon : 0, Target : 58)
# not enough Missile for Target 58
# Value: 70.57633796719173, Index: (Weapon : 4, Target : 78)
# not enough Missile for Target 78
# Value: 70.47517463843889, Index: (Weapon : 3, Target : 10)
# Value: 70.19603017173891, Index: (Weapon : 4, Target : 47)
# not enough Missile for Target 47
# Value: 70.16826870316382, Index: (Weapon : 0, Target : 3)
# not enough Missile for Target 3
# Value: 70.09025311046747, Index: (Weapon : 3, Target : 60)
# not enough Missile for Target 60
# Value: 69.98030913259208, Index: (Weapon : 1, Target : 86)
# Value: 69.93464718903408, Index: (Weapon : 1, Target : 49)
# not enough Missile for Target 49
# Value: 69.7898581303532, Index: (Weapon : 0, Target : 60)
# not enough Missile for Target 60
# Value: 69.7357524007162, Index: (Weapon : 4, Target : 43)
# not enough Missile for Target 43
# Value: 69.61571258555077, Index: (Weapon : 3, Target : 42)
# not enough Missile for Target 42
# Value: 69.49578192145351, Index: (Weapon : 4, Target : 39)
# not enough Missile for Target 39
# Value: 69.4822078114972, Index: (Weapon : 3, Target : 80)
# not enough Missile for Target 80
# Value: 69.38470929532603, Index: (Weapon : 0, Target : 87)
# not enough Missile for Target 87
# Value: 69.35233365896842, Index: (Weapon : 3, Target : 15)
# Value: 69.0356948321751, Index: (Weapon : 1, Target : 75)
# not enough Missile for Target 75
# Value: 68.71465013321502, Index: (Weapon : 3, Target : 44)
# Value: 68.68095530068216, Index: (Weapon : 2, Target : 58)
# not enough Missile for Target 58
# Value: 68.459302675322, Index: (Weapon : 0, Target : 74)
# not enough Missile for Target 74
# Value: 68.17965922138937, Index: (Weapon : 3, Target : 59)
# not enough Missile for Target 59
# Value: 67.95164277004683, Index: (Weapon : 3, Target : 49)
# not enough Missile for Target 49
# Value: 67.86124744539858, Index: (Weapon : 4, Target : 19)
# not enough Missile for Target 19
# Value: 67.68891828032858, Index: (Weapon : 1, Target : 43)
# not enough Missile for Target 43
# Value: 67.1116019922336, Index: (Weapon : 4, Target : 65)
# not enough Missile for Target 65
# Value: 67.07332724340702, Index: (Weapon : 3, Target : 4)
# not enough Missile for Target 4
# Value: 66.83746546825493, Index: (Weapon : 2, Target : 81)
# not enough Missile for Target 81
# Value: 66.6916736888789, Index: (Weapon : 4, Target : 11)
# not enough Missile for Target 11
# Value: 66.48124197981006, Index: (Weapon : 4, Target : 68)
# not enough Missile for Target 68
# Value: 66.15360472473432, Index: (Weapon : 1, Target : 96)
# Value: 66.04971324967853, Index: (Weapon : 4, Target : 84)
# not enough Missile for Target 84
# Value: 65.92126843267415, Index: (Weapon : 3, Target : 34)
# not enough Missile for Target 34
# Value: 65.80189306690943, Index: (Weapon : 1, Target : 82)
# not enough Missile for Target 82
# Value: 65.75551340303376, Index: (Weapon : 2, Target : 36)
# not enough Missile for Target 36
# Value: 65.39308153730947, Index: (Weapon : 2, Target : 96)
# not enough Missile for Target 96
# Value: 65.33708430380298, Index: (Weapon : 3, Target : 69)
# not enough Missile for Target 69
# Value: 65.1283512389164, Index: (Weapon : 4, Target : 91)
# not enough Missile for Target 91
# Value: 65.04732401472589, Index: (Weapon : 4, Target : 35)
# Value: 64.64697633357906, Index: (Weapon : 2, Target : 4)
# not enough Missile for Target 4
# Value: 64.56033488937176, Index: (Weapon : 0, Target : 46)
# not enough Missile for Target 46
# Value: 64.30388819335438, Index: (Weapon : 1, Target : 87)
# not enough Missile for Target 87
# Value: 63.908885163369895, Index: (Weapon : 3, Target : 86)
# not enough Missile for Target 86
# Value: 63.778094615052176, Index: (Weapon : 4, Target : 12)
# Value: 63.637534155542696, Index: (Weapon : 4, Target : 71)
# not enough Missile for Target 71
# Value: 63.32260205341042, Index: (Weapon : 0, Target : 22)
# not enough Missile for Target 22
# Value: 63.30681467292701, Index: (Weapon : 0, Target : 78)
# not enough Missile for Target 78
# Value: 63.222308586499885, Index: (Weapon : 2, Target : 69)
# not enough Missile for Target 69
# Value: 63.20062047191791, Index: (Weapon : 1, Target : 34)
# not enough Missile for Target 34
# Value: 62.76470520928484, Index: (Weapon : 1, Target : 51)
# Value: 62.76418364773094, Index: (Weapon : 1, Target : 59)
# not enough Missile for Target 59
# Value: 62.452349032570574, Index: (Weapon : 1, Target : 24)
# not enough Missile for Target 24
# Value: 62.08891043472397, Index: (Weapon : 2, Target : 14)
# not enough Missile for Target 14
# Value: 62.043941119951384, Index: (Weapon : 0, Target : 42)
# not enough Missile for Target 42
# Value: 61.492892220577936, Index: (Weapon : 3, Target : 6)
# Value: 61.42949012771878, Index: (Weapon : 0, Target : 21)
# not enough Missile for Target 21
# Value: 61.392462176255904, Index: (Weapon : 3, Target : 95)
# not enough Missile for Target 95
# Value: 61.14804127435509, Index: (Weapon : 0, Target : 85)
# not enough Missile for Target 85
# Value: 61.13222949906131, Index: (Weapon : 3, Target : 96)
# not enough Missile for Target 96
# Value: 60.91236623687462, Index: (Weapon : 4, Target : 48)
# not enough Missile for Target 48
# Value: 60.89074404287452, Index: (Weapon : 0, Target : 98)
# not enough Missile for Target 98
# Value: 60.86221872828558, Index: (Weapon : 3, Target : 20)
# not enough Missile for Target 20
# Value: 60.14699061928863, Index: (Weapon : 4, Target : 55)
# not enough Missile for Target 55
# Value: 59.728976236783716, Index: (Weapon : 1, Target : 27)
# not enough Missile for Target 27
# Value: 59.23328096710402, Index: (Weapon : 2, Target : 54)
# not enough Missile for Target 54
# Value: 58.6951468073346, Index: (Weapon : 0, Target : 0)
# not enough Missile for Target 0
# Value: 58.46795252574544, Index: (Weapon : 1, Target : 66)
# not enough Missile for Target 66
# Value: 58.27526102890667, Index: (Weapon : 0, Target : 18)
# not enough Missile for Target 18
# Value: 58.22699458309463, Index: (Weapon : 1, Target : 73)
# not enough Missile for Target 73
# Value: 58.024686232373334, Index: (Weapon : 2, Target : 45)
# not enough Missile for Target 45
# Value: 57.73609026806229, Index: (Weapon : 1, Target : 29)
# not enough Missile for Target 29
# Value: 57.649653572153476, Index: (Weapon : 0, Target : 10)
# not enough Missile for Target 10
# Value: 57.443549215482555, Index: (Weapon : 3, Target : 70)
# not enough Missile on Weapon 3
# Value: 57.18141891429152, Index: (Weapon : 3, Target : 54)
# not enough Missile for Target 54
# Value: 56.78736494971473, Index: (Weapon : 2, Target : 63)
# not enough Missile for Target 63
# Value: 56.35940507844514, Index: (Weapon : 2, Target : 46)
# not enough Missile for Target 46
# Value: 56.20158213484756, Index: (Weapon : 2, Target : 19)
# not enough Missile for Target 19
# Value: 56.06484894987866, Index: (Weapon : 2, Target : 29)
# not enough Missile for Target 29
# Value: 55.48460828226825, Index: (Weapon : 1, Target : 95)
# not enough Missile for Target 95
# Value: 55.24707242906899, Index: (Weapon : 0, Target : 59)
# not enough Missile for Target 59
# Value: 55.240752660353635, Index: (Weapon : 3, Target : 31)
# not enough Missile on Weapon 3
# Value: 55.057184765596915, Index: (Weapon : 3, Target : 91)
# not enough Missile for Target 91
# Value: 54.974116639229, Index: (Weapon : 2, Target : 51)
# not enough Missile for Target 51
# Value: 54.70555191853995, Index: (Weapon : 1, Target : 20)
# not enough Missile for Target 20
# Value: 54.69146684017168, Index: (Weapon : 0, Target : 99)
# not enough Missile for Target 99
# Value: 54.336077472531166, Index: (Weapon : 2, Target : 6)
# not enough Missile for Target 6
# Value: 54.33578651815056, Index: (Weapon : 2, Target : 79)
# not enough Missile for Target 79
# Value: 54.27737191226671, Index: (Weapon : 3, Target : 63)
# not enough Missile for Target 63
# Value: 53.79191139136019, Index: (Weapon : 3, Target : 64)
# not enough Missile for Target 64
# Value: 53.4647484056755, Index: (Weapon : 3, Target : 85)
# not enough Missile for Target 85
# Value: 53.25663213603834, Index: (Weapon : 4, Target : 57)
# not enough Missile for Target 57
# Value: 53.179842666922035, Index: (Weapon : 4, Target : 9)
# not enough Missile for Target 9
# Value: 52.86381443925079, Index: (Weapon : 4, Target : 28)
# not enough Missile for Target 28
# Value: 52.69971249759752, Index: (Weapon : 3, Target : 41)
# not enough Missile on Weapon 3
# Value: 52.61793355479947, Index: (Weapon : 4, Target : 86)
# not enough Missile for Target 86
# Value: 52.243757831713715, Index: (Weapon : 3, Target : 37)
# not enough Missile for Target 37
# Value: 52.13181885322645, Index: (Weapon : 4, Target : 56)
# Value: 52.05508635459557, Index: (Weapon : 0, Target : 39)
# not enough Missile for Target 39
# Value: 51.93312968038397, Index: (Weapon : 0, Target : 89)
# not enough Missile for Target 89
# Value: 51.68417964754418, Index: (Weapon : 1, Target : 16)
# not enough Missile for Target 16
# Value: 51.5471013567728, Index: (Weapon : 0, Target : 79)
# not enough Missile for Target 79
# Value: 51.48806024693164, Index: (Weapon : 0, Target : 6)
# not enough Missile for Target 6
# Value: 51.38000211825675, Index: (Weapon : 1, Target : 6)
# not enough Missile for Target 6
# Value: 51.09624637336821, Index: (Weapon : 3, Target : 77)
# not enough Missile for Target 77
# Value: 50.961943299483444, Index: (Weapon : 4, Target : 76)
# Value: 50.69599087645467, Index: (Weapon : 2, Target : 47)
# not enough Missile for Target 47
# Value: 50.61095696979498, Index: (Weapon : 0, Target : 64)
# not enough Missile for Target 64
# Value: 50.127949013056615, Index: (Weapon : 1, Target : 47)
# not enough Missile for Target 47
# Value: 49.74285435697682, Index: (Weapon : 2, Target : 15)
# not enough Missile for Target 15
# Value: 49.73693609680301, Index: (Weapon : 3, Target : 84)
# not enough Missile for Target 84
# Value: 49.70845249168719, Index: (Weapon : 2, Target : 73)
# not enough Missile for Target 73
# Value: 48.847289266628636, Index: (Weapon : 4, Target : 34)
# not enough Missile for Target 34
# Value: 48.551570935191236, Index: (Weapon : 0, Target : 26)
# not enough Missile for Target 26
# Value: 48.478806324090364, Index: (Weapon : 4, Target : 40)
# not enough Missile on Weapon 4
# Value: 48.45640490803512, Index: (Weapon : 0, Target : 16)
# not enough Missile for Target 16
# Value: 48.22766456482009, Index: (Weapon : 4, Target : 3)
# not enough Missile for Target 3
# Value: 48.14093654660217, Index: (Weapon : 1, Target : 72)
# not enough Missile for Target 72
# Value: 47.89153360547188, Index: (Weapon : 0, Target : 52)
# not enough Missile for Target 52
# Value: 47.86244081893131, Index: (Weapon : 4, Target : 51)
# not enough Missile for Target 51
# Value: 47.106793389865054, Index: (Weapon : 0, Target : 2)
# not enough Missile for Target 2
# Value: 47.05715343899616, Index: (Weapon : 0, Target : 48)
# not enough Missile for Target 48
# Value: 46.94429641409855, Index: (Weapon : 4, Target : 75)
# not enough Missile for Target 75
# Value: 46.85929384446518, Index: (Weapon : 2, Target : 80)
# not enough Missile for Target 80
# Value: 46.76896512793623, Index: (Weapon : 1, Target : 8)
# not enough Missile for Target 8
# Value: 46.674274616072275, Index: (Weapon : 0, Target : 30)
# Value: 45.64397169608841, Index: (Weapon : 4, Target : 36)
# not enough Missile for Target 36
# Value: 45.52764553205757, Index: (Weapon : 2, Target : 62)
# not enough Missile on Weapon 2
# Value: 45.41356597273676, Index: (Weapon : 4, Target : 62)
# not enough Missile on Weapon 4
# Value: 45.36301371610259, Index: (Weapon : 2, Target : 26)
# not enough Missile for Target 26
# Value: 45.213658960187935, Index: (Weapon : 0, Target : 13)
# Value: 44.00341657987473, Index: (Weapon : 3, Target : 83)
# not enough Missile for Target 83
# Value: 43.84442943759903, Index: (Weapon : 4, Target : 72)
# not enough Missile for Target 72
# Value: 43.696040189916125, Index: (Weapon : 1, Target : 14)
# not enough Missile for Target 14
# Value: 43.38733875019865, Index: (Weapon : 1, Target : 9)
# not enough Missile for Target 9
# Value: 43.11762251256241, Index: (Weapon : 1, Target : 67)
# not enough Missile for Target 67
# Value: 43.09999316619054, Index: (Weapon : 3, Target : 2)
# not enough Missile for Target 2
# Value: 42.581482453297255, Index: (Weapon : 0, Target : 45)
# not enough Missile for Target 45
# Value: 42.5696812666006, Index: (Weapon : 2, Target : 70)
# not enough Missile on Weapon 2
# Value: 42.1742363792865, Index: (Weapon : 1, Target : 62)
# Value: 42.060538198967265, Index: (Weapon : 2, Target : 35)
# not enough Missile for Target 35
# Value: 41.935176034716136, Index: (Weapon : 1, Target : 11)
# not enough Missile for Target 11
# Value: 41.882389576445995, Index: (Weapon : 1, Target : 83)
# not enough Missile for Target 83
# Value: 41.44504949343262, Index: (Weapon : 0, Target : 61)
# not enough Missile for Target 61
# Value: 41.3363808986888, Index: (Weapon : 2, Target : 56)
# not enough Missile for Target 56
# Value: 40.96424176596834, Index: (Weapon : 3, Target : 48)
# not enough Missile for Target 48
# Value: 40.749935847762124, Index: (Weapon : 0, Target : 15)
# not enough Missile for Target 15
# Value: 40.46860911751389, Index: (Weapon : 4, Target : 32)
# not enough Missile for Target 32
# Value: 39.76713031539489, Index: (Weapon : 2, Target : 37)
# not enough Missile for Target 37
# Value: 39.68707679956654, Index: (Weapon : 3, Target : 35)
# not enough Missile for Target 35
# Value: 39.64440493885641, Index: (Weapon : 3, Target : 33)
# not enough Missile for Target 33
# Value: 39.52301598213302, Index: (Weapon : 1, Target : 99)
# not enough Missile for Target 99
# Value: 39.39394286865883, Index: (Weapon : 0, Target : 80)
# not enough Missile for Target 80
# Value: 39.305557395984735, Index: (Weapon : 1, Target : 45)
# not enough Missile for Target 45
# Value: 39.30435301098571, Index: (Weapon : 4, Target : 42)
# not enough Missile for Target 42
# Value: 39.264401100480406, Index: (Weapon : 4, Target : 30)
# not enough Missile for Target 30
# Value: 39.226051721512654, Index: (Weapon : 3, Target : 12)
# not enough Missile for Target 12
# Value: 39.16773309494689, Index: (Weapon : 2, Target : 52)
# not enough Missile for Target 52
# Value: 38.839575066480485, Index: (Weapon : 1, Target : 41)
# not enough Missile on Weapon 1
# Value: 38.56530222721131, Index: (Weapon : 1, Target : 76)
# not enough Missile for Target 76
# Value: 38.45200759974142, Index: (Weapon : 1, Target : 71)
# not enough Missile for Target 71
# Value: 37.89365770503438, Index: (Weapon : 2, Target : 93)
# not enough Missile for Target 93
# Value: 37.60949647481572, Index: (Weapon : 1, Target : 94)
# not enough Missile for Target 94
# Value: 37.44851389340813, Index: (Weapon : 4, Target : 90)
# not enough Missile for Target 90
# Value: 37.06698440409426, Index: (Weapon : 4, Target : 88)
# not enough Missile for Target 88
# Value: 37.03219987572524, Index: (Weapon : 3, Target : 47)
# not enough Missile for Target 47
# Value: 36.757407483967434, Index: (Weapon : 3, Target : 57)
# not enough Missile for Target 57
# Value: 36.5828304738253, Index: (Weapon : 1, Target : 93)
# not enough Missile for Target 93
# Value: 36.3800569029408, Index: (Weapon : 1, Target : 85)
# not enough Missile for Target 85
# Value: 36.18836378368956, Index: (Weapon : 4, Target : 1)
# not enough Missile for Target 1
# Value: 36.020632734072144, Index: (Weapon : 2, Target : 49)
# not enough Missile for Target 49
# Value: 35.58586195114357, Index: (Weapon : 4, Target : 92)
# not enough Missile for Target 92
# Value: 35.55061168529933, Index: (Weapon : 2, Target : 67)
# not enough Missile for Target 67
# Value: 35.41803052395353, Index: (Weapon : 1, Target : 12)
# not enough Missile for Target 12
# Value: 35.40626444997366, Index: (Weapon : 2, Target : 33)
# not enough Missile for Target 33
# Value: 35.23302630944595, Index: (Weapon : 3, Target : 52)
# not enough Missile for Target 52
# Value: 35.06825736089902, Index: (Weapon : 0, Target : 90)
# not enough Missile for Target 90
# Value: 35.02808422469145, Index: (Weapon : 4, Target : 89)
# not enough Missile for Target 89
# Value: 34.64929151938672, Index: (Weapon : 0, Target : 35)
# not enough Missile for Target 35
# Value: 34.639870369884015, Index: (Weapon : 1, Target : 48)
# not enough Missile for Target 48
# Value: 34.14080207565206, Index: (Weapon : 3, Target : 87)
# not enough Missile for Target 87
# Value: 34.08462730519495, Index: (Weapon : 2, Target : 5)
# not enough Missile for Target 5
# Value: 33.86828364517508, Index: (Weapon : 3, Target : 23)
# not enough Missile for Target 23
# Value: 32.7956191489799, Index: (Weapon : 2, Target : 89)
# not enough Missile for Target 89
# Value: 32.729033775161824, Index: (Weapon : 2, Target : 87)
# not enough Missile for Target 87
# Value: 32.713616687681544, Index: (Weapon : 1, Target : 33)
# not enough Missile for Target 33
# Value: 32.63546460055985, Index: (Weapon : 1, Target : 38)
# not enough Missile for Target 38
# Value: 31.82582015456632, Index: (Weapon : 4, Target : 74)
# not enough Missile for Target 74
# Value: 31.71230236457233, Index: (Weapon : 2, Target : 90)
# not enough Missile for Target 90
# Value: 31.663555048932274, Index: (Weapon : 4, Target : 66)
# not enough Missile for Target 66
# Value: 31.519514729951478, Index: (Weapon : 3, Target : 89)
# not enough Missile for Target 89
# Value: 31.48483446507826, Index: (Weapon : 3, Target : 92)
# not enough Missile for Target 92
# Value: 31.35633598879217, Index: (Weapon : 0, Target : 41)
# Value: 31.338470792681573, Index: (Weapon : 1, Target : 56)
# not enough Missile for Target 56
# Value: 31.337570974855268, Index: (Weapon : 4, Target : 23)
# not enough Missile for Target 23
# Value: 31.04547056252742, Index: (Weapon : 4, Target : 0)
# not enough Missile for Target 0
# Value: 30.752292610839323, Index: (Weapon : 0, Target : 56)
# not enough Missile for Target 56
# Value: 30.544267995885647, Index: (Weapon : 2, Target : 0)
# not enough Missile for Target 0
# Value: 30.21368156660987, Index: (Weapon : 4, Target : 59)
# not enough Missile for Target 59
# Value: 30.199623137923297, Index: (Weapon : 3, Target : 30)
# not enough Missile for Target 30
# Value: 30.025900220546944, Index: (Weapon : 3, Target : 51)
# not enough Missile for Target 51
# Value: 29.76446471097992, Index: (Weapon : 2, Target : 77)
# not enough Missile for Target 77
# Value: 29.616210809837796, Index: (Weapon : 1, Target : 70)
# not enough Missile on Weapon 1
# Value: 29.576280774342152, Index: (Weapon : 4, Target : 24)
# not enough Missile for Target 24
# Value: 29.31664956805464, Index: (Weapon : 4, Target : 33)
# not enough Missile for Target 33
# Value: 29.29903352530385, Index: (Weapon : 1, Target : 0)
# not enough Missile for Target 0
# Value: 29.293305661310484, Index: (Weapon : 3, Target : 50)
# not enough Missile for Target 50
# Value: 29.13235024883921, Index: (Weapon : 3, Target : 1)
# not enough Missile for Target 1
# Value: 28.92555915158468, Index: (Weapon : 2, Target : 84)
# not enough Missile for Target 84
# Value: 28.847493233153372, Index: (Weapon : 4, Target : 81)
# not enough Missile for Target 81
# Value: 28.46690572577559, Index: (Weapon : 0, Target : 12)
# not enough Missile for Target 12
# Value: 28.42811857574661, Index: (Weapon : 3, Target : 62)
# not enough Missile for Target 62
# Value: 28.38495162099904, Index: (Weapon : 1, Target : 97)
# not enough Missile for Target 97
# Value: 28.203666534819387, Index: (Weapon : 4, Target : 44)
# not enough Missile for Target 44
# Value: 27.805089968592025, Index: (Weapon : 1, Target : 35)
# not enough Missile for Target 35
# Value: 27.55420453369132, Index: (Weapon : 0, Target : 72)
# not enough Missile for Target 72
# Value: 27.53353476372131, Index: (Weapon : 2, Target : 40)
# not enough Missile on Weapon 2
# Value: 27.521004534751125, Index: (Weapon : 3, Target : 67)
# not enough Missile for Target 67
# Value: 27.38832329070977, Index: (Weapon : 1, Target : 46)
# not enough Missile for Target 46
# Value: 27.35737812096789, Index: (Weapon : 1, Target : 92)
# not enough Missile for Target 92
# Value: 27.155274680432395, Index: (Weapon : 3, Target : 79)
# not enough Missile for Target 79
# Value: 26.883558447053357, Index: (Weapon : 4, Target : 54)
# not enough Missile for Target 54
# Value: 26.859304024588155, Index: (Weapon : 3, Target : 39)
# not enough Missile for Target 39
# Value: 26.60219384692808, Index: (Weapon : 1, Target : 53)
# not enough Missile for Target 53
# Value: 26.32465710634231, Index: (Weapon : 1, Target : 2)
# not enough Missile for Target 2
# Value: 26.29762220660328, Index: (Weapon : 0, Target : 50)
# not enough Missile for Target 50
# Value: 26.265029129167694, Index: (Weapon : 0, Target : 37)
# not enough Missile for Target 37
# Value: 26.20031020227723, Index: (Weapon : 0, Target : 76)
# not enough Missile for Target 76
# Value: 26.113000958595748, Index: (Weapon : 1, Target : 77)
# not enough Missile for Target 77
# Value: 26.017195676124416, Index: (Weapon : 1, Target : 15)
# not enough Missile for Target 15
# Value: 25.700423116264332, Index: (Weapon : 4, Target : 14)
# not enough Missile for Target 14
# Value: 25.678361030010503, Index: (Weapon : 2, Target : 60)
# not enough Missile for Target 60
# Value: 25.547862041302317, Index: (Weapon : 3, Target : 40)
# not enough Missile on Weapon 3
# Value: 25.35526570698178, Index: (Weapon : 0, Target : 53)
# not enough Missile for Target 53
# Value: 25.251314746347305, Index: (Weapon : 4, Target : 25)
# not enough Missile for Target 25
# Value: 25.18385771064481, Index: (Weapon : 0, Target : 36)
# not enough Missile for Target 36
# Value: 24.212391293035715, Index: (Weapon : 2, Target : 25)
# not enough Missile for Target 25
# Value: 24.124109652841987, Index: (Weapon : 0, Target : 17)
# not enough Missile for Target 17
# Value: 23.51479066064862, Index: (Weapon : 3, Target : 38)
# not enough Missile for Target 38
# Value: 23.347588186457912, Index: (Weapon : 0, Target : 20)
# not enough Missile for Target 20
# Value: 23.044494545930096, Index: (Weapon : 0, Target : 55)
# not enough Missile for Target 55
# Value: 22.826557679688182, Index: (Weapon : 1, Target : 52)
# not enough Missile for Target 52
# Value: 22.54635834138136, Index: (Weapon : 4, Target : 99)
# not enough Missile for Target 99
# Value: 22.21694758016318, Index: (Weapon : 0, Target : 8)
# not enough Missile for Target 8
# Value: 21.900594645427642, Index: (Weapon : 1, Target : 42)
# not enough Missile for Target 42
# Value: 21.76621688751909, Index: (Weapon : 3, Target : 78)
# not enough Missile for Target 78
# Value: 20.776186913144052, Index: (Weapon : 4, Target : 16)
# not enough Missile for Target 16
# Value: 20.158472275645966, Index: (Weapon : 2, Target : 28)
# not enough Missile for Target 28
# Value: 20.076808077512528, Index: (Weapon : 1, Target : 10)
# not enough Missile for Target 10
# Value: 19.92540981032568, Index: (Weapon : 4, Target : 2)
# not enough Missile for Target 2
# Value: 19.81879893263716, Index: (Weapon : 4, Target : 10)
# not enough Missile for Target 10
# Value: 19.700103052622914, Index: (Weapon : 1, Target : 84)
# not enough Missile for Target 84
# Value: 19.6922221320191, Index: (Weapon : 1, Target : 31)
# not enough Missile on Weapon 1
# Value: 19.44864819027444, Index: (Weapon : 4, Target : 67)
# not enough Missile for Target 67
# Value: 19.168705749847152, Index: (Weapon : 4, Target : 96)
# not enough Missile for Target 96
# Value: 19.130392954981055, Index: (Weapon : 4, Target : 18)
# not enough Missile for Target 18
# Value: 18.403862682694253, Index: (Weapon : 0, Target : 73)
# not enough Missile for Target 73
# Value: 18.395858074373574, Index: (Weapon : 2, Target : 30)
# not enough Missile for Target 30
# Value: 18.3495101109589, Index: (Weapon : 0, Target : 27)
# not enough Missile for Target 27
# Value: 16.812130813999755, Index: (Weapon : 2, Target : 16)
# not enough Missile for Target 16
# Value: 16.761956363816477, Index: (Weapon : 2, Target : 41)
# not enough Missile for Target 41
# Value: 16.723685470592, Index: (Weapon : 3, Target : 46)
# not enough Missile for Target 46
# Value: 16.64606968425921, Index: (Weapon : 3, Target : 90)
# not enough Missile for Target 90
# Value: 16.576146126494383, Index: (Weapon : 3, Target : 13)
# not enough Missile for Target 13
# Value: 16.2047418540132, Index: (Weapon : 1, Target : 13)
# not enough Missile for Target 13
# Value: 15.441814875411197, Index: (Weapon : 1, Target : 61)
# not enough Missile for Target 61
# Value: 15.084083881479662, Index: (Weapon : 2, Target : 97)
# not enough Missile for Target 97
# Value: 15.050695493747382, Index: (Weapon : 0, Target : 69)
# not enough Missile for Target 69
# Value: 14.971792272434415, Index: (Weapon : 2, Target : 43)
# not enough Missile for Target 43
# Value: 14.689514830060189, Index: (Weapon : 2, Target : 17)
# not enough Missile for Target 17
# Value: 14.592610148808847, Index: (Weapon : 3, Target : 74)
# not enough Missile for Target 74
# Value: 14.039910294446273, Index: (Weapon : 0, Target : 40)
# Value: 13.954790175845678, Index: (Weapon : 0, Target : 82)
# not enough Missile for Target 82
# Value: 13.903512615734245, Index: (Weapon : 4, Target : 77)
# not enough Missile for Target 77
# Value: 13.834832107630543, Index: (Weapon : 2, Target : 86)
# not enough Missile for Target 86
# Value: 13.419294877742132, Index: (Weapon : 1, Target : 79)
# not enough Missile for Target 79
# Value: 13.283190169750476, Index: (Weapon : 4, Target : 22)
# not enough Missile for Target 22
# Value: 13.098261810453225, Index: (Weapon : 4, Target : 17)
# not enough Missile for Target 17
# Value: 13.037040899631231, Index: (Weapon : 4, Target : 41)
# not enough Missile for Target 41
# Value: 12.806220342831262, Index: (Weapon : 0, Target : 29)
# not enough Missile for Target 29
# Value: 12.67406617463085, Index: (Weapon : 1, Target : 28)
# not enough Missile for Target 28
# Value: 12.602108516587398, Index: (Weapon : 0, Target : 38)
# not enough Missile for Target 38
# Value: 12.08647507681025, Index: (Weapon : 4, Target : 13)
# not enough Missile for Target 13
# Value: 11.907457152967492, Index: (Weapon : 0, Target : 91)
# not enough Missile for Target 91
# Value: 11.772777272455343, Index: (Weapon : 2, Target : 55)
# not enough Missile for Target 55
# Value: 11.742936318210823, Index: (Weapon : 2, Target : 23)
# not enough Missile for Target 23
# Value: 11.716593967927437, Index: (Weapon : 4, Target : 6)
# not enough Missile for Target 6
# Value: 11.539302630530255, Index: (Weapon : 2, Target : 32)
# not enough Missile for Target 32
# Value: 11.112749266151214, Index: (Weapon : 4, Target : 97)
# not enough Missile for Target 97
# Value: 10.941707111213395, Index: (Weapon : 1, Target : 23)
# not enough Missile for Target 23
# Value: 10.781470145291294, Index: (Weapon : 0, Target : 75)
# not enough Missile for Target 75
# Value: 10.708386923157427, Index: (Weapon : 1, Target : 40)
# not enough Missile for Target 40
# Value: 10.63978420911165, Index: (Weapon : 0, Target : 11)
# not enough Missile for Target 11
# Value: 10.56156223346863, Index: (Weapon : 4, Target : 31)
# not enough Missile on Weapon 4
# Value: 10.368874561448036, Index: (Weapon : 2, Target : 31)
# not enough Missile on Weapon 2
# Value: 10.295092959152077, Index: (Weapon : 1, Target : 58)
# not enough Missile for Target 58
# Value: 10.294819676798623, Index: (Weapon : 4, Target : 45)
# not enough Missile for Target 45
# Value: 10.254267881388847, Index: (Weapon : 1, Target : 64)
# not enough Missile for Target 64
# Value: 10.142181895421107, Index: (Weapon : 1, Target : 44)
# not enough Missile for Target 44
# Value: 10.129364772871828, Index: (Weapon : 2, Target : 83)
# not enough Missile for Target 83
# Value: 10.083606909573431, Index: (Weapon : 4, Target : 21)
# not enough Missile for Target 21
# Value: 10.009641565785643, Index: (Weapon : 3, Target : 88)
# not enough Missile for Target 88
# Value: 9.92492266350901, Index: (Weapon : 0, Target : 94)
# not enough Missile for Target 94
# Value: 9.923110304988182, Index: (Weapon : 2, Target : 99)
# not enough Missile for Target 99
# Value: 9.762426503558293, Index: (Weapon : 2, Target : 8)
# not enough Missile for Target 8
# Value: 9.683205986426222, Index: (Weapon : 3, Target : 7)
# not enough Missile on Weapon 3
# Value: 8.493665451463677, Index: (Weapon : 2, Target : 38)
# not enough Missile for Target 38
# Value: 8.29534393809837, Index: (Weapon : 3, Target : 76)
# not enough Missile for Target 76
# Value: 8.245806992180924, Index: (Weapon : 0, Target : 65)
# not enough Missile for Target 65
# Value: 7.746363869356411, Index: (Weapon : 3, Target : 56)
# not enough Missile for Target 56
# Value: 7.452450703440713, Index: (Weapon : 3, Target : 55)
# not enough Missile for Target 55
# Value: 6.741216824968554, Index: (Weapon : 0, Target : 31)
# Value: 6.54135212131552, Index: (Weapon : 1, Target : 7)
# not enough Missile on Weapon 1
# Value: 6.447025386333021, Index: (Weapon : 3, Target : 27)
# not enough Missile for Target 27
# Value: 6.206197340340414, Index: (Weapon : 2, Target : 39)
# not enough Missile for Target 39
# Value: 5.947718467012538, Index: (Weapon : 4, Target : 15)
# not enough Missile for Target 15
# Value: 5.733018412729764, Index: (Weapon : 4, Target : 80)
# not enough Missile for Target 80
# Value: 5.319621188019801, Index: (Weapon : 3, Target : 11)
# not enough Missile for Target 11
# Value: 5.056472536756422, Index: (Weapon : 0, Target : 66)
# not enough Missile for Target 66
# Value: 5.054253404500438, Index: (Weapon : 2, Target : 88)
# not enough Missile for Target 88
# Value: 5.049723574046825, Index: (Weapon : 2, Target : 13)
# not enough Missile for Target 13
# Value: 4.900474681845706, Index: (Weapon : 4, Target : 20)
# not enough Missile for Target 20
# Value: 4.412539987778745, Index: (Weapon : 3, Target : 28)
# not enough Missile for Target 28
# Value: 4.353567770384969, Index: (Weapon : 0, Target : 4)
# not enough Missile for Target 4
# Value: 4.247712849853258, Index: (Weapon : 0, Target : 86)
# not enough Missile for Target 86
# Value: 4.194040662052883, Index: (Weapon : 4, Target : 98)
# not enough Missile for Target 98
# Value: 4.076799341484045, Index: (Weapon : 2, Target : 10)
# not enough Missile for Target 10
# Value: 3.7664234719707332, Index: (Weapon : 4, Target : 82)
# not enough Missile for Target 82
# Value: 3.675830785253334, Index: (Weapon : 3, Target : 21)
# not enough Missile for Target 21
# Value: 3.632450369071886, Index: (Weapon : 3, Target : 73)
# not enough Missile for Target 73
# Value: 3.53852556754789, Index: (Weapon : 2, Target : 71)
# not enough Missile for Target 71
# Value: 3.480845911903224, Index: (Weapon : 1, Target : 17)
# not enough Missile for Target 17
# Value: 3.035443784246074, Index: (Weapon : 0, Target : 7)
# Value: 3.0122250183635852, Index: (Weapon : 4, Target : 95)
# not enough Missile for Target 95
# Value: 2.9890845536024497, Index: (Weapon : 3, Target : 81)
# not enough Missile for Target 81
# Value: 2.493838639760109, Index: (Weapon : 4, Target : 7)
# not enough Missile for Target 7
# Value: 2.4521367458856185, Index: (Weapon : 2, Target : 94)
# not enough Missile for Target 94
# Value: 2.4331254063896406, Index: (Weapon : 1, Target : 50)
# not enough Missile for Target 50
# Value: 2.4029977575840604, Index: (Weapon : 0, Target : 44)
# not enough Missile for Target 44
# Value: 2.1145096108964823, Index: (Weapon : 2, Target : 82)
# not enough Missile for Target 82
# Value: 2.074056857505316, Index: (Weapon : 0, Target : 14)
# not enough Missile for Target 14
# Value: 1.9267842636207342, Index: (Weapon : 1, Target : 98)
# not enough Missile for Target 98
# Value: 1.7915394619460399, Index: (Weapon : 1, Target : 65)
# not enough Missile for Target 65
# Value: 1.6889881396506532, Index: (Weapon : 0, Target : 96)
# not enough Missile for Target 96
# Value: 1.609026079059598, Index: (Weapon : 4, Target : 70)
# not enough Missile on Weapon 4
# Value: 1.410899999879292, Index: (Weapon : 3, Target : 22)
# not enough Missile for Target 22
# Value: 1.3373619560451693, Index: (Weapon : 0, Target : 51)
# not enough Missile for Target 51
# Value: 1.1241577227070634, Index: (Weapon : 0, Target : 63)
# not enough Missile for Target 63
# Value: 0.9963058699532397, Index: (Weapon : 0, Target : 1)
# not enough Missile for Target 1
# Value: 0.5256947138521123, Index: (Weapon : 0, Target : 62)
# not enough Missile for Target 62
# Value: 0.460828846881165, Index: (Weapon : 2, Target : 34)
# not enough Missile for Target 34
# Value: 0.20439892186774966, Index: (Weapon : 1, Target : 30)
# not enough Missile for Target 30
# Value: 0.06575764043024457, Index: (Weapon : 0, Target : 70)

# %%
print(objective_fun_1(theta_wt))
# Out:
# 8218.77301257516

# %%
indices = np.where(theta_wt == 1)


# Convert the indices to a list of tuples
indices_list = list(zip(*indices))

# Sort the indices by the second index (M)
indices_list.sort(key=lambda x: x[1])
print(f"목표 함수 값 : {objective_fun_1(theta_wt)}")

for i, group in enumerate(indices_list):
    # Iterate over each group
    print(f"타깃 {group[1]}에 대하여 발사대 {group[0]}가 미사일을 발사합니다. 요격확률 : {PK_wt[group[0], group[1]]:.2f}")
# Out:
# 목표 함수 값 : 8218.77301257516
# 타깃 0에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 85.84
# 타깃 1에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 93.28
# 타깃 2에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 87.94
# 타깃 3에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 85.17
# 타깃 4에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 98.05
# 타깃 5에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 92.85
# 타깃 6에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 61.49
# 타깃 7에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 3.04
# 타깃 8에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 88.97
# 타깃 9에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 94.41
# 타깃 10에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 70.48
# 타깃 11에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 80.83
# 타깃 12에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 63.78
# 타깃 13에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 45.21
# 타깃 14에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 81.37
# 타깃 15에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 69.35
# 타깃 16에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 87.42
# 타깃 17에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 95.69
# 타깃 18에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 89.72
# 타깃 19에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 98.43
# 타깃 20에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 97.32
# 타깃 21에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 97.24
# 타깃 22에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 98.27
# 타깃 23에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 93.91
# 타깃 24에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 92.89
# 타깃 25에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 98.80
# 타깃 26에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 97.80
# 타깃 27에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 98.80
# 타깃 28에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 98.59
# 타깃 29에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 93.48
# 타깃 30에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 46.67
# 타깃 31에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 6.74
# 타깃 32에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 97.26
# 타깃 33에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 95.53
# 타깃 34에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 71.22
# 타깃 35에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 65.05
# 타깃 36에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 93.83
# 타깃 37에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 92.58
# 타깃 38에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 87.59
# 타깃 39에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 78.38
# 타깃 40에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 14.04
# 타깃 41에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 31.36
# 타깃 42에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 95.54
# 타깃 43에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 93.98
# 타깃 44에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 68.71
# 타깃 45에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 77.34
# 타깃 46에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 89.88
# 타깃 47에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 84.47
# 타깃 48에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 96.20
# 타깃 49에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 95.95
# 타깃 50에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 82.73
# 타깃 51에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 62.76
# 타깃 52에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 87.24
# 타깃 53에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 94.59
# 타깃 54에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 81.55
# 타깃 55에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 94.60
# 타깃 56에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 52.13
# 타깃 57에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 81.85
# 타깃 58에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 92.83
# 타깃 59에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 90.72
# 타깃 60에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 97.36
# 타깃 61에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 89.31
# 타깃 62에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 42.17
# 타깃 63에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 88.38
# 타깃 64에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 94.55
# 타깃 65에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 96.95
# 타깃 66에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 94.73
# 타깃 67에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 95.59
# 타깃 68에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 87.88
# 타깃 69에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 91.42
# 타깃 70에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 0.07
# 타깃 71에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 93.23
# 타깃 72에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 93.46
# 타깃 73에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 88.91
# 타깃 74에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 97.40
# 타깃 75에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 74.87
# 타깃 76에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 50.96
# 타깃 77에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 96.53
# 타깃 78에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 93.52
# 타깃 79에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 82.22
# 타깃 80에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 71.31
# 타깃 81에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 91.61
# 타깃 82에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 86.46
# 타깃 83에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 95.77
# 타깃 84에 대하여 발사대 0가 미사일을 발사합니다. 요격확률 : 85.25
# 타깃 85에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 97.32
# 타깃 86에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 69.98
# 타깃 87에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 79.40
# 타깃 88에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 91.87
# 타깃 89에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 85.82
# 타깃 90에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 80.80
# 타깃 91에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 93.73
# 타깃 92에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 83.67
# 타깃 93에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 94.85
# 타깃 94에 대하여 발사대 4가 미사일을 발사합니다. 요격확률 : 97.34
# 타깃 95에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 82.27
# 타깃 96에 대하여 발사대 1가 미사일을 발사합니다. 요격확률 : 66.15
# 타깃 97에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 97.55
# 타깃 98에 대하여 발사대 2가 미사일을 발사합니다. 요격확률 : 98.61
# 타깃 99에 대하여 발사대 3가 미사일을 발사합니다. 요격확률 : 75.74

# %%
"""
제약조건 (2)
수식 (2)는 동일 유도탄이 다수의 표적에 중복하여 할당되지 않기 위한 제약 조건이다.
"""

# 동일 유도탄이 다수의 표적에 중복 할당 X
def constraint2(theta_wt):
    W, T, M = theta_wt.shape
    for m in range(M):
        for w in range(W):
            # If the sum exceeds 1, immediately return False
            if np.sum(theta_wt[w,:,m]) > 1:
                return False
    # If none of the sums exceed 1, return True
    return True

# Now we can check the constraint:
print(constraint2(theta_wt))
# Out:
# True

# %%
"""
제약조건 (3)
각 위협 표적에 할당할 수 있는 유도탄의 개수를 제한하기 위하여 수식 (3)과 같은 제약식을 적용한다.
"""
# constraint3
def constraint3(theta_wt):
    W, T, M = theta_wt.shape
    for t in range(T):
        if np.sum(theta_wt[:,t,:]) > FN_T[t]:
            return False
    return True

print(constraint3(theta_wt))
# Out:
# True

# %%
"""
제약조건 (4)
한 발사대가 연속발사를 하기 위해서는 발사절차 및 발사대 안정화를 위한 시간을 고려하여야 하므로, 수식 (4)과 같이 한 발사대 상의 연속적 발사를 위한 최소 발사 간격을 제약으로 고려한다.
"""

def constraint4(theta_wt):
    return True

# %%
"""
제약조건 (5)
각 발사대에서 발사된 유도탄은 제한된 공간 영역 상에서 표적을 요격할 수 있다.
표적의 예상 궤적과 발사대 위치에 따른 요격 공간으로부터 교전 가능한 유도탄 발사 시간이 계산되어진다.
위협 표적에 대해 서 교전 가능한 발사 시간 구간 내에서 발사 시점이 산출되어야만 교전 가능하므로, 수식 (5)와 같이 표적 t에 대한 발사대 w에서 발사 가능한 시간에 대한 제 약 조건을 고려해야 한다.
"""
def constraint5(theta_wt):
    return True

# %%
"""
제약조건 (6)
각 발사대는 적재된 수량만큼 유도탄을 사용할 수 있으므로, 수식 (6)과 같이 한 발사대에서 할당할 수 있는 유도탄의 개수는 적재량 이하여야 한다는 제약 조건을 고려한다.
"""
def constraint6(theta_wt):
    W, T, M = theta_wt.shape
    for w in range(W):
        if np.sum(theta_wt[w,:,:]) > m_w[w]:
            return False
    return True

print(constraint6(theta_wt))
# Out:
# True
